# %%
# !pip install transformers
# Out:
# Requirement already satisfied: transformers in c:\users\ed\appdata\local\programs\python\python313\lib\site-packages (4.57.3)
# Requirement already satisfied: filelock in c:\users\ed\appdata\local\programs\python\python313\lib\site-packages (from transformers) (3.20.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.34.0 in c:\users\ed\appdata\local\programs\python\python313\lib\site-packages (from transformers) (0.36.0)
# Requirement already satisfied: numpy>=1.17 in c:\users\ed\appdata\local\programs\python\python313\lib\site-packages (from transformers) (2.3.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\ed\appdata\roaming\python\python313\site-packages (from transformers) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\ed\appdata\local\programs\python\python313\lib\site-packages (from transformers) (6.0.3)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\ed\appdata\local\programs\python\python313\lib\site-packages (from transformers) (2025.11.3)
# Requirement already satisfied: requests in c:\users\ed\appdata\local\programs\python\python313\lib\site-packages (from transformers) (2.32.4)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in c:\users\ed\appdata\local\programs\python\python313\lib\site-packages (from transformers) (0.22.1)
# Requirement already satisfied: safetensors>=0.4.3 in c:\users\ed\appdata\local\programs\python\python313\lib\site-packages (from transformers) (0.7.0)
# Requirement already satisfied: tqdm>=4.27 in c:\users\ed\appdata\local\programs\python\python313\lib\site-packages (from transformers) (4.67.1)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\ed\appdata\local\programs\python\python313\lib\site-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (2025.10.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\ed\appdata\local\programs\python\python313\lib\site-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (4.14.1)
# Requirement already satisfied: colorama in c:\users\ed\appdata\roaming\python\python313\site-packages (from tqdm>=4.27->transformers) (0.4.6)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\ed\appdata\local\programs\python\python313\lib\site-packages (from requests->transformers) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\ed\appdata\local\programs\python\python313\lib\site-packages (from requests->transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\ed\appdata\local\programs\python\python313\lib\site-packages (from requests->transformers) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\ed\appdata\local\programs\python\python313\lib\site-packages (from requests->transformers) (2025.8.3)

# %%
# Download local version
path = 'C:\\Users\\Ed\\Downloads\\qm8.csv'
import pandas as pd
df = pd.read_csv(path, nrows=2000)

# %%
import pandas as pd
import kagglehub
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
from transformers import AutoTokenizer, AutoModel, AutoConfig, BertConfig, BertModel
from torch.optim import AdamW

# ------------------------------------------------------
# 1. Toy corpus with urgency scores
# ------------------------------------------------------

# Download latest version
#path = kagglehub.dataset_download("shivanshuman/quantum-machine-8-aka-qm8")
#df = pd.read_csv(path, nrows=100)

# Extract the first column as a list of strings
toy_sentences = df.iloc[:, 0].astype(str).tolist()

# Extract the second column as a PyTorch float tensor
toy_urgency = torch.tensor(df.iloc[:, 1].values, dtype=torch.float32)

# ------------------------------------------------------
# 2. Dataset class
# ------------------------------------------------------

class UrgencyDataset(Dataset):
    def __init__(self, sentences, scores, tokenizer, max_len=32):
        self.sentences = sentences
        self.scores = scores
        self.tokenizer = tokenizer
        self.max_len = max_len

    def __len__(self):
        return len(self.sentences)

    def __getitem__(self, idx):
        text = self.sentences[idx]
        score = self.scores[idx]

        encoding = self.tokenizer(
            text,
            truncation=True,
            max_length=self.max_len,
            padding="max_length",
            return_tensors="pt"
        )

        return {
            "input_ids": encoding["input_ids"].squeeze(0),
            "attention_mask": encoding["attention_mask"].squeeze(0),
            "label": score
        }

# -------------------------
# 3) MLP head (configurable)
# -------------------------
class MLPHead(nn.Module):
    def __init__(self, input_dim, hidden_sizes, dropout=0.1, activation=nn.GELU):
        """
        input_dim: dimensionality of encoder pooled vector (e.g., 768)
        hidden_sizes: list of ints for successive hidden layers; final output -> 1
        dropout: dropout prob between layers
        activation: activation class (not instance), default GELU
        """
        super().__init__()
        layers = []
        prev = input_dim
        for h in hidden_sizes:
            layers.append(nn.Linear(prev, h))
            layers.append(activation())
            layers.append(nn.Dropout(dropout))
            prev = h
        # final linear to single logit
        layers.append(nn.Linear(prev, 1))
        self.net = nn.Sequential(*layers)

    def forward(self, x):
        # x: (B, input_dim)
        logits = self.net(x)          # (B,1)
        return logits.squeeze(-1)     # (B,)

# -------------------------
# 4) Full model with BERT + custom MLP head
# -------------------------
class TransformerUrgencyRegressor(nn.Module):
    """
    Transformer encoder + configurable MLP regression head.
    Args:
        model_name (str): pretrained Hugging Face model id (default: "distilbert-base-uncased").
        mlp_hidden_sizes (list[int] or None): hidden sizes for the MLP head; if None, defaults to [H*8, 512].
        mlp_dropout (float): dropout probability inside the head.
        use_mean_pooling (bool): if True, use attention-mask-weighted mean pooling of token embeddings;
        if False, use the token at position 0 (CLS) as the sentence rep.
    """
    def __init__(self,
                 model_name: str = "seyonec/ChemBERTa-zinc-base-v1",
                 mlp_hidden_sizes=None,
                 mlp_dropout: float = 0.1,
                 use_mean_pooling: bool = False):
        super().__init__()

        # load encoder
        self.encoder = AutoModel.from_pretrained(model_name)
        H = self.encoder.config.hidden_size

        # default head architecture if none specified
        if mlp_hidden_sizes is None:
            mlp_hidden_sizes = [H * 8, 512]

        # MLP head
        self.head = MLPHead(input_dim=H, hidden_sizes=mlp_hidden_sizes, dropout=mlp_dropout)

        # pooling choice flag (must be set here so forward can read it)
        self.use_mean_pooling = use_mean_pooling

        # Optional: freeze encoder for quick experiments
        # for p in self.encoder.parameters():
        #     p.requires_grad = False

    def forward(self, input_ids, attention_mask):
        """
        Args:
            input_ids: Tensor of shape (B, T)
            attention_mask: Tensor of shape (B, T) with 1 for real tokens, 0 for padding

        Returns:
            logit: Tensor of shape (B,) - one scalar prediction per input
        """
        outputs = self.encoder(input_ids=input_ids, attention_mask=attention_mask, return_dict=True)
        last_hidden = outputs.last_hidden_state   # (B, T, H)

        if self.use_mean_pooling:
            # mask: (B, T, 1)
            mask = attention_mask.unsqueeze(-1).type_as(last_hidden)
            summed = (last_hidden * mask).sum(dim=1)      # (B, H)
            counts = mask.sum(dim=1)                      # (B, 1)
            eps = 1e-9
            pooled = summed / counts.clamp(min=eps)      # (B, H)
            sentence_rep = pooled
        else:
            # CLS pooling: token at position 0
            sentence_rep = last_hidden[:, 0, :]          # (B, H)

        logit = self.head(sentence_rep)                 # (B,)
        return logit
    
    # Add Extra Encoder Depth
    def extend_encoder_layers_minimal(self, target_num_layers: int, reinit_new: bool = True, copy_with_noise: bool = True):
        """
        Extend encoder to target_num_layers. Return old_depth (number of layers before extension).
        If copy_with_noise=True we copy the last layer and add small noise to parameters (safer).
        """
        import copy, torch
        layer_list = self.encoder.encoder.layer
        old_depth = len(layer_list)
        if target_num_layers <= old_depth:
            return old_depth

        to_add = target_num_layers - old_depth
        last = layer_list[-1]
        for _ in range(to_add):
            new_layer = copy.deepcopy(last)
            if reinit_new:
                if copy_with_noise:
                    # copy weights and add tiny noise (safer than full random reinit)
                    for p_old, p_new in zip(last.parameters(), new_layer.parameters()):
                        p_new.data.copy_(p_old.data + 1e-3 * torch.randn_like(p_old.data))
                else:
                    # plain reinit (as before)
                    for p in new_layer.parameters():
                        if p.dim() > 1:
                            torch.nn.init.xavier_uniform_(p)
                        else:
                            torch.nn.init.zeros_(p)
            layer_list.append(new_layer)

        # update config
        if hasattr(self.encoder, "config"):
            self.encoder.config.num_hidden_layers = target_num_layers

        return old_depth


# -------------------------
# 5) Training setup
# -------------------------

base = "seyonec/ChemBERTa-zinc-base-v1"
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
tokenizer = AutoTokenizer.from_pretrained(base)

dataset = UrgencyDataset(toy_sentences, toy_urgency, tokenizer)
loader = DataLoader(dataset, batch_size=4, shuffle=True)

# instantiate model with a custom MLP: change the list to whatever you want
model = TransformerUrgencyRegressor(model_name=base,
                                    mlp_hidden_sizes=[768 * 8, 512],
                                    mlp_dropout=0.25).to(device)

old_depth = model.extend_encoder_layers_minimal(target_num_layers=16, reinit_new=True)



## Add width to transformer FFNs
old_encoder = AutoModel.from_pretrained(base)
old_sd = old_encoder.state_dict()

# make new config with wider FFN (keep hidden_size unchanged)
cfg = AutoConfig.from_pretrained(base)
cfg.intermediate_size = int(cfg.hidden_size * 8)   # e.g. 6x FFN (originally 4x)

# instantiate new encoder and copy matching tensors from pretrained
new_encoder = AutoModel.from_config(cfg)
new_sd = new_encoder.state_dict()
for k in new_sd.keys():
    if k in old_sd and old_sd[k].shape == new_sd[k].shape:
        new_sd[k] = old_sd[k].clone()
new_encoder.load_state_dict(new_sd)

# swap encoder into model
model.encoder = new_encoder.to(device)



## (optional but recommended) freeze old layers initially
for i, layer in enumerate(model.encoder.encoder.layer):
    if i < old_depth:
        for p in layer.parameters():
            p.requires_grad = False
# collect parameter groups
old_params = []
new_params = []
for i, layer in enumerate(model.encoder.encoder.layer):
    if i < old_depth:
        old_params += [p for p in layer.parameters() if p.requires_grad]
    else:
        new_params += list(layer.parameters())
head_params = list(model.head.parameters())



# minimal stable optimizer
optimizer = AdamW(
    [{"params": old_params, "lr": 1e-6},   # pretrained (or empty if frozen)
    {"params": new_params, "lr": 1e-5},   # newly added layers
    {"params": head_params, "lr": 5e-6}],
    weight_decay=0.01)

loss_fn = nn.L1Loss()


# -------------------------
# 6) Training loop
# -------------------------
epochs = 30
print("Training...\n")

# Create calibration params on the model if not present
if not hasattr(model, "cal_scale") or not hasattr(model, "cal_bias"):
    # create parameters and attach them to the model for ownership
    model.cal_scale = torch.nn.Parameter(torch.tensor(1.0, dtype=torch.float32, device=device))
    model.cal_bias  = torch.nn.Parameter(torch.tensor(0.0, dtype=torch.float32, device=device))
    # add them to the optimizer with a higher lr so calibration learns fast
    try:
        optimizer.add_param_group({'params': [model.cal_scale, model.cal_bias], 'lr': 1e-6})
    except Exception as e:
        # If optimizer doesn't support add_param_group for some reason, recreate it:
        print("Adding calibration params failed, please recreate optimizer with these params included.")
        raise

for epoch in range(epochs):
    total_loss = 0.0
    num_examples = 0
    model.train()

    for batch in loader:
        input_ids = batch["input_ids"].to(device)
        attention_mask = batch["attention_mask"].to(device)
        labels = batch["label"].to(device)

        optimizer.zero_grad()
        logits = model(input_ids=input_ids, attention_mask=attention_mask)  # (B,)
        # calibrated prediction: y_cal = a * y_raw + b
        y_cal = model.cal_scale * logits + model.cal_bias    
        loss = loss_fn(y_cal, labels)
        loss.backward()
        torch.nn.utils.clip_grad_norm_(model.parameters(), 1.0)
        optimizer.step()

        batch_size = input_ids.size(0)
        total_loss += loss.item() * batch_size
        num_examples += batch_size

        # Quick diagnostics
        # 1) label stats
        print("labels:", labels.min().item(), labels.mean().item(), labels.max().item())

        # 2) sample preds (on the current batch)
        model.eval()
        with torch.no_grad():
            sample_raw = model(input_ids[:4].to(device), attention_mask[:4].to(device))
            sample_cal = (model.cal_scale * sample_raw + model.cal_bias).cpu().numpy()
        print("sample calibrated preds:", sample_cal)

        # 3) grad sizes (after loss.backward())
        total_grad = 0.0
        for n, p in list(model.named_parameters()) + [("cal_scale", model.cal_scale), ("cal_bias", model.cal_bias)]:
            if isinstance(p, torch.nn.Parameter):
                g = p.grad
            else:
                # when tuple from add, skip
                g = None
            if g is not None:
                total_grad += g.abs().sum().item()
        print("total grad sum:", total_grad)
        model.train()

    avg_loss = total_loss / max(1, num_examples)
    print(f"Epoch {epoch+1}/{epochs} - Avg Loss: {avg_loss:.6f}")

# ------------------y------------------------------------
# 6. Test predictions
# ------------------------------------------------------

print("\nPredictions (calibrated):")
model.eval()
with torch.no_grad():
    for i, sentence in enumerate(toy_sentences):
        enc = tokenizer(sentence, return_tensors="pt", padding=True, truncation=True, max_length=32).to(device)
        raw = model(enc["input_ids"], enc["attention_mask"])       # raw model output
        calibrated = (model.cal_scale * raw + model.cal_bias).item()
        # If you normalized labels during training, unnormalize here:
        # calibrated = calibrated * y_std + y_mean
        print(f"Sentence: '{sentence}'")
        print(f"  True urgency: {toy_urgency[i].item():.4f}")
        print(f"  Predicted (calibrated): {calibrated:.4f}\n")
# Out:
# Training...
#
# labels: 0.23410168290138245 0.28229770064353943 0.35039928555488586
# sample calibrated preds: [0.1591782  0.13230367 0.14692199 0.11242146]
# total grad sum: 2022.971896605773
# labels: 0.1704525500535965 0.22045016288757324 0.25322139263153076
# sample calibrated preds: [0.19085936 0.23119701 0.24894701 0.19397825]
# total grad sum: 1861.7404646579635
# labels: 0.2040371149778366 0.23063598573207855 0.27156683802604675
# sample calibrated preds: [0.19583318 0.22058456 0.21700235 0.26021078]
# total grad sum: 2311.372445313179
# labels: 0.1844605952501297 0.23399211466312408 0.2682938575744629
# sample calibrated preds: [0.29037276 0.28148806 0.30104336 0.24662109]
# total grad sum: 2025.7975925417413
# labels: 0.2112559974193573 0.25173819065093994 0.26671990752220154
# sample calibrated preds: [0.27369967 0.28028083 0.2491081  0.28550878]
# total grad sum: 2151.659319096685
# labels: 0.1477704793214798 0.2211461365222931 0.2660871744155884
# sample calibrated preds: [0.2944406  0.27330118 0.23970631 0.2788511 ]
# total grad sum: 2267.5464168499093
# labels: 0.1622576117515564 0.24822013080120087 0.2961139678955078
# sample calibrated preds: [0.27400592 0.2606593  0.28363234 0.26095566]
# total grad sum: 1944.578938359186
# labels: 0.1597280502319336 0.2301342785358429 0.27125439047813416
# sample calibrated preds: [0.25161457 0.21266238 0.2621868  0.27580553]
# total grad sum: 2211.828284795137
# labels: 0.16347476840019226 0.21753939986228943 0.27356430888175964
# sample calibrated preds: [0.26148626 0.2739285  0.21758091 0.25167012]
# total grad sum: 2203.578069407534
# labels: 0.1756429374217987 0.21459835767745972 0.2560420036315918
# sample calibrated preds: [0.14564481 0.26127484 0.25765413 0.20717804]
# total grad sum: 2643.8901176252793
# labels: 0.19766728579998016 0.2468308061361313 0.3120269179344177
# sample calibrated preds: [0.26120743 0.19726264 0.24717808 0.19309312]
# total grad sum: 2109.8707475561114
# labels: 0.21718069911003113 0.2575366199016571 0.31683284044265747
# sample calibrated preds: [0.14562799 0.28724644 0.25652486 0.24335523]
# total grad sum: 2135.269965748098
# labels: 0.16054397821426392 0.20479847490787506 0.2273416817188263
# sample calibrated preds: [0.17363417 0.23033048 0.16655679 0.2619305 ]
# total grad sum: 2404.566358962311
# labels: 0.24429738521575928 0.2638282775878906 0.2775311768054962
# sample calibrated preds: [0.26215398 0.25023845 0.26568988 0.2566658 ]
# total grad sum: 2057.70916068359
# labels: 0.12221751362085342 0.1773318499326706 0.24740512669086456
# sample calibrated preds: [0.2613657  0.26781243 0.1958929  0.2616995 ]
# total grad sum: 2191.2967047736684
# labels: 0.15715232491493225 0.22177298367023468 0.29577964544296265
# sample calibrated preds: [0.23614044 0.22652818 0.24786066 0.23341468]
# total grad sum: 2032.9567810261278
# labels: 0.19178710877895355 0.23933619260787964 0.2677646577358246
# sample calibrated preds: [0.200255   0.20106238 0.2637304  0.23258343]
# total grad sum: 2261.82275303444
# labels: 0.14303654432296753 0.19845537841320038 0.25600260496139526
# sample calibrated preds: [0.2474086  0.2185085  0.22951616 0.24848859]
# total grad sum: 1977.796499370891
# labels: 0.16980606317520142 0.22210592031478882 0.2694971263408661
# sample calibrated preds: [0.2269215  0.18427026 0.2289797  0.23840778]
# total grad sum: 2102.697264991224
# labels: 0.22954197227954865 0.2617962062358856 0.2954047620296478
# sample calibrated preds: [0.22004244 0.22118694 0.17131658 0.23919512]
# total grad sum: 2127.059724385507
# labels: 0.1512475460767746 0.23163673281669617 0.2651286721229553
# sample calibrated preds: [0.18751231 0.24595167 0.21831805 0.17104593]
# total grad sum: 1949.3570836412573
# labels: 0.1659671515226364 0.23216231167316437 0.2802474796772003
# sample calibrated preds: [0.19912978 0.22527802 0.24439149 0.25656492]
# total grad sum: 2100.013668952339
# labels: 0.1711125671863556 0.21556229889392853 0.26999831199645996
# sample calibrated preds: [0.23223728 0.22816043 0.26582664 0.27993518]
# total grad sum: 2248.896175387862
# labels: 0.21408163011074066 0.23446404933929443 0.2581472098827362
# sample calibrated preds: [0.286894   0.24680239 0.2920266  0.26146027]
# total grad sum: 2306.432675708623
# labels: 0.17145772278308868 0.2105795294046402 0.22889310121536255
# sample calibrated preds: [0.2844837  0.26887676 0.26069382 0.23211665]
# total grad sum: 1920.6669964872858
# labels: 0.1608293056488037 0.2179795354604721 0.2622334063053131
# sample calibrated preds: [0.2802018  0.28308174 0.28159305 0.2975134 ]
# total grad sum: 1938.0381228663412
# labels: 0.13893386721611023 0.1933496594429016 0.24897469580173492
# sample calibrated preds: [0.2575349  0.28158796 0.29262125 0.20693122]
# total grad sum: 2368.188637203847
# labels: 0.16144728660583496 0.20430737733840942 0.22590404748916626
# sample calibrated preds: [0.26597923 0.26330116 0.2836203  0.24424486]
# total grad sum: 1849.1171290661923
# labels: 0.24456678330898285 0.27971580624580383 0.29882335662841797
# sample calibrated preds: [0.2609348  0.2502025  0.25451213 0.23990838]
# total grad sum: 2108.8477898688607
# labels: 0.18131321668624878 0.23837362229824066 0.2867831885814667
# sample calibrated preds: [0.19578233 0.24927267 0.17658196 0.26822528]
# total grad sum: 2394.657566001013
# labels: 0.1629491150379181 0.22192658483982086 0.2578282058238983
# sample calibrated preds: [0.21920948 0.23938403 0.19664454 0.25638592]
# total grad sum: 2115.4130682334194
# labels: 0.15695762634277344 0.21771876513957977 0.2712354063987732
# sample calibrated preds: [0.19675261 0.21333876 0.24155843 0.17816529]
# total grad sum: 2306.7143744915466
# labels: 0.17030861973762512 0.1964782029390335 0.24143296480178833
# sample calibrated preds: [0.12806313 0.1965637  0.16530322 0.09726356]
# total grad sum: 2442.3556924763143
# labels: 0.21822470426559448 0.23732545971870422 0.26555371284484863
# sample calibrated preds: [0.24416655 0.1715854  0.18950959 0.21583587]
# total grad sum: 2039.269462480754
# labels: 0.15807613730430603 0.25425201654434204 0.334666907787323
# sample calibrated preds: [0.19274162 0.23616916 0.1711991  0.24575108]
# total grad sum: 2062.109317616908
# labels: 0.16264140605926514 0.23800444602966309 0.26728710532188416
# sample calibrated preds: [0.23359953 0.24470325 0.18742324 0.24194017]
# total grad sum: 2131.19436373992
# labels: 0.1689995527267456 0.21535788476467133 0.27462202310562134
# sample calibrated preds: [0.23569515 0.25099283 0.22003096 0.20571844]
# total grad sum: 2133.3865821059067
# labels: 0.2458679974079132 0.2613082528114319 0.2708341181278229
# sample calibrated preds: [0.29246524 0.28335086 0.20360935 0.27506876]
# total grad sum: 2353.0587964568863
# labels: 0.2032179981470108 0.23732483386993408 0.267238974571228
# sample calibrated preds: [0.26014093 0.13394804 0.28065953 0.24775104]
# total grad sum: 2334.2874034187007
# labels: 0.23005996644496918 0.2467908263206482 0.26656121015548706
# sample calibrated preds: [0.24908438 0.28288245 0.2914149  0.3048839 ]
# total grad sum: 2334.325317161559
# labels: 0.18233701586723328 0.21595396101474762 0.23636287450790405
# sample calibrated preds: [0.2980579  0.28631017 0.27098647 0.27575767]
# total grad sum: 1935.8013243417513
# labels: 0.26219964027404785 0.28542470932006836 0.32961776852607727
# sample calibrated preds: [0.29511318 0.31055576 0.30198234 0.2862225 ]
# total grad sum: 1915.3778209404427
# labels: 0.15466849505901337 0.21398460865020752 0.27245035767555237
# sample calibrated preds: [0.21506384 0.30339348 0.30391738 0.24681835]
# total grad sum: 2655.6568097409363
# labels: 0.21299980580806732 0.24706698954105377 0.2865373492240906
# sample calibrated preds: [0.2902121  0.30224288 0.27230603 0.27986708]
# total grad sum: 1836.8563937749723
# labels: 0.10717520862817764 0.17678558826446533 0.24043777585029602
# sample calibrated preds: [0.24992749 0.260425   0.21612734 0.2579098 ]
# total grad sum: 2061.452162006166
# labels: 0.14992108941078186 0.2255978286266327 0.31546762585639954
# sample calibrated preds: [0.26986998 0.16645755 0.24776104 0.18018991]
# total grad sum: 2390.5601695491705
# labels: 0.1935555338859558 0.2335675060749054 0.2647530436515808
# sample calibrated preds: [0.25458345 0.1644547  0.19602722 0.2348172 ]
# total grad sum: 2217.2475991302194
# labels: 0.16272583603858948 0.2139141857624054 0.27093109488487244
# sample calibrated preds: [0.18259428 0.19248138 0.23520006 0.11246315]
# total grad sum: 2113.8902257714185
# labels: 0.11887288093566895 0.19757214188575745 0.2609786093235016
# sample calibrated preds: [0.17368752 0.12298635 0.2675964  0.20423149]
# total grad sum: 2349.671079551403
# labels: 0.10883046686649323 0.18707604706287384 0.2509036064147949
# sample calibrated preds: [0.14550129 0.199469   0.13839065 0.14092487]
# total grad sum: 2354.289981147468
# labels: 0.24940398335456848 0.2592334747314453 0.26952260732650757
# sample calibrated preds: [0.18833768 0.18066233 0.21252671 0.1812839 ]
# total grad sum: 1905.4636224564028
# labels: 0.14557409286499023 0.24719516932964325 0.32815229892730713
# sample calibrated preds: [0.15806343 0.14458342 0.1607834  0.14480351]
# total grad sum: 2181.626095505151
# labels: 0.15561459958553314 0.22172333300113678 0.2560120224952698
# sample calibrated preds: [0.20414776 0.1762623  0.18321529 0.18231237]
# total grad sum: 2179.495521294618
# labels: 0.21701690554618835 0.2513419985771179 0.2718741297721863
# sample calibrated preds: [0.16158448 0.2444739  0.20834346 0.18412551]
# total grad sum: 2022.4330459172195
# labels: 0.21779635548591614 0.24128270149230957 0.272550493478775
# sample calibrated preds: [0.23184058 0.23057918 0.14431135 0.25140283]
# total grad sum: 2127.926520050418
# labels: 0.13700717687606812 0.19675514101982117 0.27101361751556396
# sample calibrated preds: [0.2265321  0.24429871 0.2590137  0.20478423]
# total grad sum: 1965.8013563581455
# labels: 0.24448229372501373 0.27522099018096924 0.3298591673374176
# sample calibrated preds: [0.24865834 0.24316521 0.26345524 0.2685595 ]
# total grad sum: 2003.3804446381073
# labels: 0.1407749354839325 0.2320438027381897 0.2809208631515503
# sample calibrated preds: [0.2257745  0.15504888 0.2532459  0.26527202]
# total grad sum: 2130.726598991598
# labels: 0.21166525781154633 0.2511151432991028 0.27076447010040283
# sample calibrated preds: [0.28656065 0.27230462 0.24753544 0.27012396]
# total grad sum: 1892.8382180105518
# labels: 0.16340233385562897 0.21474012732505798 0.26067590713500977
# sample calibrated preds: [0.17326817 0.22401598 0.23975854 0.22487873]
# total grad sum: 2018.621194047871
# labels: 0.20475177466869354 0.2729618549346924 0.32394829392433167
# sample calibrated preds: [0.26182866 0.28555208 0.2251763  0.2754737 ]
# total grad sum: 2042.38607376033
# labels: 0.15494458377361298 0.20955047011375427 0.2666906416416168
# sample calibrated preds: [0.21293823 0.26422194 0.22880298 0.19781005]
# total grad sum: 1931.8375518582332
# labels: 0.17036019265651703 0.23723110556602478 0.271881639957428
# sample calibrated preds: [0.2539793 0.2526038 0.2306165 0.2399772]
# total grad sum: 1742.5559927405898
# labels: 0.16704115271568298 0.20358115434646606 0.2598922550678253
# sample calibrated preds: [0.23056568 0.20442152 0.10052524 0.18528254]
# total grad sum: 1980.2489912924389
# labels: 0.16065746545791626 0.22842225432395935 0.2625681459903717
# sample calibrated preds: [0.18042386 0.2000507  0.15184368 0.2189852 ]
# total grad sum: 2292.2871339174785
# labels: 0.14772695302963257 0.22730186581611633 0.2691940665245056
# sample calibrated preds: [0.19506285 0.13189451 0.08661076 0.20379053]
# total grad sum: 1904.9707779048617
# labels: 0.20088431239128113 0.2387973964214325 0.2654608190059662
# sample calibrated preds: [0.20349084 0.1771901  0.17569536 0.15645424]
# total grad sum: 1936.6773737615135
# labels: 0.18817740678787231 0.24987566471099854 0.27245715260505676
# sample calibrated preds: [0.1358335  0.21258861 0.1902893  0.18780732]
# total grad sum: 1812.4475976896863
# labels: 0.20457786321640015 0.22651046514511108 0.2568179666996002
# sample calibrated preds: [0.16486362 0.15067218 0.21321644 0.18762116]
# total grad sum: 1871.0685906828146
# labels: 0.15671436488628387 0.19607751071453094 0.24019953608512878
# sample calibrated preds: [0.20816113 0.18096204 0.22525181 0.20797022]
# total grad sum: 2017.502014127504
# labels: 0.21609416604042053 0.23300068080425262 0.25613656640052795
# sample calibrated preds: [0.20428857 0.21740036 0.22555688 0.1519311 ]
# total grad sum: 1963.2689888747416
# labels: 0.23526780307292938 0.26040735840797424 0.2893519103527069
# sample calibrated preds: [0.2619032  0.20234838 0.25939566 0.2709741 ]
# total grad sum: 1770.7164557070478
# labels: 0.17093053460121155 0.24896366894245148 0.2895164489746094
# sample calibrated preds: [0.26460478 0.27910322 0.28493536 0.28722963]
# total grad sum: 2060.7591351343763
# labels: 0.11825817078351974 0.1942034512758255 0.25642475485801697
# sample calibrated preds: [0.26920786 0.27114367 0.29069784 0.22007072]
# total grad sum: 2008.0838984535612
# labels: 0.1708473563194275 0.24115639925003052 0.27411729097366333
# sample calibrated preds: [0.2860649  0.28575417 0.28656587 0.28889012]
# total grad sum: 1791.3668435312443
# labels: 0.1918843686580658 0.24251726269721985 0.27948054671287537
# sample calibrated preds: [0.27454624 0.16133578 0.3045614  0.28317887]
# total grad sum: 1837.6488098378686
# labels: 0.16053533554077148 0.2159070074558258 0.26800426840782166
# sample calibrated preds: [0.29597783 0.23429057 0.23013543 0.21788901]
# total grad sum: 1939.3760959169535
# labels: 0.16331855952739716 0.21554042398929596 0.23783451318740845
# sample calibrated preds: [0.25310653 0.2658239  0.2437185  0.23106858]
# total grad sum: 1874.129806348103
# labels: 0.178823783993721 0.21091358363628387 0.23252440989017487
# sample calibrated preds: [0.27669522 0.18195252 0.2533922  0.19170067]
# total grad sum: 2001.3603098986555
# labels: 0.23486678302288055 0.2582654356956482 0.28139039874076843
# sample calibrated preds: [0.24670343 0.2592456  0.18336636 0.26373994]
# total grad sum: 2086.225325004192
# labels: 0.20774215459823608 0.2538932263851166 0.2835773229598999
# sample calibrated preds: [0.25058046 0.25359553 0.19349878 0.24606368]
# total grad sum: 2022.908885383103
# labels: 0.16239899396896362 0.21586810052394867 0.26388442516326904
# sample calibrated preds: [0.1562593  0.21514358 0.17274587 0.18024297]
# total grad sum: 2007.6321801911486
# labels: 0.16005876660346985 0.22309598326683044 0.2696947157382965
# sample calibrated preds: [0.1886752  0.16612574 0.21253128 0.21627733]
# total grad sum: 1859.103628300038
# labels: 0.1668202430009842 0.2264944314956665 0.30892714858055115
# sample calibrated preds: [0.15518184 0.19052729 0.15401371 0.21704556]
# total grad sum: 2147.668620388622
# labels: 0.2624853849411011 0.2675274610519409 0.27254560589790344
# sample calibrated preds: [0.22017936 0.22111183 0.23321769 0.23114087]
# total grad sum: 1900.4159276286682
# labels: 0.16936707496643066 0.21902906894683838 0.2440548837184906
# sample calibrated preds: [0.20227098 0.15217851 0.21491368 0.19429179]
# total grad sum: 1974.655900369135
# labels: 0.20964689552783966 0.2284146100282669 0.26360785961151123
# sample calibrated preds: [0.22778898 0.19151762 0.23971309 0.19800419]
# total grad sum: 1910.5835527744111
# labels: 0.18168702721595764 0.2196124792098999 0.2711714506149292
# sample calibrated preds: [0.21554556 0.21711244 0.16848396 0.25695243]
# total grad sum: 2040.2564024731487
# labels: 0.20691131055355072 0.22394931316375732 0.2467355579137802
# sample calibrated preds: [0.23097387 0.27813855 0.2558424  0.21838361]
# total grad sum: 2141.5926033747305
# labels: 0.16469591856002808 0.2153984159231186 0.27594640851020813
# sample calibrated preds: [0.26724368 0.2705427  0.20831239 0.24663197]
# total grad sum: 1906.7552140491825
# labels: 0.14308106899261475 0.18093983829021454 0.2502933740615845
# sample calibrated preds: [0.27212313 0.2220879  0.17901996 0.25625017]
# total grad sum: 2018.4664712685108
# labels: 0.16107626259326935 0.21953420341014862 0.2857743203639984
# sample calibrated preds: [0.23592289 0.21370848 0.25607812 0.23219714]
# total grad sum: 1892.8962672642283
# labels: 0.20750181376934052 0.22024261951446533 0.2557310461997986
# sample calibrated preds: [0.26560465 0.21132362 0.22807515 0.22717512]
# total grad sum: 2186.8668518166423
# labels: 0.16266492009162903 0.22255480289459229 0.2684381902217865
# sample calibrated preds: [0.19443686 0.22962664 0.18457395 0.25844258]
# total grad sum: 2097.197553385165
# labels: 0.10702860355377197 0.21055035293102264 0.30282366275787354
# sample calibrated preds: [0.22912897 0.19191721 0.20241226 0.22093326]
# total grad sum: 2166.4136066882515
# labels: 0.17137427628040314 0.24122439324855804 0.3109375536441803
# sample calibrated preds: [0.23647244 0.21490686 0.21080802 0.20117496]
# total grad sum: 1821.805502162369
# labels: 0.2145308405160904 0.24995435774326324 0.2742067575454712
# sample calibrated preds: [0.21735427 0.23435026 0.17995726 0.22011134]
# total grad sum: 1895.973178018936
# labels: 0.1294361650943756 0.18950431048870087 0.2674425542354584
# sample calibrated preds: [0.2432431  0.18325649 0.21283819 0.1992562 ]
# total grad sum: 1959.6973597963147
# labels: 0.15879018604755402 0.21035507321357727 0.25996312499046326
# sample calibrated preds: [0.23320383 0.19457878 0.22591783 0.20979097]
# total grad sum: 1739.2659751246115
# labels: 0.21162539720535278 0.24180863797664642 0.264024555683136
# sample calibrated preds: [0.18793164 0.21959454 0.22717248 0.2600774 ]
# total grad sum: 2178.4781165633026
# labels: 0.16763688623905182 0.21756523847579956 0.2674790918827057
# sample calibrated preds: [0.17081577 0.19275382 0.22003537 0.22710437]
# total grad sum: 2078.7430137106617
# labels: 0.16136297583580017 0.18816760182380676 0.25429484248161316
# sample calibrated preds: [0.1613006  0.22584009 0.17641139 0.18532248]
# total grad sum: 2010.2310559932985
# labels: 0.23139822483062744 0.2568601071834564 0.2774755656719208
# sample calibrated preds: [0.2197624  0.22568317 0.2272611  0.20983112]
# total grad sum: 1828.8939643793988
# labels: 0.1348569691181183 0.19201387465000153 0.24373376369476318
# sample calibrated preds: [0.2360622  0.18832806 0.20070638 0.19349058]
# total grad sum: 1965.613272363204
# labels: 0.16177307069301605 0.23721450567245483 0.3316079080104828
# sample calibrated preds: [0.22792163 0.21057296 0.19113834 0.21151671]
# total grad sum: 1877.1594261347977
# labels: 0.16302360594272614 0.22209110856056213 0.2594137191772461
# sample calibrated preds: [0.22502895 0.18319532 0.2237823  0.12253965]
# total grad sum: 1973.464658370017
# labels: 0.1416819989681244 0.19607260823249817 0.2292778044939041
# sample calibrated preds: [0.2030509  0.19761306 0.17666161 0.17553394]
# total grad sum: 1878.902361688948
# labels: 0.16446490585803986 0.228112131357193 0.2652208209037781
# sample calibrated preds: [0.1915133  0.24014938 0.2293707  0.23523785]
# total grad sum: 1798.9547248766344
# labels: 0.18635189533233643 0.2202771008014679 0.25157222151756287
# sample calibrated preds: [0.19058196 0.22803895 0.25183976 0.1927521 ]
# total grad sum: 1936.9247740436017
# labels: 0.15567085146903992 0.18832510709762573 0.2595042586326599
# sample calibrated preds: [0.19988784 0.18713859 0.22542007 0.2124159 ]
# total grad sum: 2119.7981865336856
# labels: 0.08734208345413208 0.1830562949180603 0.22369484603405
# sample calibrated preds: [0.17162149 0.2226297  0.20159903 0.20950137]
# total grad sum: 2303.0613125547934
# labels: 0.1642557829618454 0.1978485882282257 0.23015360534191132
# sample calibrated preds: [0.21750277 0.17888309 0.18817176 0.20178255]
# total grad sum: 1964.9657425035634
# labels: 0.16217347979545593 0.20876500010490417 0.257081538438797
# sample calibrated preds: [0.2140572  0.19412942 0.15250526 0.19887465]
# total grad sum: 1930.6017962158592
# labels: 0.1945856660604477 0.24594415724277496 0.2749921381473541
# sample calibrated preds: [0.24260856 0.2780749  0.19145265 0.21470332]
# total grad sum: 1950.7851833039954
# labels: 0.1480582058429718 0.2293417602777481 0.3147633671760559
# sample calibrated preds: [0.20138082 0.17707895 0.26336548 0.21190706]
# total grad sum: 1991.6338277478915
# labels: 0.16300171613693237 0.20590996742248535 0.26105618476867676
# sample calibrated preds: [0.24956724 0.21964902 0.26519096 0.26378736]
# total grad sum: 1964.7128051009809
# labels: 0.24068915843963623 0.26707661151885986 0.31417882442474365
# sample calibrated preds: [0.21353787 0.2832482  0.28127885 0.25782317]
# total grad sum: 2227.4290225131917
# labels: 0.2570289373397827 0.2858305871486664 0.3247937560081482
# sample calibrated preds: [0.27097887 0.29074544 0.28319645 0.22828373]
# total grad sum: 1846.2642397002019
# labels: 0.21327798068523407 0.25701969861984253 0.28596553206443787
# sample calibrated preds: [0.28647277 0.2726365  0.23630765 0.226156  ]
# total grad sum: 1832.1459099390609
# labels: 0.17206887900829315 0.23679755628108978 0.28667131066322327
# sample calibrated preds: [0.22183244 0.27602628 0.28930208 0.2742823 ]
# total grad sum: 2005.901506475824
# labels: 0.21444188058376312 0.23739808797836304 0.2638147175312042
# sample calibrated preds: [0.24323955 0.24407968 0.2606094  0.29678586]
# total grad sum: 1872.2774808172398
# labels: 0.16184209287166595 0.22225691378116608 0.270240843296051
# sample calibrated preds: [0.23291013 0.23804718 0.24346343 0.25412893]
# total grad sum: 2210.3318366229482
# labels: 0.15399070084095 0.2203434854745865 0.2863786220550537
# sample calibrated preds: [0.27815956 0.25047493 0.23917899 0.21866848]
# total grad sum: 1952.6814696013146
# labels: 0.1311521977186203 0.21845129132270813 0.26421523094177246
# sample calibrated preds: [0.2473715  0.21733744 0.196354   0.27816898]
# total grad sum: 1929.4665767506808
# labels: 0.19712120294570923 0.26161259412765503 0.3143119513988495
# sample calibrated preds: [0.24156313 0.26013786 0.23092687 0.24048714]
# total grad sum: 1865.9550954283245
# labels: 0.14375972747802734 0.20401442050933838 0.27254781126976013
# sample calibrated preds: [0.19995397 0.19526759 0.25892344 0.26491264]
# total grad sum: 2125.026766206541
# labels: 0.21665506064891815 0.251986563205719 0.2692342698574066
# sample calibrated preds: [0.25598723 0.17399292 0.25441328 0.2545779 ]
# total grad sum: 1871.1937302725066
# labels: 0.16054600477218628 0.21763528883457184 0.260163277387619
# sample calibrated preds: [0.09252555 0.18913917 0.27636182 0.21344553]
# total grad sum: 2379.144846551233
# labels: 0.22255860269069672 0.2729809284210205 0.3306899666786194
# sample calibrated preds: [0.2501012  0.24534635 0.28780234 0.25746807]
# total grad sum: 1870.6943147244115
# labels: 0.15221604704856873 0.22041857242584229 0.32341983914375305
# sample calibrated preds: [0.18360159 0.2907838  0.17398779 0.19991863]
# total grad sum: 2234.3620364036574
# labels: 0.15441389381885529 0.20179028809070587 0.24285386502742767
# sample calibrated preds: [0.2287331  0.30898973 0.24191123 0.231594  ]
# total grad sum: 1876.2470972224592
# labels: 0.19766391813755035 0.2330915480852127 0.26148563623428345
# sample calibrated preds: [0.26982516 0.21269481 0.2613509  0.22774297]
# total grad sum: 1866.5477750155972
# labels: 0.16144506633281708 0.20446790754795074 0.25383830070495605
# sample calibrated preds: [0.18922924 0.27075678 0.17605974 0.21959482]
# total grad sum: 1826.5940778169165
# labels: 0.2051980048418045 0.25076422095298767 0.2868308126926422
# sample calibrated preds: [0.24125403 0.25938886 0.2328237  0.13989653]
# total grad sum: 1886.8205145512488
# labels: 0.15858228504657745 0.19956836104393005 0.25476518273353577
# sample calibrated preds: [0.16246225 0.26170358 0.19924207 0.17664418]
# total grad sum: 1954.5991747723563
# labels: 0.16390149295330048 0.2598019242286682 0.3293915390968323
# sample calibrated preds: [0.22999933 0.22108513 0.15234025 0.21153586]
# total grad sum: 1830.5979725059153
# labels: 0.2131030410528183 0.25142404437065125 0.3194149434566498
# sample calibrated preds: [0.18807197 0.05766669 0.18123971 0.13307896]
# total grad sum: 1986.6625644123064
# labels: 0.16226622462272644 0.2231018990278244 0.26798203587532043
# sample calibrated preds: [0.22220352 0.17760961 0.10732004 0.18417543]
# total grad sum: 1966.8399186004413
# labels: 0.1708391010761261 0.24470055103302002 0.2787644565105438
# sample calibrated preds: [0.1143173  0.17382061 0.2364791  0.17084599]
# total grad sum: 1989.1361936098826
# labels: 0.1661224514245987 0.24286428093910217 0.3220742642879486
# sample calibrated preds: [0.15505297 0.25524893 0.0680442  0.1271926 ]
# total grad sum: 1899.343850413537
# labels: 0.1615881621837616 0.2019447684288025 0.31790444254875183
# sample calibrated preds: [0.20894407 0.18765014 0.23670183 0.12648559]
# total grad sum: 2129.5003132382303
# labels: 0.20914721488952637 0.24472247064113617 0.26292684674263
# sample calibrated preds: [0.18453544 0.22363368 0.24864686 0.211669  ]
# total grad sum: 2005.6301599915398
# labels: 0.14528271555900574 0.22012114524841309 0.2690029442310333
# sample calibrated preds: [0.21511598 0.20358482 0.24394144 0.26894173]
# total grad sum: 2014.5492653005872
# labels: 0.18631309270858765 0.20903080701828003 0.2515125572681427
# sample calibrated preds: [0.21811987 0.26221392 0.23958038 0.21762012]
# total grad sum: 2019.6245116443179
# labels: 0.23557917773723602 0.2514927089214325 0.2687026560306549
# sample calibrated preds: [0.2612031  0.20500885 0.2088784  0.2532068 ]
# total grad sum: 1748.3595856867328
# labels: 0.16889560222625732 0.22089806199073792 0.2656828463077545
# sample calibrated preds: [0.24115962 0.25680432 0.24154104 0.22631225]
# total grad sum: 1826.0482385883238
# labels: 0.16104626655578613 0.2254103720188141 0.314018189907074
# sample calibrated preds: [0.20436354 0.24775419 0.26203355 0.23869179]
# total grad sum: 1896.370626335669
# labels: 0.16152851283550262 0.19010011851787567 0.22478099167346954
# sample calibrated preds: [0.22485137 0.17070216 0.18890814 0.22805776]
# total grad sum: 1966.1797075133404
# labels: 0.16112427413463593 0.23372992873191833 0.2660044729709625
# sample calibrated preds: [0.21117955 0.20570248 0.25590843 0.25554138]
# total grad sum: 1897.243972721862
# labels: 0.15391354262828827 0.2112378180027008 0.25069501996040344
# sample calibrated preds: [0.24189897 0.21225074 0.17505763 0.24192956]
# total grad sum: 2037.9924600202376
# labels: 0.1621469259262085 0.18523108959197998 0.20895792543888092
# sample calibrated preds: [0.19064233 0.21535937 0.2574673  0.17206731]
# total grad sum: 1995.9655022972001
# labels: 0.16683316230773926 0.2046535760164261 0.23454271256923676
# sample calibrated preds: [0.2184233  0.19763035 0.21742658 0.22330056]
# total grad sum: 1827.4990892291898
# labels: 0.21300150454044342 0.2458263784646988 0.28594616055488586
# sample calibrated preds: [0.285698   0.25525334 0.25140804 0.21362494]
# total grad sum: 1751.5955815374389
# labels: 0.15860648453235626 0.1900549829006195 0.21960562467575073
# sample calibrated preds: [0.2820482  0.23314618 0.24831222 0.25983134]
# total grad sum: 1799.7761579491912
# labels: 0.23667140305042267 0.25860047340393066 0.27224043011665344
# sample calibrated preds: [0.27204597 0.2833431  0.24702802 0.2636171 ]
# total grad sum: 1814.258771858607
# labels: 0.21674415469169617 0.26184046268463135 0.3415689170360565
# sample calibrated preds: [0.2551254  0.2500277  0.2760448  0.28028187]
# total grad sum: 1971.3772223682618
# labels: 0.16713476181030273 0.2133498638868332 0.246811643242836
# sample calibrated preds: [0.22174704 0.24251033 0.24509059 0.27366826]
# total grad sum: 1973.655928826879
# labels: 0.16015009582042694 0.2157096415758133 0.244303360581398
# sample calibrated preds: [0.24651171 0.27046797 0.24678586 0.25491595]
# total grad sum: 1912.448427874197
# labels: 0.16114990413188934 0.23089241981506348 0.27740219235420227
# sample calibrated preds: [0.29126617 0.2914443  0.24012272 0.23630385]
# total grad sum: 1709.0459704959621
# labels: 0.15512867271900177 0.2384532392024994 0.2704590857028961
# sample calibrated preds: [0.26038176 0.29600704 0.29611906 0.29663098]
# total grad sum: 1798.340700553436
# labels: 0.12051545083522797 0.17942854762077332 0.26318514347076416
# sample calibrated preds: [0.29773727 0.28062755 0.2891102  0.20860733]
# total grad sum: 1769.6308317392404
# labels: 0.2501341700553894 0.2782505452632904 0.3429182767868042
# sample calibrated preds: [0.28165692 0.29258433 0.27711466 0.27568558]
# total grad sum: 1903.5992305501698
# labels: 0.1637907326221466 0.22504745423793793 0.2730526030063629
# sample calibrated preds: [0.25583756 0.27581105 0.2546259  0.25614068]
# total grad sum: 1935.1432595103327
# labels: 0.1960909515619278 0.23969021439552307 0.25953179597854614
# sample calibrated preds: [0.2654246  0.27766904 0.2610852  0.28197336]
# total grad sum: 1676.8539358396158
# labels: 0.12172570079565048 0.18286654353141785 0.22085729241371155
# sample calibrated preds: [0.23031971 0.27063474 0.24967185 0.16904888]
# total grad sum: 1755.0782184048371
# labels: 0.216465026140213 0.2405053973197937 0.26709216833114624
# sample calibrated preds: [0.25069308 0.23316137 0.21432555 0.25073975]
# total grad sum: 1638.453899076621
# labels: 0.20168012380599976 0.23592311143875122 0.26916664838790894
# sample calibrated preds: [0.23748288 0.20351703 0.2008247  0.23881502]
# total grad sum: 1653.4976003482413
# labels: 0.14264418184757233 0.18538565933704376 0.222578763961792
# sample calibrated preds: [0.20167425 0.14988501 0.22277342 0.19344808]
# total grad sum: 1804.2517356740004
# labels: 0.2140263468027115 0.24267637729644775 0.27368298172950745
# sample calibrated preds: [0.22992024 0.19219229 0.20125209 0.23210098]
# total grad sum: 1896.9672135195588
# labels: 0.16103796660900116 0.22824795544147491 0.27627015113830566
# sample calibrated preds: [0.16485564 0.23339829 0.18591696 0.19823848]
# total grad sum: 1819.8336513935828
# labels: 0.1553201824426651 0.2115446925163269 0.2706739008426666
# sample calibrated preds: [0.18066417 0.1841442  0.22425835 0.22637604]
# total grad sum: 1866.6943717042955
# labels: 0.21419091522693634 0.2411538064479828 0.29425886273384094
# sample calibrated preds: [0.21254407 0.20289661 0.23146462 0.22123286]
# total grad sum: 1792.5049470766398
# labels: 0.21683776378631592 0.24330440163612366 0.2805074453353882
# sample calibrated preds: [0.20778824 0.23957886 0.2379828  0.235167  ]
# total grad sum: 1883.8853077723852
# labels: 0.16263258457183838 0.2026137411594391 0.2972326874732971
# sample calibrated preds: [0.24040209 0.219794   0.2050128  0.21419941]
# total grad sum: 1719.9684767569624
# labels: 0.16128775477409363 0.231075257062912 0.2945857048034668
# sample calibrated preds: [0.22081722 0.2418992  0.21601811 0.18934225]
# total grad sum: 1937.4637327913347
# labels: 0.1326497197151184 0.17984865605831146 0.26108020544052124
# sample calibrated preds: [0.16025858 0.22854325 0.18961199 0.20542444]
# total grad sum: 1823.0169351001077
# labels: 0.25013911724090576 0.26435115933418274 0.27224406599998474
# sample calibrated preds: [0.22736439 0.2321107  0.20294617 0.19565763]
# total grad sum: 1644.8882525028466
# labels: 0.21550321578979492 0.23332974314689636 0.2796110510826111
# sample calibrated preds: [0.21252082 0.19952452 0.22029221 0.19424888]
# total grad sum: 1894.9439172066366
# labels: 0.16380101442337036 0.21825477480888367 0.2785476744174957
# sample calibrated preds: [0.2122888  0.20215121 0.22409202 0.22655573]
# total grad sum: 1763.2430155063698
# labels: 0.17106826603412628 0.21994610130786896 0.2657940983772278
# sample calibrated preds: [0.15331444 0.23654601 0.12980261 0.1620016 ]
# total grad sum: 1844.1876111511635
# labels: 0.16110125184059143 0.22799554467201233 0.25354450941085815
# sample calibrated preds: [0.24148484 0.25526807 0.25429395 0.25462133]
# total grad sum: 1705.12013530029
# labels: 0.2413715273141861 0.2589140832424164 0.28409460186958313
# sample calibrated preds: [0.25996405 0.2602542  0.27636287 0.25611174]
# total grad sum: 1615.1401442370475
# labels: 0.14549605548381805 0.21005025506019592 0.2585115134716034
# sample calibrated preds: [0.22024421 0.20008129 0.28283277 0.23585668]
# total grad sum: 2027.7273147020169
# labels: 0.1797984540462494 0.2145966738462448 0.2693939805030823
# sample calibrated preds: [0.26808935 0.2807111  0.27284706 0.288996  ]
# total grad sum: 1687.5791282667165
# labels: 0.1807219535112381 0.22000652551651 0.2625327706336975
# sample calibrated preds: [0.26003346 0.19717325 0.26694712 0.2534681 ]
# total grad sum: 1727.2731153280847
# labels: 0.10909365862607956 0.20811602473258972 0.27633512020111084
# sample calibrated preds: [0.2888169  0.30183217 0.17153923 0.23135929]
# total grad sum: 1821.268642071374
# labels: 0.14646753668785095 0.22409439086914062 0.2697223424911499
# sample calibrated preds: [0.22603355 0.17370903 0.2877161  0.24355999]
# total grad sum: 1929.4338648929756
# labels: 0.16673637926578522 0.24633079767227173 0.3086760640144348
# sample calibrated preds: [0.22249934 0.23361592 0.26897678 0.24019805]
# total grad sum: 1719.1087459453602
# labels: 0.16124263405799866 0.24485403299331665 0.33237117528915405
# sample calibrated preds: [0.2204382  0.24078003 0.26187304 0.13728848]
# total grad sum: 1783.0862077146458
# labels: 0.17650912702083588 0.22152379155158997 0.2586984932422638
# sample calibrated preds: [0.22383386 0.22128163 0.2052656  0.22721559]
# total grad sum: 2064.138136871365
# labels: 0.16369156539440155 0.2397320419549942 0.3390956521034241
# sample calibrated preds: [0.26023695 0.21259542 0.22802204 0.1960023 ]
# total grad sum: 1815.7934460839315
# labels: 0.16482479870319366 0.20462173223495483 0.23379677534103394
# sample calibrated preds: [0.22092336 0.13440023 0.21253608 0.20222533]
# total grad sum: 1853.5117334091765
# labels: 0.1715307980775833 0.21178443729877472 0.2652280926704407
# sample calibrated preds: [0.12065813 0.22498697 0.2029959  0.12354478]
# total grad sum: 1847.913203509232
# labels: 0.1746443659067154 0.20790226757526398 0.2245292216539383
# sample calibrated preds: [0.21511269 0.22011016 0.24280202 0.10883727]
# total grad sum: 1936.1845775482022
# labels: 0.14478589594364166 0.1983584761619568 0.2947694957256317
# sample calibrated preds: [0.26438966 0.22027399 0.23631062 0.15371528]
# total grad sum: 2223.0050224002553
# labels: 0.16093629598617554 0.2202373445034027 0.2545889914035797
# sample calibrated preds: [0.25520098 0.25647458 0.20626204 0.27351594]
# total grad sum: 1902.7494250670313
# labels: 0.19006159901618958 0.25194114446640015 0.27496427297592163
# sample calibrated preds: [0.2709877  0.2787585  0.272061   0.19258419]
# total grad sum: 1699.0974667863802
# labels: 0.15794217586517334 0.22425119578838348 0.257951557636261
# sample calibrated preds: [0.27322352 0.28601766 0.1970188  0.2252607 ]
# total grad sum: 1765.4815330288743
# labels: 0.15724803507328033 0.20788615942001343 0.24130186438560486
# sample calibrated preds: [0.25180036 0.21937849 0.19218847 0.21879661]
# total grad sum: 1870.2164137602665
# labels: 0.21978920698165894 0.23515011370182037 0.2612696588039398
# sample calibrated preds: [0.25764194 0.25708747 0.27111012 0.25151372]
# total grad sum: 1689.5444098203566
# labels: 0.15742729604244232 0.21375122666358948 0.2509709596633911
# sample calibrated preds: [0.13745718 0.20487043 0.26703656 0.2730976 ]
# total grad sum: 1827.0577238380913
# labels: 0.15965576469898224 0.204098641872406 0.23972243070602417
# sample calibrated preds: [0.16972533 0.16226204 0.17532252 0.23216712]
# total grad sum: 1971.9623573990038
# labels: 0.16151027381420135 0.2014559805393219 0.2547306716442108
# sample calibrated preds: [0.24567814 0.1638207  0.18972285 0.1624206 ]
# total grad sum: 1926.2353212222606
# labels: 0.14940443634986877 0.21926778554916382 0.26154470443725586
# sample calibrated preds: [0.20164087 0.25029075 0.2292032  0.14253278]
# total grad sum: 1792.9822178598397
# labels: 0.16268843412399292 0.21607480943202972 0.253258615732193
# sample calibrated preds: [0.252359   0.2434429  0.15929776 0.22139663]
# total grad sum: 1717.9570910031475
# labels: 0.22013871371746063 0.2498871088027954 0.3025650680065155
# sample calibrated preds: [0.20529097 0.20716092 0.2132523  0.25295073]
# total grad sum: 1730.5148206012507
# labels: 0.10512910783290863 0.2573447525501251 0.3965910077095032
# sample calibrated preds: [0.24300672 0.2604661  0.2547589  0.087405  ]
# total grad sum: 1962.8561697117889
# labels: 0.2137926071882248 0.23682722449302673 0.2690081298351288
# sample calibrated preds: [0.16770823 0.25845125 0.24177858 0.25396025]
# total grad sum: 2066.281673981851
# labels: 0.23574139177799225 0.26128527522087097 0.3097306787967682
# sample calibrated preds: [0.2605896  0.24693532 0.25908726 0.26406014]
# total grad sum: 1734.0071552534614
# labels: 0.10759898275136948 0.19924619793891907 0.2643975019454956
# sample calibrated preds: [0.08743237 0.21808843 0.28145605 0.2770172 ]
# total grad sum: 1941.3577511929734
# labels: 0.22465981543064117 0.24548953771591187 0.2664678692817688
# sample calibrated preds: [0.29369614 0.30713615 0.21704915 0.23880076]
# total grad sum: 1709.7273761758124
# labels: 0.1785171777009964 0.22005580365657806 0.24687626957893372
# sample calibrated preds: [0.2843128  0.22918336 0.31339738 0.27283463]
# total grad sum: 1895.8063349261124
# labels: 0.1707199215888977 0.2071242481470108 0.27834224700927734
# sample calibrated preds: [0.25100183 0.30188662 0.2909954  0.29674783]
# total grad sum: 1696.3935154376998
# labels: 0.16868998110294342 0.20094303786754608 0.24253012239933014
# sample calibrated preds: [0.2693199  0.31900468 0.2854909  0.28913003]
# total grad sum: 1660.7012031432973
# labels: 0.2305537611246109 0.273589164018631 0.3105204701423645
# sample calibrated preds: [0.3067696  0.31459108 0.2991226  0.27315414]
# total grad sum: 1651.5400302603814
# labels: 0.20483343303203583 0.24198615550994873 0.26613155007362366
# sample calibrated preds: [0.2509293  0.2559879  0.3064184  0.27347466]
# total grad sum: 1690.5255569347291
# labels: 0.17134781181812286 0.22809383273124695 0.2550901770591736
# sample calibrated preds: [0.2740162  0.26619473 0.25808585 0.2793649 ]
# total grad sum: 1688.6694040082161
# labels: 0.16325265169143677 0.24662096798419952 0.3112069368362427
# sample calibrated preds: [0.2693438  0.1710962  0.24908425 0.26144224]
# total grad sum: 1695.7265503447036
# labels: 0.15359416604042053 0.17825847864151 0.2100028395652771
# sample calibrated preds: [0.19681232 0.16931038 0.09227491 0.17750663]
# total grad sum: 1994.163595946467
# labels: 0.16422171890735626 0.21486631035804749 0.261796236038208
# sample calibrated preds: [0.19955015 0.19755112 0.1672504  0.15020896]
# total grad sum: 1809.6863905533974
# labels: 0.13142678141593933 0.21594160795211792 0.2630307078361511
# sample calibrated preds: [0.15539564 0.21823055 0.16246301 0.19961028]
# total grad sum: 1715.2412948626868
# labels: 0.22244830429553986 0.26328736543655396 0.31564244627952576
# sample calibrated preds: [0.17712182 0.20709755 0.22245218 0.18915862]
# total grad sum: 1697.5817818834316
# labels: 0.2161370813846588 0.26111143827438354 0.31542012095451355
# sample calibrated preds: [0.24309143 0.24289466 0.21469888 0.19696736]
# total grad sum: 1650.4791121264807
# labels: 0.16042493283748627 0.2231874167919159 0.2677270472049713
# sample calibrated preds: [0.24378341 0.14064921 0.23176673 0.15916722]
# total grad sum: 2031.1458080131813
# labels: 0.10953456908464432 0.198196679353714 0.2531430423259735
# sample calibrated preds: [0.1376835  0.20445755 0.20157646 0.24339128]
# total grad sum: 1775.4239468953979
# labels: 0.20696772634983063 0.2379438579082489 0.2657081186771393
# sample calibrated preds: [0.25663745 0.2274451  0.22746459 0.2373594 ]
# total grad sum: 1663.8082453908305
# labels: 0.1457836627960205 0.20141032338142395 0.2696262300014496
# sample calibrated preds: [0.22732563 0.23386095 0.19514519 0.22711867]
# total grad sum: 1800.6985205555561
# labels: 0.1664210855960846 0.21595685184001923 0.25928381085395813
# sample calibrated preds: [0.23155937 0.25177363 0.23879549 0.23140828]
# total grad sum: 1629.8280914811426
# labels: 0.17022037506103516 0.23125867545604706 0.28187689185142517
# sample calibrated preds: [0.19574513 0.25446323 0.256586   0.23530196]
# total grad sum: 1795.9008206389065
# labels: 0.26064273715019226 0.2845923900604248 0.2969374358654022
# sample calibrated preds: [0.24583869 0.26050958 0.2583006  0.24257587]
# total grad sum: 1682.0669414258045
# labels: 0.2097405344247818 0.2424977421760559 0.27203986048698425
# sample calibrated preds: [0.25894383 0.23720738 0.24873324 0.21826921]
# total grad sum: 1684.7753348172112
# labels: 0.2030044049024582 0.22666019201278687 0.2932130992412567
# sample calibrated preds: [0.24809895 0.2274431  0.2218931  0.20282169]
# total grad sum: 1627.6141481010318
# labels: 0.1603062003850937 0.2036968469619751 0.23881475627422333
# sample calibrated preds: [0.18521129 0.22185937 0.21373014 0.21347694]
# total grad sum: 1920.6053454983448
# labels: 0.2232649028301239 0.2690010368824005 0.329718679189682
# sample calibrated preds: [0.22364195 0.23462242 0.16454647 0.20821421]
# total grad sum: 1947.1052957044121
# labels: 0.10444299876689911 0.19327974319458008 0.2721579670906067
# sample calibrated preds: [0.20206241 0.23323497 0.18792859 0.11431067]
# total grad sum: 1884.3871338159054
# labels: 0.14852778613567352 0.2262377142906189 0.2741023898124695
# sample calibrated preds: [0.19528222 0.24713868 0.236664   0.19685413]
# total grad sum: 1901.779455501597
# labels: 0.15469668805599213 0.21740581095218658 0.24897432327270508
# sample calibrated preds: [0.20062342 0.20228036 0.21803007 0.23091097]
# total grad sum: 1629.2536360813165
# labels: 0.2136020064353943 0.24272924661636353 0.2889053225517273
# sample calibrated preds: [0.23135751 0.22874184 0.22035159 0.22593418]
# total grad sum: 1807.9747571621929
# labels: 0.15008218586444855 0.25210729241371155 0.3230845332145691
# sample calibrated preds: [0.2535258  0.18470962 0.2653588  0.21492995]
# total grad sum: 1676.3304051986665
# labels: 0.10786642879247665 0.20062939822673798 0.2669188678264618
# sample calibrated preds: [0.23441009 0.20564653 0.26880246 0.23579843]
# total grad sum: 1981.7389899880636
# labels: 0.16389767825603485 0.23411282896995544 0.35862866044044495
# sample calibrated preds: [0.16694166 0.27632466 0.28075385 0.26740065]
# total grad sum: 2019.9943255036815
# labels: 0.1451784372329712 0.218295156955719 0.3069395124912262
# sample calibrated preds: [0.18340477 0.28120813 0.23281759 0.24456869]
# total grad sum: 1912.025122263694
# labels: 0.1610441356897354 0.2091503143310547 0.26054155826568604
# sample calibrated preds: [0.27768314 0.2529107  0.27846986 0.2515226 ]
# total grad sum: 1682.199318771412
# labels: 0.15734383463859558 0.22502338886260986 0.3123725354671478
# sample calibrated preds: [0.2845319  0.2194175  0.17846134 0.2891677 ]
# total grad sum: 2263.884015927581
# labels: 0.20605160295963287 0.24109217524528503 0.2753819227218628
# sample calibrated preds: [0.2543586  0.27008095 0.2250907  0.27882227]
# total grad sum: 1758.318933601692
# labels: 0.20159323513507843 0.22332030534744263 0.26298952102661133
# sample calibrated preds: [0.2737732  0.24263656 0.22003913 0.24816807]
# total grad sum: 1658.6279335205322
# labels: 0.2245102822780609 0.26680660247802734 0.3128613829612732
# sample calibrated preds: [0.25248128 0.2578366  0.23006012 0.20010781]
# total grad sum: 1927.2554086052114
# labels: 0.17203348875045776 0.20204877853393555 0.21618759632110596
# sample calibrated preds: [0.18785548 0.19803135 0.23416266 0.19376594]
# total grad sum: 1833.3055381363763
# labels: 0.12984232604503632 0.21216405928134918 0.2712375521659851
# sample calibrated preds: [0.19897142 0.23286995 0.12386921 0.19344376]
# total grad sum: 1802.2224512884059
# labels: 0.20165303349494934 0.2143252193927765 0.2313479632139206
# sample calibrated preds: [0.18944307 0.2135765  0.18167321 0.19497235]
# total grad sum: 1780.6370084203882
# labels: 0.14503400027751923 0.17189136147499084 0.20117813348770142
# sample calibrated preds: [0.20461278 0.11986408 0.14412957 0.19592026]
# total grad sum: 1903.2072719070602
# labels: 0.21560125052928925 0.24599891901016235 0.27214181423187256
# sample calibrated preds: [0.21311024 0.19670923 0.22687398 0.22350085]
# total grad sum: 1599.0579522051207
# labels: 0.19924874603748322 0.2569538950920105 0.3155876398086548
# sample calibrated preds: [0.20883344 0.21874523 0.22082539 0.16120791]
# total grad sum: 1650.3446570356527
# labels: 0.15822547674179077 0.1821489930152893 0.2109510749578476
# sample calibrated preds: [0.15950696 0.19346339 0.18477872 0.1746861 ]
# total grad sum: 1715.9706121938334
# labels: 0.22601613402366638 0.25924092531204224 0.30432718992233276
# sample calibrated preds: [0.20693903 0.20471583 0.2028563  0.21420987]
# total grad sum: 1762.2233272952458
# labels: 0.22793327271938324 0.24511557817459106 0.2686118483543396
# sample calibrated preds: [0.20881328 0.21284217 0.21651058 0.22302055]
# total grad sum: 1663.5964134634858
# labels: 0.19951283931732178 0.24950474500656128 0.26954159140586853
# sample calibrated preds: [0.2233756  0.23220219 0.22054909 0.22513537]
# total grad sum: 1578.2710913580052
# labels: 0.1710173487663269 0.21829935908317566 0.2639140188694
# sample calibrated preds: [0.22909634 0.23308629 0.22246085 0.19575553]
# total grad sum: 1809.5168195058077
# labels: 0.21433432400226593 0.24021431803703308 0.27956926822662354
# sample calibrated preds: [0.2251868  0.25829542 0.24155472 0.23097228]
# total grad sum: 1649.8150550125802
# labels: 0.22922323644161224 0.25340402126312256 0.27065640687942505
# sample calibrated preds: [0.24709886 0.26457587 0.265117   0.25732607]
# total grad sum: 1816.8836760997674
# labels: 0.16031189262866974 0.2662259340286255 0.33603110909461975
# sample calibrated preds: [0.2808452  0.2727965  0.28199148 0.25760964]
# total grad sum: 1635.123609102633
# labels: 0.1618468165397644 0.20544397830963135 0.2666059732437134
# sample calibrated preds: [0.29804027 0.2726262  0.26247346 0.2493236 ]
# total grad sum: 1675.0591260561678
# labels: 0.16472585499286652 0.2507416605949402 0.37613752484321594
# sample calibrated preds: [0.25937128 0.29851952 0.30230066 0.2738195 ]
# total grad sum: 1783.5967505612844
# labels: 0.21867801249027252 0.2641744017601013 0.32760146260261536
# sample calibrated preds: [0.2880261  0.29972777 0.27010408 0.292133  ]
# total grad sum: 1820.3405101122476
# labels: 0.22379127144813538 0.24357786774635315 0.27013692259788513
# sample calibrated preds: [0.29987216 0.27212873 0.27016175 0.29497996]
# total grad sum: 1791.774842059847
# labels: 0.18749111890792847 0.21197783946990967 0.25441011786460876
# sample calibrated preds: [0.26511964 0.27663428 0.29703623 0.29908723]
# total grad sum: 1587.7697650175705
# labels: 0.23872555792331696 0.2622281610965729 0.2744360566139221
# sample calibrated preds: [0.2962639  0.2961417  0.27299523 0.27157095]
# total grad sum: 1592.9726496864364
# labels: 0.2378699630498886 0.2636343836784363 0.28128933906555176
# sample calibrated preds: [0.28189072 0.27595732 0.27422565 0.26059827]
# total grad sum: 1548.1991653377336
# labels: 0.16652558743953705 0.22691158950328827 0.2712721824645996
# sample calibrated preds: [0.23740773 0.26517433 0.23680553 0.22279415]
# total grad sum: 1645.8724511168411
# labels: 0.17039954662322998 0.2199692577123642 0.27870285511016846
# sample calibrated preds: [0.23039624 0.16214535 0.20679174 0.23447388]
# total grad sum: 1646.7854634384369
# labels: 0.2128809541463852 0.24291452765464783 0.27260977029800415
# sample calibrated preds: [0.19816864 0.1999215  0.21715634 0.2008585 ]
# total grad sum: 1752.938215730775
# labels: 0.16946394741535187 0.22306887805461884 0.27077388763427734
# sample calibrated preds: [0.16255033 0.19914635 0.15555474 0.16979916]
# total grad sum: 1788.6646337571815
# labels: 0.15390296280384064 0.19827760756015778 0.26446518301963806
# sample calibrated preds: [0.17269339 0.16276239 0.18243529 0.12789674]
# total grad sum: 1710.2031970601279
# labels: 0.1635625809431076 0.201478511095047 0.2603645622730255
# sample calibrated preds: [0.14927103 0.14907259 0.18368849 0.1270731 ]
# total grad sum: 1596.5224114165153
# labels: 0.18668532371520996 0.23701241612434387 0.27124905586242676
# sample calibrated preds: [0.1481622  0.18604231 0.16504885 0.17886408]
# total grad sum: 1608.309127002899
# labels: 0.16091157495975494 0.21921037137508392 0.239908367395401
# sample calibrated preds: [0.17721038 0.18619172 0.18826492 0.15844874]
# total grad sum: 1632.7122856391316
# labels: 0.22247940301895142 0.25133031606674194 0.2900659739971161
# sample calibrated preds: [0.18159747 0.18170978 0.20105506 0.20071512]
# total grad sum: 1614.686453312544
# labels: 0.1602989137172699 0.2158167064189911 0.2657739222049713
# sample calibrated preds: [0.2032224  0.13004841 0.1995054  0.21178253]
# total grad sum: 1637.1371391907796
# ...
# sample calibrated preds: [0.29741567 0.25839788 0.2723733  0.2456151 ]
# total grad sum: 1774.9836948367747
# labels: 0.10702860355377197 0.17588680982589722 0.26952871680259705
# sample calibrated preds: [0.20745057 0.3140931  0.20515178 0.2621131 ]
# total grad sum: 1901.4749428775035
# labels: 0.22562895715236664 0.2533903121948242 0.26482048630714417
# sample calibrated preds: [0.2941842  0.3158562  0.28304192 0.25782055]
# total grad sum: 1685.2967943753413
# labels: 0.1480582058429718 0.24195611476898193 0.29265096783638
# sample calibrated preds: [0.31060827 0.1967972  0.30331424 0.28255653]
# total grad sum: 1616.0826329830036
# labels: 0.19229961931705475 0.22169974446296692 0.2639140188694
# sample calibrated preds: [0.22677387 0.24243271 0.27477816 0.2769654 ]
# total grad sum: 1675.662000001044
# labels: 0.1490190178155899 0.17067961394786835 0.22617222368717194
# sample calibrated preds: [0.2726792  0.1879644  0.18676884 0.21358113]
# total grad sum: 1730.8565117165342
# labels: 0.16079753637313843 0.21321909129619598 0.2580835223197937
# sample calibrated preds: [0.2583668  0.23305017 0.1981966  0.26531354]
# total grad sum: 1617.6758473835189
# labels: 0.1709335744380951 0.20426785945892334 0.22490549087524414
# sample calibrated preds: [0.21995705 0.18930228 0.2082617  0.15803002]
# total grad sum: 1720.6926552981513
# labels: 0.20946471393108368 0.24532470107078552 0.2809208631515503
# sample calibrated preds: [0.22773916 0.22042955 0.26051614 0.18411338]
# total grad sum: 1635.7464270459939
# labels: 0.15991626679897308 0.19579091668128967 0.24005840718746185
# sample calibrated preds: [0.1995592  0.15484214 0.15591787 0.17637457]
# total grad sum: 1712.382535162921
# labels: 0.1625850647687912 0.2044772356748581 0.2600080966949463
# sample calibrated preds: [0.21941754 0.13970111 0.19868591 0.10857936]
# total grad sum: 1766.074562513794
# labels: 0.16383162140846252 0.2375107705593109 0.3306899666786194
# sample calibrated preds: [0.14172828 0.16705808 0.20535061 0.13815142]
# total grad sum: 1825.5895165568422
# labels: 0.17291006445884705 0.23693180084228516 0.26561689376831055
# sample calibrated preds: [0.20040923 0.18960707 0.10333959 0.1794981 ]
# total grad sum: 1682.1893250280061
# labels: 0.16227124631404877 0.23540809750556946 0.28582963347435
# sample calibrated preds: [0.09035452 0.21259438 0.20356047 0.2046044 ]
# total grad sum: 1664.5187554816862
# labels: 0.15860648453235626 0.24978312849998474 0.3069395124912262
# sample calibrated preds: [0.22687899 0.22095966 0.1943415  0.22231539]
# total grad sum: 1644.2331692190683
# labels: 0.16897602379322052 0.20548751950263977 0.252554714679718
# sample calibrated preds: [0.21588784 0.159878   0.1579106  0.1418125 ]
# total grad sum: 1735.4264221450157
# labels: 0.13700717687606812 0.20954447984695435 0.2645006775856018
# sample calibrated preds: [0.24198003 0.11730225 0.24796982 0.14134711]
# total grad sum: 1901.3617684890678
# labels: 0.20962168276309967 0.24276350438594818 0.2664678692817688
# sample calibrated preds: [0.1929447  0.20317991 0.24984095 0.2677871 ]
# total grad sum: 1621.3456322256388
# labels: 0.15221604704856873 0.2057085633277893 0.2728733420372009
# sample calibrated preds: [0.19027646 0.24485809 0.15598115 0.23006923]
# total grad sum: 1636.3947734683702
# labels: 0.15911945700645447 0.20668838918209076 0.24925877153873444
# sample calibrated preds: [0.23871395 0.26382148 0.17436521 0.2551158 ]
# total grad sum: 1662.8783580578233
# labels: 0.16184209287166595 0.2311587929725647 0.28190186619758606
# sample calibrated preds: [0.2782759  0.18769944 0.2555241  0.2359202 ]
# total grad sum: 1664.3752382251614
# labels: 0.17086482048034668 0.22618907690048218 0.2852035462856293
# sample calibrated preds: [0.23008706 0.16896002 0.27517363 0.20689858]
# total grad sum: 1768.296582733163
# labels: 0.14986853301525116 0.1844625324010849 0.2599691152572632
# sample calibrated preds: [0.16610864 0.21805671 0.15664387 0.16022816]
# total grad sum: 1819.294664501237
# labels: 0.16177307069301605 0.22239641845226288 0.2444101870059967
# sample calibrated preds: [0.17364661 0.20442027 0.2315385  0.15252472]
# total grad sum: 1684.208688771912
# labels: 0.23735104501247406 0.24976757168769836 0.26435554027557373
# sample calibrated preds: [0.23153006 0.2392659  0.25368932 0.18679214]
# total grad sum: 1660.409091219752
# labels: 0.12221751362085342 0.1640210747718811 0.2027672380208969
# sample calibrated preds: [0.23173043 0.11134358 0.15811408 0.1679334 ]
# total grad sum: 1967.2662574025437
# labels: 0.1953926533460617 0.23443979024887085 0.28596553206443787
# sample calibrated preds: [0.16996841 0.22969522 0.20178066 0.22816023]
# total grad sum: 1714.5600832142977
# labels: 0.22539688646793365 0.2569955587387085 0.2711714506149292
# sample calibrated preds: [0.24491505 0.246017   0.15905084 0.25207615]
# total grad sum: 1805.5676972984047
# labels: 0.1762310266494751 0.2238357961177826 0.2715645432472229
# sample calibrated preds: [0.2583193  0.17907003 0.20288321 0.15664881]
# total grad sum: 1908.1692593097378
# labels: 0.2245292216539383 0.25637441873550415 0.26844871044158936
# sample calibrated preds: [0.27751958 0.19779323 0.26217005 0.27025545]
# total grad sum: 1738.2612879872868
# labels: 0.20483343303203583 0.24184127151966095 0.26983892917633057
# sample calibrated preds: [0.22808835 0.27122048 0.27420482 0.28299052]
# total grad sum: 1760.8289988937304
# labels: 0.1756429374217987 0.2089594602584839 0.2451501041650772
# sample calibrated preds: [0.20281535 0.21628886 0.18962571 0.27752617]
# total grad sum: 1914.731735165789
# labels: 0.1711125671863556 0.2263951301574707 0.3025650680065155
# sample calibrated preds: [0.29246557 0.24328701 0.27220362 0.230023  ]
# total grad sum: 1650.961235102804
# labels: 0.20474837720394135 0.27537593245506287 0.32394829392433167
# sample calibrated preds: [0.2837428  0.2860207  0.27281505 0.23554695]
# total grad sum: 1772.1382190620138
# labels: 0.16260601580142975 0.21098244190216064 0.2947901487350464
# sample calibrated preds: [0.23005961 0.2448579  0.2818748  0.19773605]
# total grad sum: 1837.8456100598755
# labels: 0.15858228504657745 0.22188878059387207 0.28594616055488586
# sample calibrated preds: [0.22963011 0.22789048 0.24058332 0.27516904]
# total grad sum: 1651.346895483153
# labels: 0.2000093162059784 0.24572451412677765 0.2709572911262512
# sample calibrated preds: [0.27408937 0.2575302  0.26025453 0.2800122 ]
# total grad sum: 1651.1687263103709
# labels: 0.16469591856002808 0.2241838425397873 0.26223862171173096
# sample calibrated preds: [0.25870413 0.23977093 0.25827783 0.2194032 ]
# total grad sum: 1619.6212543246716
# labels: 0.15876060724258423 0.22547581791877747 0.25996312499046326
# sample calibrated preds: [0.21502358 0.24106853 0.26350483 0.20110604]
# total grad sum: 1623.3752621137824
# labels: 0.1609988659620285 0.23730580508708954 0.271504282951355
# sample calibrated preds: [0.24072784 0.23851748 0.20161644 0.25855586]
# total grad sum: 1623.472004052046
# labels: 0.17036019265651703 0.2069159895181656 0.23252184689044952
# sample calibrated preds: [0.21943192 0.20585373 0.21316281 0.22109309]
# total grad sum: 1774.173764470368
# labels: 0.17370742559432983 0.23829607665538788 0.2753819227218628
# sample calibrated preds: [0.23636718 0.20553052 0.24215527 0.23026901]
# total grad sum: 1711.0386010880648
# labels: 0.2205915004014969 0.2371649444103241 0.2696262300014496
# sample calibrated preds: [0.22893542 0.19797878 0.22476663 0.21374166]
# total grad sum: 1702.0451200841328
# labels: 0.23454271256923676 0.26044219732284546 0.2785476744174957
# sample calibrated preds: [0.23774225 0.24724345 0.20833878 0.22702506]
# total grad sum: 1583.1947478910852
# labels: 0.13068461418151855 0.20731908082962036 0.2593918740749359
# sample calibrated preds: [0.23774998 0.18106091 0.21089323 0.18542142]
# total grad sum: 1605.1212436804108
# labels: 0.202021524310112 0.23521947860717773 0.2688479721546173
# sample calibrated preds: [0.25684938 0.23036474 0.24657679 0.19191048]
# total grad sum: 1825.2732091979042
# labels: 0.1919361650943756 0.23894280195236206 0.2650274336338043
# sample calibrated preds: [0.25272334 0.25571123 0.22280002 0.25742626]
# total grad sum: 1628.2120676803004
# labels: 0.15849162638187408 0.1901172399520874 0.24130186438560486
# sample calibrated preds: [0.24330483 0.19875422 0.2428527  0.24196813]
# total grad sum: 1816.8091637399277
# labels: 0.160805806517601 0.2178599238395691 0.28412601351737976
# sample calibrated preds: [0.21002874 0.25724426 0.20234202 0.25615034]
# total grad sum: 1679.3936251449372
# labels: 0.16885386407375336 0.2165660709142685 0.2657254636287689
# sample calibrated preds: [0.256869   0.2807952  0.22224508 0.21668851]
# total grad sum: 1678.8814585607886
# labels: 0.16110125184059143 0.22176803648471832 0.26582926511764526
# sample calibrated preds: [0.21151188 0.27156034 0.19071068 0.27421588]
# total grad sum: 1802.8863556967672
# labels: 0.21822470426559448 0.2678043246269226 0.3196551203727722
# sample calibrated preds: [0.25906074 0.24233073 0.2669031  0.17933905]
# total grad sum: 1808.9729001575868
# labels: 0.231605663895607 0.2534526288509369 0.2857672870159149
# sample calibrated preds: [0.18736538 0.262663   0.2169731  0.23609722]
# total grad sum: 1774.5766664274406
# labels: 0.17028194665908813 0.24734723567962646 0.2790815830230713
# sample calibrated preds: [0.2532948  0.17605875 0.24107455 0.2473186 ]
# total grad sum: 1866.4961776767104
# labels: 0.15695762634277344 0.23430292308330536 0.3965910077095032
# sample calibrated preds: [0.17483684 0.25797006 0.16346925 0.15794042]
# total grad sum: 1768.7058816183708
# labels: 0.1975233554840088 0.23713502287864685 0.2716996371746063
# sample calibrated preds: [0.24045423 0.16336161 0.24189702 0.22155458]
# total grad sum: 1796.3885077604784
# labels: 0.21370655298233032 0.2328159064054489 0.27537015080451965
# sample calibrated preds: [0.24591626 0.16685182 0.19619642 0.20325059]
# total grad sum: 1683.4127650270195
# labels: 0.10948865860700607 0.2031560093164444 0.26931506395339966
# sample calibrated preds: [0.11341431 0.1647995  0.23339622 0.17274478]
# total grad sum: 1695.2751402333092
# labels: 0.2006559520959854 0.2497410774230957 0.28187689185142517
# sample calibrated preds: [0.1971377  0.22539571 0.18762784 0.26317668]
# total grad sum: 1687.6266740159726
# labels: 0.15391354262828827 0.23033063113689423 0.2744152545928955
# sample calibrated preds: [0.17797263 0.26932812 0.22249237 0.2712361 ]
# total grad sum: 1823.8978056257893
# labels: 0.2043619155883789 0.24047768115997314 0.2651076912879944
# sample calibrated preds: [0.2892967  0.22476444 0.28306943 0.23647471]
# total grad sum: 1604.704559944671
# labels: 0.1421714425086975 0.21420659124851227 0.2609786093235016
# sample calibrated preds: [0.15990864 0.23198695 0.3005664  0.22810087]
# total grad sum: 1790.5561908342681
# labels: 0.16325265169143677 0.21746161580085754 0.2730526030063629
# sample calibrated preds: [0.1835522  0.2695706  0.20209362 0.27234012]
# total grad sum: 1717.397281366002
# labels: 0.2103087306022644 0.24324020743370056 0.30282366275787354
# sample calibrated preds: [0.20514561 0.2479746  0.2535625  0.24068546]
# total grad sum: 1683.1070167951748
# labels: 0.16110584139823914 0.2304050177335739 0.31662142276763916
# sample calibrated preds: [0.27454835 0.29624435 0.12433286 0.15320379]
# total grad sum: 1923.7729680538962
# labels: 0.10940192639827728 0.2174212783575058 0.3199576139450073
# sample calibrated preds: [0.13106947 0.25896522 0.12629941 0.25000876]
# total grad sum: 1748.8519335307888
# labels: 0.15807613730430603 0.2116311490535736 0.2660871744155884
# sample calibrated preds: [0.22082129 0.2978822  0.29324794 0.17513812]
# total grad sum: 1899.4979665642668
# labels: 0.141312837600708 0.20570355653762817 0.2947694957256317
# sample calibrated preds: [0.30833048 0.19616485 0.19031373 0.13163722]
# total grad sum: 2063.6504754191938
# labels: 0.2342335432767868 0.26617899537086487 0.3257185220718384
# sample calibrated preds: [0.2799071  0.30608296 0.24938713 0.30008453]
# total grad sum: 1626.4210070239212
# labels: 0.14437629282474518 0.18719157576560974 0.26802316308021545
# sample calibrated preds: [0.18133008 0.13005097 0.2964528  0.19866122]
# total grad sum: 1760.1514942964561
# labels: 0.19178710877895355 0.23625415563583374 0.3086760640144348
# sample calibrated preds: [0.28170568 0.21035703 0.22107644 0.25077426]
# total grad sum: 1948.7298428844374
# labels: 0.1607966274023056 0.17724570631980896 0.19609855115413666
# sample calibrated preds: [0.17871006 0.19339569 0.15160868 0.18022694]
# total grad sum: 1801.337936901437
# labels: 0.16057224571704865 0.2150646597146988 0.2448454350233078
# sample calibrated preds: [0.23582517 0.31152734 0.2906241  0.18006648]
# total grad sum: 2016.431090015435
# labels: 0.16884450614452362 0.19836118817329407 0.2668316066265106
# sample calibrated preds: [0.2309812  0.15352102 0.16455884 0.2580541 ]
# total grad sum: 1847.7645182955007
# labels: 0.187950998544693 0.22059568762779236 0.2499547004699707
# sample calibrated preds: [0.22165592 0.2585118  0.21927693 0.12379395]
# total grad sum: 1836.0951965826484
# labels: 0.2177666872739792 0.225047767162323 0.2367861121892929
# sample calibrated preds: [0.20139018 0.16769575 0.13261917 0.14527279]
# total grad sum: 1912.450722606487
# labels: 0.20434702932834625 0.23169569671154022 0.2684381902217865
# sample calibrated preds: [0.16534755 0.20676678 0.18666342 0.20000273]
# total grad sum: 1682.4002564864898
# labels: 0.18380145728588104 0.20591163635253906 0.21909591555595398
# sample calibrated preds: [0.19956478 0.18833783 0.15840991 0.1399566 ]
# total grad sum: 1912.990278049494
# labels: 0.18631309270858765 0.22988581657409668 0.3015902042388916
# sample calibrated preds: [0.2581584  0.15095368 0.20013098 0.16829279]
# total grad sum: 1729.1707050369446
# labels: 0.17339907586574554 0.2084846794605255 0.2603645622730255
# sample calibrated preds: [0.21058175 0.17072804 0.14876407 0.26927924]
# total grad sum: 1916.9145323879043
# labels: 0.10808900743722916 0.1605778932571411 0.21602310240268707
# sample calibrated preds: [0.1744479  0.18315306 0.15869208 0.12017152]
# total grad sum: 1815.843997488125
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 265
#     263 y_cal = model.cal_scale * logits + model.cal_bias
#     264 loss = loss_fn(y_cal, labels)
# --> 265 loss.backward()
#     266 torch.nn.utils.clip_grad_norm_(model.parameters(), 1.0)
#     267 optimizer.step()
#
# File c:\Users\Ed\AppData\Local\Programs\Python\Python313\Lib\site-packages\torch\_tensor.py:625, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     615 if has_torch_function_unary(self):
#     616     return handle_torch_function(
#     617         Tensor.backward,
#     618         (self,),
#    (...)    623         inputs=inputs,
#     624     )
# --> 625 torch.autograd.backward(
#     626     self, gradient, retain_graph, create_graph, inputs=inputs
#     627 )
#
# File c:\Users\Ed\AppData\Local\Programs\Python\Python313\Lib\site-packages\torch\autograd\__init__.py:354, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     349     retain_graph = create_graph
#     351 # The reason we repeat the same comment below is that
#     352 # some Python versions print out the first line of a multi-line function
#     353 # calls in the traceback and some print out the last line
# --> 354 _engine_run_backward(
#     355     tensors,
#     356     grad_tensors_,
#     357     retain_graph,
#     358     create_graph,
#     359     inputs_tuple,
#     360     allow_unreachable=True,
#     361     accumulate_grad=True,
#     362 )
#
# File c:\Users\Ed\AppData\Local\Programs\Python\Python313\Lib\site-packages\torch\autograd\graph.py:841, in _engine_run_backward(t_outputs, *args, **kwargs)
#     839     unregister_hooks = _register_logging_hooks_on_whole_graph(t_outputs)
#     840 try:
# --> 841     return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     842         t_outputs, *args, **kwargs
#     843     )  # Calls into the C++ engine to run the backward pass
#     844 finally:
#     845     if attach_logging_hooks:
#
# KeyboardInterrupt:

# %% [markdown]
# # Experimental Area

# %%
preds = model(input_ids=input_ids, attention_mask=attention_mask)  # shape (B,) or (B,1)
print("preds shape", preds.shape)
print("preds unique (first 20):", np.unique(preds.detach().cpu().numpy())[:20])
print("preds std", preds.detach().cpu().float().std().item())
# Out:
# preds shape torch.Size([4])
# preds unique (first 20): [0.23956104]
# preds std 0.0

# %%
# print some weights stats of one new layer, e.g. the linear weights in the FFN or attention
for name, p in model.encoder.encoder.layer[-1].named_parameters():
    print(name, p.data.mean().item(), p.data.std().item())
    break
# Out:
# attention.self.query.weight 2.7404408683651127e-05 0.03611214458942413

# %%
from transformers import BertTokenizer

# Load the same tokenizer your encoder uses
tokenizer = BertTokenizer.from_pretrained("bert-base-uncased")

text = "[H]C([H])=O"

# Tokenize
tokens = tokenizer.tokenize(text)
token_ids = tokenizer.convert_tokens_to_ids(tokens)

print("Original text:", text)
print("Tokens:", tokens)
print("Token IDs:", token_ids)
# Out:
# Original text: [H]C([H])=O
# Tokens: ['[', 'h', ']', 'c', '(', '[', 'h', ']', ')', '=', 'o']
# Token IDs: [1031, 1044, 1033, 1039, 1006, 1031, 1044, 1033, 1007, 1027, 1051]

# %%
import numpy as np
print("Label statistics:")
print(f"  Mean: {toy_urgency.mean():.4f}")
print(f"  Std : {toy_urgency.std():.4f}")
print(f"  Min/Max: {toy_urgency.min():.4f} / {toy_urgency.max():.4f}")
# Out:
# Label statistics:
#   Mean: 0.2499
#   Std : 0.0611
#   Min/Max: 0.1081 / 0.4330

# %% [markdown]
# # Testing block

# %%
import math
import numpy as np
import pandas as pd
import torch
from sklearn.metrics import mean_absolute_error

# -------------------------
# Diagnostics: show df shape & columns
# -------------------------
print("Original df shape:", getattr(df, "shape", None))
print("Columns:", list(df.columns))

# If column names are weird, show first few rows to inspect
print("\nFirst 10 rows of df (for inspection):")
display(df.head(10)) if "display" in globals() else print(df.head(10).to_string(index=False))

# -------------------------
# Choose a safe slice for rows 101..121 (inclusive)
# -------------------------
START = 10001
END_EXCLUSIVE = 10101

df_test = pd.read_csv(r'C:\\Users\\Ed\\Downloads\\qm8.csv', nrows=21000)
n = len(df_test)
df_test = df_test.iloc[10001:10101].reset_index(drop=True)
df_test = df_test[['smiles', 'E1-CC2']]

if START >= n:
    # If df has fewer rows than START, fall back to last 21 rows (or all rows if <21)
    fallback_count = min(21, n)
    start_idx = max(0, n - fallback_count)
    end_idx = n
    print(f"\nWARNING: df has only {n} rows, so rows {START}-{END_EXCLUSIVE-1} don't exist.")
    print(f"Falling back to rows {start_idx}..{end_idx-1} (last {fallback_count} rows).")
else:
    start_idx = START
    end_idx = min(END_EXCLUSIVE, n)
    print(f"\nSelecting rows {start_idx}..{end_idx-1} from df (if available).")

print("df_test shape:", df_test.shape)

# -------------------------
# Identify text and label columns (robustly)
# -------------------------
if "smiles" in df_test.columns:
    text_col = "smiles"
else:
    text_col = df_test.columns[0]

# your label column seems to be 'E1-CC2' in this run — if present, use it; else second column
if "E1-CC2" in df_test.columns:
    label_col = "E1-CC2"
elif "urgency" in df_test.columns:
    label_col = "urgency"
else:
    # fallback to second column if present
    label_col = df_test.columns[1] if df_test.shape[1] > 1 else None

print(f"Using text column: '{text_col}', label column: '{label_col}'")

# -------------------------
# Drop rows missing text or labels
# -------------------------
if label_col is None:
    raise RuntimeError("No suitable label column found in df_test. Please ensure a numeric label column exists.")

# Coerce label to numeric and drop NaNs
df_test[label_col] = pd.to_numeric(df_test[label_col], errors="coerce")
before_drop = len(df_test)
df_test = df_test.dropna(subset=[text_col, label_col]).reset_index(drop=True)
after_drop = len(df_test)
print(f"Dropped {before_drop - after_drop} rows with missing text or non-numeric labels. Remaining: {after_drop}")

if len(df_test) == 0:
    raise RuntimeError("No rows left in df_test after cleaning. Please check your DataFrame and indices.")

# -------------------------
# Prediction helper (batched)
# -------------------------
model.eval()

# --- SETTINGS (update these to match training) ---
mode = "regression"    # "regression" or "binary"
# If you normalized labels for training, set these (otherwise set to None)
label_mean = None      # e.g. mean.item() or float
label_std  = None      # e.g. std.item() or float

# --- safe predict function ---
def predict_batch(texts, batch_size=32, max_length=32, device=device):
    model.eval()
    preds = []
    for i in range(0, len(texts), batch_size):
        batch_texts = texts[i:i+batch_size]
        enc = tokenizer(
            batch_texts,
            truncation=True,
            padding=True,
            max_length=max_length,
            return_tensors="pt"
        )
        input_ids = enc["input_ids"].to(device)
        attention_mask = enc["attention_mask"].to(device)
        with torch.no_grad():
            logits = model(input_ids=input_ids, attention_mask=attention_mask)  # (B,)

            # If you trained a calibration layer (scale + bias), apply it here.
            if hasattr(model, "cal_scale") and hasattr(model, "cal_bias"):
                logits = model.cal_scale * logits + model.cal_bias

            if mode == "binary":
                out = torch.sigmoid(logits).cpu().numpy()
            else:
                out = logits.cpu().numpy()
                # if labels were normalized during training, unnormalize here
                if (label_mean is not None) and (label_std is not None):
                    out = out * label_std + label_mean

        preds.extend(out.tolist())
    return np.array(preds)


# --- Use it on your df_test ---
texts = df_test[text_col].astype(str).tolist()
preds = predict_batch(texts, batch_size=16, max_length=32)
df_test["predicted_urgency"] = preds

# --- Do NOT clamp labels for regression unless you have a good reason ---
# df_test[label_col] = df_test[label_col].clip(0.0, 1.0)  # remove for regression

# --- Metrics ---
mae = mean_absolute_error(df_test[label_col].values, df_test["predicted_urgency"].values)

def safe_pearson(a, b):
    a = np.asarray(a, dtype=float)
    b = np.asarray(b, dtype=float)
    if len(a) < 2:
        return float("nan")
    am = a - a.mean(); bm = b - b.mean()
    denom = math.sqrt((am**2).sum() * (bm**2).sum())
    if denom == 0:
        return float("nan")
    return float((am * bm).sum() / denom)

pearson = safe_pearson(df_test[label_col].values, df_test["predicted_urgency"].values)
print(f"MAE on slice: {mae:.4f}   Pearson r: {pearson:.4f}")

print("Results (sorted by abs_error desc):")
N = 50
cols = [text_col, label_col, "predicted_urgency", "abs_error"]
df_test["abs_error"] = (df_test[label_col] - df_test["predicted_urgency"]).abs()
print(df_test[cols].head(N).to_string(index=False,
    formatters={
        text_col: "{{:.{}}}".format(80).format,   # truncate long strings to 80 chars
        label_col: "{:.4f}".format,
        "predicted_urgency": "{:.4f}".format,
        "abs_error": "{:.4f}".format
    }))

# -------------------------
# Optional: show the raw df_test if you want
# -------------------------
print("\nFinal df_test shape:", df_test.shape)
# Out:
# Original df shape: (2000, 17)
# Columns: ['smiles', 'E1-CC2', 'E2-CC2', 'f1-CC2', 'f2-CC2', 'E1-PBE0', 'E2-PBE0', 'f1-PBE0', 'f2-PBE0', 'E1-PBE0.1', 'E2-PBE0.1', 'f1-PBE0.1', 'f2-PBE0.1', 'E1-CAM', 'E2-CAM', 'f1-CAM', 'f2-CAM']
#
# First 10 rows of df (for inspection):
#                       smiles   E1-CC2   E2-CC2       f1-CC2   f2-CC2  E1-PBE0  E2-PBE0  f1-PBE0      f2-PBE0  E1-PBE0.1  E2-PBE0.1  f1-PBE0.1    f2-PBE0.1   E1-CAM   E2-CAM  f1-CAM  f2-CAM
#            [H]C([H])([H])[H] 0.432952 0.432960 2.497283e-01 0.249736 0.430218 0.430236 0.181436 1.815015e-01   0.430218   0.430236   0.181436 1.815015e-01 0.409931 0.409939  0.1832  0.1832
#                 [H]N([H])[H] 0.265220 0.350081 6.701544e-02 0.030049 0.268386 0.349106 0.040761 3.164115e-02   0.268386   0.349106   0.040761 3.164115e-02 0.253853 0.334481  0.0575  0.0238
#                      [H]O[H] 0.286537 0.363579 3.775532e-02 0.000000 0.291377 0.362091 0.019503 1.000000e-08   0.291377   0.362091   0.019503 1.000000e-08 0.278519 0.350074  0.0333  0.0000
#                    [H]C#C[H] 0.358629 0.358629 0.000000e+00 0.000000 0.256321 0.268469 0.000000 0.000000e+00   0.256321   0.268469   0.000000 0.000000e+00 0.244879 0.255051  0.0000  0.0000
#                       [H]C#N 0.319958 0.336074 0.000000e+00 0.000000 0.295139 0.311657 0.000000 0.000000e+00   0.295139   0.311657   0.000000 0.000000e+00 0.283425 0.296993  0.0000  0.0000
#                  [H]C([H])=O 0.153914 0.291234 0.000000e+00 0.091023 0.148553 0.312962 0.000000 1.579165e-01   0.148553   0.312962   0.000000 1.579165e-01 0.146839 0.304442  0.0000  0.0954
# [H]C([H])([H])C([H])([H])[H] 0.376138 0.376146 0.000000e+00 0.000000 0.372867 0.372891 0.000000 0.000000e+00   0.372867   0.372891   0.000000 0.000000e+00 0.354965 0.354976  0.0000  0.0000
#           [H]OC([H])([H])[H] 0.266691 0.333191 9.443000e-04 0.071608 0.277884 0.331415 0.001311 5.682431e-02   0.277884   0.331415   0.001311 5.682431e-02 0.261225 0.325294  0.0003  0.0653
#         [H]C#CC([H])([H])[H] 0.273389 0.285750 0.000000e+00 0.001194 0.251415 0.262750 0.000000 1.653170e-03   0.251415   0.262750   0.000000 1.653170e-03 0.243832 0.253357  0.0000  0.0009
#            [H]C([H])([H])C#N 0.319655 0.334414 1.000000e-08 0.002747 0.289962 0.305077 0.000000 2.763860e-03   0.289962   0.305077   0.000000 2.763860e-03 0.283900 0.296563  0.0000  0.0017
#
# Selecting rows 10001..10100 from df (if available).
# df_test shape: (100, 2)
# Using text column: 'smiles', label column: 'E1-CC2'
# Dropped 0 rows with missing text or non-numeric labels. Remaining: 100
# MAE on slice: 0.0195   Pearson r: 0.8847
# Results (sorted by abs_error desc):
#                                                                        smiles E1-CC2 predicted_urgency abs_error
#   [H]C#CC([H])(C([H])([H])C([H])([H])[H])C([H])(C([H])([H])[H])C([H])([H])[H] 0.2691            0.2820    0.0128
#             [H]C#CC([H])(C([H])([H])C([H])([H])[H])C([H])(O[H])C([H])([H])[H] 0.2685            0.2820    0.0135
#      [H]C([H])([H])C([H])([H])C([H])(C#N)C([H])(C([H])([H])[H])C([H])([H])[H] 0.3128            0.2730    0.0398
#                [H]OC([H])(C([H])([H])[H])C([H])(C#N)C([H])([H])C([H])([H])[H] 0.2861            0.2739    0.0123
#           [H]C([H])([H])N(C([H])([H])[H])C([H])(C#N)C([H])([H])C([H])([H])[H] 0.2359            0.2814    0.0455
#                [H]N([H])C([H])([H])C([H])(C#N)N(C([H])([H])[H])C([H])([H])[H] 0.2397            0.2435    0.0038
#                     [H]OC([H])([H])C([H])(C#N)N(C([H])([H])[H])C([H])([H])[H] 0.2442            0.2686    0.0243
#           [H]N(C([H])([H])[H])C([H])(C#N)C([H])(C([H])([H])[H])C([H])([H])[H] 0.2435            0.2474    0.0039
#                [H]N(C([H])([H])[H])C([H])(C#N)C([H])(N([H])[H])C([H])([H])[H] 0.2460            0.2474    0.0014
#                     [H]OC([H])(C([H])([H])[H])C([H])(C#N)N([H])C([H])([H])[H] 0.2475            0.2529    0.0054
#             [H]C#CC([H])(OC([H])([H])[H])C([H])(C([H])([H])[H])C([H])([H])[H] 0.2630            0.2673    0.0043
#                       [H]C#CC([H])(OC([H])([H])[H])C([H])(O[H])C([H])([H])[H] 0.2632            0.2623    0.0009
#                [H]C([H])([H])OC([H])(C#N)C([H])(C([H])([H])[H])C([H])([H])[H] 0.2760            0.2735    0.0025
#                     [H]N([H])C([H])(C([H])([H])[H])C([H])(C#N)OC([H])([H])[H] 0.2502            0.2910    0.0408
#                          [H]OC([H])(C([H])([H])[H])C([H])(C#N)OC([H])([H])[H] 0.2746            0.2411    0.0335
#                            [H]OC([H])([H])C([H])(C([H])=O)C(=O)C([H])([H])[H] 0.1575            0.1368    0.0208
#                  [H]C(=O)C([H])(C(=O)C([H])([H])[H])C([H])([H])C([H])([H])[H] 0.1542            0.1415    0.0127
#                       [H]C(=O)C([H])(C(=O)N([H])[H])C([H])([H])C([H])([H])[H] 0.1588            0.1429    0.0159
#                    [H]N=C([H])N(C(=O)C([H])([H])[H])C([H])([H])C([H])([H])[H] 0.1941            0.1964    0.0023
#                         [H]N=C([H])N(C(=O)N([H])[H])C([H])([H])C([H])([H])[H] 0.2233            0.1984    0.0248
#                    [H]N=C(N(C([H])=O)C([H])([H])C([H])([H])[H])C([H])([H])[H] 0.1965            0.1535    0.0430
#                       [H]C(=O)N(C(=O)C([H])([H])[H])C([H])([H])C([H])([H])[H] 0.1682            0.1574    0.0108
#                            [H]C(=O)N(C(=O)N([H])[H])C([H])([H])C([H])([H])[H] 0.2036            0.1736    0.0300
#                       [H]C(=O)C([H])(C(=O)C([H])([H])[H])N([H])C([H])([H])[H] 0.1586            0.1634    0.0048
#                            [H]C(=O)C([H])(C(=O)N([H])[H])N([H])C([H])([H])[H] 0.1679            0.1427    0.0252
#                            [H]C(=O)C([H])(OC([H])([H])[H])C(=O)C([H])([H])[H] 0.1514            0.1313    0.0201
#                                 [H]C(=O)C([H])(OC([H])([H])[H])C(=O)N([H])[H] 0.1587            0.1550    0.0036
#                                 [H]OC([H])([H])C([H])(C([H])=O)C(=O)N([H])[H] 0.1596            0.1585    0.0011
#           [H]OC([H])([H])C([H])(C([H])=O)C([H])(C([H])([H])[H])C([H])([H])[H] 0.1628            0.1669    0.0041
#                     [H]OC([H])([H])C([H])(C([H])=O)C([H])(O[H])C([H])([H])[H] 0.1657            0.1679    0.0022
# [H]C(=O)C([H])(C([H])([H])C([H])([H])[H])C([H])(C([H])([H])[H])C([H])([H])[H] 0.1606            0.1608    0.0002
#           [H]OC([H])(C([H])([H])[H])C([H])(C([H])=O)C([H])([H])C([H])([H])[H] 0.1640            0.1790    0.0150
#      [H]C(=O)N(C([H])([H])C([H])([H])[H])C([H])(C([H])([H])[H])C([H])([H])[H] 0.2099            0.1841    0.0259
#                [H]OC([H])([H])C([H])(C([H])=O)N(C([H])([H])[H])C([H])([H])[H] 0.1603            0.1787    0.0184
#           [H]C(=O)C([H])(OC([H])([H])[H])C([H])(C([H])([H])[H])C([H])([H])[H] 0.1543            0.1523    0.0021
#                     [H]OC([H])(C([H])([H])[H])C([H])(OC([H])([H])[H])C([H])=O 0.1561            0.2850    0.1289
#                     [H]OC([H])([H])C([H])(C(=O)C([H])([H])[H])C([H])([H])O[H] 0.1668            0.1827    0.0159
# [H]C([H])([H])C(=O)C([H])(C([H])([H])C([H])([H])[H])C([H])([H])C([H])([H])[H] 0.1663            0.1584    0.0079
#      [H]N([H])C(=O)C([H])(C([H])([H])C([H])([H])[H])C([H])([H])C([H])([H])[H] 0.2145            0.1678    0.0467
#           [H]OC([H])([H])C([H])(C(=O)C([H])([H])[H])C([H])([H])C([H])([H])[H] 0.1652            0.1827    0.0175
#                [H]OC([H])([H])C([H])(C(=O)N([H])[H])C([H])([H])C([H])([H])[H] 0.2151            0.1986    0.0164
#           [H]C([H])([H])OC([H])(C(=O)C([H])([H])[H])C([H])([H])C([H])([H])[H] 0.1624            0.1850    0.0226
#                [H]N([H])C(=O)C([H])(OC([H])([H])[H])C([H])([H])C([H])([H])[H] 0.2089            0.1724    0.0364
#      [H]C([H])([H])C(=O)N(C([H])([H])C([H])([H])[H])C([H])([H])C([H])([H])[H] 0.2134            0.1875    0.0259
#           [H]N([H])C(=O)N(C([H])([H])C([H])([H])[H])C([H])([H])C([H])([H])[H] 0.2393            0.2070    0.0323
#                  [H]C([H])([H])OC([H])(C(=O)[O-])C([H])([H])[N+]([H])([H])[H] 0.1579            0.1629    0.0050
#                     [H]OC([H])([H])C([H])(OC([H])([H])[H])C(=O)C([H])([H])[H] 0.1630            0.1825    0.0194
#                          [H]OC([H])([H])C([H])(OC([H])([H])[H])C(=O)N([H])[H] 0.2074            0.1825    0.0250
#                          [H]OC([H])([H])C([H])(C(=O)N([H])[H])C([H])([H])O[H] 0.2157            0.1986    0.0171
#    [H]OC([H])([H])C([H])(C([H])([H])O[H])C([H])(C([H])([H])[H])C([H])([H])[H] 0.2591            0.2859    0.0268
#
# Final df_test shape: (100, 4)

# %%
df_test = pd.read_csv(r'C:\\Users\\Ed\\Downloads\\qm8.csv', nrows=21000)
print(len(df_test))
print(START >= n)

print(START)
print(n)
# Out:
# 21000
# True
# 10001
# 100

# %% [markdown]
# # Correlation plot

# %%
import matplotlib.pyplot as plt
import numpy as np
import math

# Extract arrays
y_true = df_test[label_col].values.astype(float)
#y_pred = df_test["predicted_urgency"].values.astype(float)
y_pred = df_test["pred_calibrated"].values.astype(float)

# Compute Pearson correlation
def pearson_corr(a, b):
    a = a - a.mean()
    b = b - b.mean()
    denom = np.sqrt((a**2).sum() * (b**2).sum())
    return np.nan if denom == 0 else (a * b).sum() / denom

r = pearson_corr(y_true, y_pred)

# Create scatter plot
plt.figure(figsize=(6, 6))
plt.scatter(y_true, y_pred, alpha=0.6)
plt.plot(
    [y_true.min(), y_true.max()],
    [y_true.min(), y_true.max()],
    linestyle="--"
)
plt.xlabel("True E1")
plt.ylabel("Predicted E1")
plt.title(f"True vs Predicted E1 (Pearson r = {r:.3f})")
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
# Fit on validation preds/trues (use your validation split, not test)
pred_val = y_pred  # numpy array
true_val = y_true

a, b = np.polyfit(pred_val, true_val, 1)   # fits true ≈ a*pred + b
print("calibration: a=", a, "b=", b)

# Apply to test
df_test["pred_calibrated"] = a * df_test["predicted_urgency"].values + b

# Evaluate
from sklearn.metrics import mean_absolute_error
print("MAE before:", mean_absolute_error(y_true, y_pred))
print("MAE after :", mean_absolute_error(y_true, df_test["pred_calibrated"].values))
# Out:
# calibration: a= 0.7696030674279708 b= 0.05171110192386278
# MAE before: 0.019494418287037664
# MAE after : 0.01609358667041008

# %%
print("Train label stats:", toy_urgency.min().item(), toy_urgency.mean().item(), toy_urgency.max().item())
print("Test label stats:", df_test[label_col].min(), df_test[label_col].mean(), df_test[label_col].max())
# Out:
# Train label stats: 0.10808900743722916 0.24988378584384918 0.4329518675804138
# Test label stats: 0.14346461 0.22664009683168318 0.32961778

# %%
# 1) show calibration params
print("cal_scale:", float(model.cal_scale.detach().cpu().numpy()))
print("cal_bias :", float(model.cal_bias.detach().cpu().numpy()))

# 2) raw vs calibrated stats on a small sample
sample_texts = texts[:128]   # from your df_test list
enc = tokenizer(sample_texts, return_tensors="pt", padding=True, truncation=True, max_length=128)
enc = {k: v.to(device) for k,v in enc.items()}
model.eval()
with torch.no_grad():
    raw = model(enc["input_ids"], enc["attention_mask"])                  # (B,)
    cal = (model.cal_scale * raw + model.cal_bias)
raw = raw.cpu().numpy()
cal = cal.cpu().numpy()
print("raw mean/std/min/max:", raw.mean(), raw.std(), raw.min(), raw.max())
print("cal mean/std/min/max:", cal.mean(), cal.std(), cal.min(), cal.max())

# 3) correlation of raw->labels and cal->labels
import numpy as np
labels = np.array(df_test[label_col].tolist()[:len(raw)])
def pearson(a,b):
    a=a-np.mean(a); b=b-np.mean(b)
    return np.sum(a*b)/np.sqrt(np.sum(a*a)*np.sum(b*b))
print("pearson raw vs labels:", pearson(raw, labels))
print("pearson calibrated vs labels:", pearson(cal, labels))
# Out:
# cal_scale: 0.540034294128418
# cal_bias : 0.24174773693084717
# raw mean/std/min/max: -0.0035941957 0.06262613 -0.1280972 0.1145164
# cal mean/std/min/max: 0.23980673 0.03382026 0.17257085 0.30359054
# pearson raw vs labels: 0.7500836225527161
# pearson calibrated vs labels: 0.7500836405927541

# %%
# 1) Show optimizer param groups and a few sample param names (helps spot missing head)
for i, g in enumerate(optimizer.param_groups):
    nparam = sum(p.numel() for p in g['params'])
    ntrain = sum(1 for p in g['params'] if getattr(p, 'requires_grad', False))
    print(f"opt group {i}: lr={g.get('lr')}, weight_decay={g.get('weight_decay')}, params={nparam}, trainable={ntrain}")
    # print up to 6 sample names by matching ids
    names = []
    for p in g['params'][:6]:
        for n,q in model.named_parameters():
            if q is p:
                names.append(n); break
        else:
            names.append("<unnamed>")
    print("  sample names:", names)

# 2) Show the last 40 named parameters so we can confirm the head is present
all_named = list(model.named_parameters())
print("\nTotal named params:", len(all_named))
for n,p in all_named[-40:]:
    print(" ", n, tuple(p.shape))
# Out:
# opt group 0: lr=2e-05, weight_decay=0.01, params=44103936, trainable=103
#   sample names: ['encoder.embeddings.word_embeddings.weight', 'encoder.embeddings.position_embeddings.weight', 'encoder.embeddings.token_type_embeddings.weight', 'encoder.embeddings.LayerNorm.weight', 'encoder.embeddings.LayerNorm.bias', 'encoder.encoder.layer.0.attention.self.query.weight']
# opt group 1: lr=0.01, weight_decay=0.01, params=7871489, trainable=6
#   sample names: ['head.net.0.weight', 'head.net.0.bias', 'head.net.3.weight', 'head.net.3.bias', 'head.net.6.weight', 'head.net.6.bias']
#
# Total named params: 109
#   encoder.encoder.layer.4.attention.self.query.weight (768, 768)
#   encoder.encoder.layer.4.attention.self.query.bias (768,)
#   encoder.encoder.layer.4.attention.self.key.weight (768, 768)
#   encoder.encoder.layer.4.attention.self.key.bias (768,)
#   encoder.encoder.layer.4.attention.self.value.weight (768, 768)
#   encoder.encoder.layer.4.attention.self.value.bias (768,)
#   encoder.encoder.layer.4.attention.output.dense.weight (768, 768)
#   encoder.encoder.layer.4.attention.output.dense.bias (768,)
#   encoder.encoder.layer.4.attention.output.LayerNorm.weight (768,)
#   encoder.encoder.layer.4.attention.output.LayerNorm.bias (768,)
#   encoder.encoder.layer.4.intermediate.dense.weight (3072, 768)
#   encoder.encoder.layer.4.intermediate.dense.bias (3072,)
#   encoder.encoder.layer.4.output.dense.weight (768, 3072)
#   encoder.encoder.layer.4.output.dense.bias (768,)
#   encoder.encoder.layer.4.output.LayerNorm.weight (768,)
#   encoder.encoder.layer.4.output.LayerNorm.bias (768,)
#   encoder.encoder.layer.5.attention.self.query.weight (768, 768)
#   encoder.encoder.layer.5.attention.self.query.bias (768,)
#   encoder.encoder.layer.5.attention.self.key.weight (768, 768)
#   encoder.encoder.layer.5.attention.self.key.bias (768,)
#   encoder.encoder.layer.5.attention.self.value.weight (768, 768)
#   encoder.encoder.layer.5.attention.self.value.bias (768,)
#   encoder.encoder.layer.5.attention.output.dense.weight (768, 768)
#   encoder.encoder.layer.5.attention.output.dense.bias (768,)
#   encoder.encoder.layer.5.attention.output.LayerNorm.weight (768,)
#   encoder.encoder.layer.5.attention.output.LayerNorm.bias (768,)
#   encoder.encoder.layer.5.intermediate.dense.weight (3072, 768)
#   encoder.encoder.layer.5.intermediate.dense.bias (3072,)
#   encoder.encoder.layer.5.output.dense.weight (768, 3072)
#   encoder.encoder.layer.5.output.dense.bias (768,)
#   encoder.encoder.layer.5.output.LayerNorm.weight (768,)
#   encoder.encoder.layer.5.output.LayerNorm.bias (768,)
#   encoder.pooler.dense.weight (768, 768)
#   encoder.pooler.dense.bias (768,)
#   head.net.0.weight (6144, 768)
#   head.net.0.bias (6144,)
#   head.net.3.weight (512, 6144)
#   head.net.3.bias (512,)
#   head.net.6.weight (1, 512)
#   head.net.6.bias (1,)
