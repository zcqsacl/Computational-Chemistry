# %%
# !pip install transformers
# Out:
# Requirement already satisfied: transformers in c:\users\ed\appdata\local\programs\python\python313\lib\site-packages (4.57.3)
# Requirement already satisfied: filelock in c:\users\ed\appdata\local\programs\python\python313\lib\site-packages (from transformers) (3.20.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.34.0 in c:\users\ed\appdata\local\programs\python\python313\lib\site-packages (from transformers) (0.36.0)
# Requirement already satisfied: numpy>=1.17 in c:\users\ed\appdata\local\programs\python\python313\lib\site-packages (from transformers) (2.3.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\ed\appdata\roaming\python\python313\site-packages (from transformers) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\ed\appdata\local\programs\python\python313\lib\site-packages (from transformers) (6.0.3)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\ed\appdata\local\programs\python\python313\lib\site-packages (from transformers) (2025.11.3)
# Requirement already satisfied: requests in c:\users\ed\appdata\local\programs\python\python313\lib\site-packages (from transformers) (2.32.4)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in c:\users\ed\appdata\local\programs\python\python313\lib\site-packages (from transformers) (0.22.1)
# Requirement already satisfied: safetensors>=0.4.3 in c:\users\ed\appdata\local\programs\python\python313\lib\site-packages (from transformers) (0.7.0)
# Requirement already satisfied: tqdm>=4.27 in c:\users\ed\appdata\local\programs\python\python313\lib\site-packages (from transformers) (4.67.1)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\ed\appdata\local\programs\python\python313\lib\site-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (2025.10.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\ed\appdata\local\programs\python\python313\lib\site-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (4.14.1)
# Requirement already satisfied: colorama in c:\users\ed\appdata\roaming\python\python313\site-packages (from tqdm>=4.27->transformers) (0.4.6)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\ed\appdata\local\programs\python\python313\lib\site-packages (from requests->transformers) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\ed\appdata\local\programs\python\python313\lib\site-packages (from requests->transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\ed\appdata\local\programs\python\python313\lib\site-packages (from requests->transformers) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\ed\appdata\local\programs\python\python313\lib\site-packages (from requests->transformers) (2025.8.3)

# %%
# Download local version
path = 'C:\\Users\\Ed\\Downloads\\qm8.csv'
import pandas as pd
df = pd.read_csv(path, nrows=1000)

# %%
import pandas as pd
import kagglehub
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
from transformers import AutoTokenizer, AutoModel, BertConfig, BertModel
from torch.optim import AdamW

# ------------------------------------------------------
# 1. Toy corpus with urgency scores
# ------------------------------------------------------

# Download latest version
#path = kagglehub.dataset_download("shivanshuman/quantum-machine-8-aka-qm8")
#df = pd.read_csv(path, nrows=100)

# Extract the first column as a list of strings
toy_sentences = df.iloc[:, 0].astype(str).tolist()

# Extract the second column as a PyTorch float tensor
toy_urgency = torch.tensor(df.iloc[:, 1].values, dtype=torch.float32)

# ------------------------------------------------------
# 2. Dataset class
# ------------------------------------------------------

class UrgencyDataset(Dataset):
    def __init__(self, sentences, scores, tokenizer, max_len=32):
        self.sentences = sentences
        self.scores = scores
        self.tokenizer = tokenizer
        self.max_len = max_len

    def __len__(self):
        return len(self.sentences)

    def __getitem__(self, idx):
        text = self.sentences[idx]
        score = self.scores[idx]

        encoding = self.tokenizer(
            text,
            truncation=True,
            max_length=self.max_len,
            padding="max_length",
            return_tensors="pt"
        )

        return {
            "input_ids": encoding["input_ids"].squeeze(0),
            "attention_mask": encoding["attention_mask"].squeeze(0),
            "label": score
        }

# -------------------------
# 3) MLP head (configurable)
# -------------------------
class MLPHead(nn.Module):
    def __init__(self, input_dim, hidden_sizes, dropout=0.1, activation=nn.GELU):
        """
        input_dim: dimensionality of encoder pooled vector (e.g., 768)
        hidden_sizes: list of ints for successive hidden layers; final output -> 1
        dropout: dropout prob between layers
        activation: activation class (not instance), default GELU
        """
        super().__init__()
        layers = []
        prev = input_dim
        for h in hidden_sizes:
            layers.append(nn.Linear(prev, h))
            layers.append(activation())
            layers.append(nn.Dropout(dropout))
            prev = h
        # final linear to single logit
        layers.append(nn.Linear(prev, 1))
        self.net = nn.Sequential(*layers)

    def forward(self, x):
        # x: (B, input_dim)
        logits = self.net(x)          # (B,1)
        return logits.squeeze(-1)     # (B,)

# -------------------------
# 4) Full model with BERT + custom MLP head
# -------------------------
class TransformerUrgencyRegressor(nn.Module):
    """
    Transformer encoder + configurable MLP regression head.
    Args:
        model_name (str): pretrained Hugging Face model id (default: "distilbert-base-uncased").
        mlp_hidden_sizes (list[int] or None): hidden sizes for the MLP head; if None, defaults to [H*8, 512].
        mlp_dropout (float): dropout probability inside the head.
        use_mean_pooling (bool): if True, use attention-mask-weighted mean pooling of token embeddings;
                                 if False, use the token at position 0 (CLS) as the sentence rep.
    """
    def __init__(self,
                 model_name: str = "seyonec/ChemBERTa-zinc-base-v1",
                 mlp_hidden_sizes=None,
                 mlp_dropout: float = 0.1,
                 use_mean_pooling: bool = False):
        super().__init__()

        # load encoder
        self.encoder = AutoModel.from_pretrained(model_name)
        H = self.encoder.config.hidden_size

        # default head architecture if none specified
        if mlp_hidden_sizes is None:
            mlp_hidden_sizes = [H * 8, 512]

        # MLP head
        self.head = MLPHead(input_dim=H, hidden_sizes=mlp_hidden_sizes, dropout=mlp_dropout)

        # pooling choice flag (must be set here so forward can read it)
        self.use_mean_pooling = use_mean_pooling

        # Optional: freeze encoder for quick experiments
        # for p in self.encoder.parameters():
        #     p.requires_grad = False

    def forward(self, input_ids, attention_mask):
        """
        Args:
            input_ids: Tensor of shape (B, T)
            attention_mask: Tensor of shape (B, T) with 1 for real tokens, 0 for padding

        Returns:
            logit: Tensor of shape (B,) - one scalar prediction per input
        """
        outputs = self.encoder(input_ids=input_ids, attention_mask=attention_mask, return_dict=True)
        last_hidden = outputs.last_hidden_state   # (B, T, H)

        if self.use_mean_pooling:
            # mask: (B, T, 1)
            mask = attention_mask.unsqueeze(-1).type_as(last_hidden)
            summed = (last_hidden * mask).sum(dim=1)      # (B, H)
            counts = mask.sum(dim=1)                      # (B, 1)
            eps = 1e-9
            pooled = summed / counts.clamp(min=eps)      # (B, H)
            sentence_rep = pooled
        else:
            # CLS pooling: token at position 0
            sentence_rep = last_hidden[:, 0, :]          # (B, H)

        logit = self.head(sentence_rep)                 # (B,)
        return logit


# -------------------------
# 5) Training setup
# -------------------------
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
tokenizer = AutoTokenizer.from_pretrained("seyonec/ChemBERTa-zinc-base-v1")

dataset = UrgencyDataset(toy_sentences, toy_urgency, tokenizer)
loader = DataLoader(dataset, batch_size=4, shuffle=True)

# instantiate model with a custom MLP: change the list to whatever you want
model = TransformerUrgencyRegressor(model_name="seyonec/ChemBERTa-zinc-base-v1",
                                    mlp_hidden_sizes=[768 * 8, 512],
                                    mlp_dropout=0.25).to(device)

optimizer = AdamW([
  {'params': model.encoder.parameters(), 'lr': 2e-5},
  {'params': model.head.parameters(), 'lr': 5e-4}
], weight_decay=0.01)

loss_fn = nn.L1Loss()


# -------------------------
# 6) Training loop
# -------------------------
epochs = 20
print("Training...\n")

# Create calibration params on the model if not present
if not hasattr(model, "cal_scale") or not hasattr(model, "cal_bias"):
    # create parameters and attach them to the model for ownership
    model.cal_scale = torch.nn.Parameter(torch.tensor(1.0, dtype=torch.float32, device=device))
    model.cal_bias  = torch.nn.Parameter(torch.tensor(0.0, dtype=torch.float32, device=device))
    # add them to the optimizer with a higher lr so calibration learns fast
    try:
        optimizer.add_param_group({'params': [model.cal_scale, model.cal_bias], 'lr': 1e-6})
    except Exception as e:
        # If optimizer doesn't support add_param_group for some reason, recreate it:
        print("Adding calibration params failed, please recreate optimizer with these params included.")
        raise

for epoch in range(epochs):
    total_loss = 0.0
    num_examples = 0
    model.train()

    for batch in loader:
        input_ids = batch["input_ids"].to(device)
        attention_mask = batch["attention_mask"].to(device)
        labels = batch["label"].to(device)

        optimizer.zero_grad()
        logits = model(input_ids=input_ids, attention_mask=attention_mask)  # (B,)
        # calibrated prediction: y_cal = a * y_raw + b
        y_cal = model.cal_scale * logits + model.cal_bias    
        loss = loss_fn(y_cal, labels)
        loss.backward()
        torch.nn.utils.clip_grad_norm_(model.parameters(), 1.0)
        optimizer.step()

        batch_size = input_ids.size(0)
        total_loss += loss.item() * batch_size
        num_examples += batch_size

        # Quick diagnostics
        # 1) label stats
        print("labels:", labels.min().item(), labels.mean().item(), labels.max().item())

        # 2) sample preds (on the current batch)
        model.eval()
        with torch.no_grad():
            sample_raw = model(input_ids[:4].to(device), attention_mask[:4].to(device))
            sample_cal = (model.cal_scale * sample_raw + model.cal_bias).cpu().numpy()
        print("sample calibrated preds:", sample_cal)

        # 3) grad sizes (after loss.backward())
        total_grad = 0.0
        for n, p in list(model.named_parameters()) + [("cal_scale", model.cal_scale), ("cal_bias", model.cal_bias)]:
            if isinstance(p, torch.nn.Parameter):
                g = p.grad
            else:
                # when tuple from add, skip
                g = None
            if g is not None:
                total_grad += g.abs().sum().item()
        print("total grad sum:", total_grad)
        model.train()

    avg_loss = total_loss / max(1, num_examples)
    print(f"Epoch {epoch+1}/{epochs} - Avg Loss: {avg_loss:.6f}")

# ------------------y------------------------------------
# 6. Test predictions
# ------------------------------------------------------

print("\nPredictions (calibrated):")
model.eval()
with torch.no_grad():
    for i, sentence in enumerate(toy_sentences):
        enc = tokenizer(sentence, return_tensors="pt", padding=True, truncation=True, max_length=32).to(device)
        raw = model(enc["input_ids"], enc["attention_mask"])       # raw model output
        calibrated = (model.cal_scale * raw + model.cal_bias).item()
        # If you normalized labels during training, unnormalize here:
        # calibrated = calibrated * y_std + y_mean
        print(f"Sentence: '{sentence}'")
        print(f"  True urgency: {toy_urgency[i].item():.4f}")
        print(f"  Predicted (calibrated): {calibrated:.4f}\n")
# Out:
# Training...
#
# labels: 0.12984232604503632 0.22471527755260468 0.2893863618373871
# sample calibrated preds: [4.717858  4.5584044 4.660641  4.8508563]
# total grad sum: 1919.484448448845
# labels: 0.2711714506149292 0.30355384945869446 0.35097572207450867
# sample calibrated preds: [2.7397041 2.245244  2.6312835 2.5977364]
# total grad sum: 2080.0117048674483
# labels: 0.15734383463859558 0.2733483910560608 0.3295547664165497
# sample calibrated preds: [0.53446245 0.54133976 0.627731   0.41195938]
# total grad sum: 2155.1068179827703
# labels: 0.25265777111053467 0.29284408688545227 0.3390956521034241
# sample calibrated preds: [-0.5189084  -0.4964387  -0.50224334 -0.47213373]
# total grad sum: 2488.6757942874756
# labels: 0.15359416604042053 0.22239553928375244 0.3196873068809509
# sample calibrated preds: [-0.0709653  -0.07398383 -0.07585317 -0.16738626]
# total grad sum: 2015.6809229487087
# labels: 0.10953456908464432 0.21629567444324493 0.4329518675804138
# sample calibrated preds: [0.4201181  0.34898    0.3797015  0.40116185]
# total grad sum: 1662.3418487518147
# labels: 0.1477704793214798 0.23371565341949463 0.2712721824645996
# sample calibrated preds: [0.4382458  0.48655984 0.46381605 0.50823236]
# total grad sum: 2461.571829874003
# labels: 0.17093053460121155 0.2756854295730591 0.35039928555488586
# sample calibrated preds: [-0.00485489  0.09641228  0.08221131  0.19538336]
# total grad sum: 1974.9956752633107
# labels: 0.21683776378631592 0.29217544198036194 0.35880714654922485
# sample calibrated preds: [0.33418885 0.34967417 0.55486315 0.42314005]
# total grad sum: 2436.843211435932
# labels: 0.19006159901618958 0.2403976023197174 0.28128933906555176
# sample calibrated preds: [0.24745014 0.16378863 0.06863669 0.10916192]
# total grad sum: 1720.0592445850875
# labels: 0.10808900743722916 0.21945011615753174 0.2972326874732971
# sample calibrated preds: [0.28615606 0.1791413  0.12673753 0.15679173]
# total grad sum: 1841.3576240830787
# labels: 0.22478099167346954 0.2686479091644287 0.2963804006576538
# sample calibrated preds: [0.30574888 0.2897705  0.3213418  0.27050605]
# total grad sum: 2217.9249351047965
# labels: 0.21992109715938568 0.25660502910614014 0.27338913083076477
# sample calibrated preds: [0.0824995  0.04678387 0.05330268 0.01579643]
# total grad sum: 1671.4201386569544
# labels: 0.16072532534599304 0.23495233058929443 0.31638476252555847
# sample calibrated preds: [0.05962625 0.1426981  0.10708925 0.18567444]
# total grad sum: 1882.4311575956965
# labels: 0.24770617485046387 0.258835107088089 0.266752690076828
# sample calibrated preds: [0.07285269 0.37415472 0.30796292 0.30852687]
# total grad sum: 1837.398257741178
# labels: 0.2238161712884903 0.24743089079856873 0.2720924913883209
# sample calibrated preds: [0.26497215 0.41167334 0.4330556  0.40172836]
# total grad sum: 2285.689513570668
# labels: 0.22861060500144958 0.2762807607650757 0.37613752484321594
# sample calibrated preds: [0.19502358 0.5331385  0.236582   0.39446282]
# total grad sum: 1665.3337530145802
# labels: 0.16275309026241302 0.23823809623718262 0.35862866044044495
# sample calibrated preds: [0.11308835 0.34271142 0.17087613 0.29739794]
# total grad sum: 1515.6566749004503
# labels: 0.15391354262828827 0.21822552382946014 0.2515079081058502
# sample calibrated preds: [0.20630138 0.14328589 0.13658364 0.39166126]
# total grad sum: 2515.440192341509
# labels: 0.14869071543216705 0.2060830295085907 0.2639140188694
# sample calibrated preds: [0.15188706 0.14740732 0.18867119 0.04854298]
# total grad sum: 2706.907429097284
# labels: 0.17028194665908813 0.23749813437461853 0.28582963347435
# sample calibrated preds: [0.28001177 0.16964959 0.34853455 0.24872522]
# total grad sum: 1563.7900104033854
# labels: 0.16885386407375336 0.23032020032405853 0.27245035767555237
# sample calibrated preds: [0.30230254 0.19719557 0.3980981  0.32655278]
# total grad sum: 1977.8855763303618
# labels: 0.1622576117515564 0.22603046894073486 0.26417985558509827
# sample calibrated preds: [0.37700054 0.17381823 0.37099037 0.23412372]
# total grad sum: 1632.7307753458422
# labels: 0.23718975484371185 0.25541457533836365 0.2666987478733063
# sample calibrated preds: [0.20799115 0.13593599 0.13253258 0.22129641]
# total grad sum: 1446.1417080319766
# labels: 0.2645006775856018 0.2979549169540405 0.34129461646080017
# sample calibrated preds: [0.23165518 0.22624063 0.20889749 0.26389104]
# total grad sum: 1611.6725602814392
# Epoch 1/20 - Avg Loss: 0.404418
# labels: 0.15391354262828827 0.24105238914489746 0.2963804006576538
# sample calibrated preds: [0.4121335  0.20171484 0.3404526  0.16987035]
# total grad sum: 1992.6085710401042
# labels: 0.21631598472595215 0.265086829662323 0.31214645504951477
# sample calibrated preds: [0.19900599 0.48030615 0.3105898  0.46196517]
# total grad sum: 1839.710650865104
# labels: 0.20552457869052887 0.23950228095054626 0.27245035767555237
# sample calibrated preds: [0.48959038 0.39997602 0.5079319  0.20790598]
# total grad sum: 1358.7902821178263
# labels: 0.14869071543216705 0.2941368818283081 0.4329518675804138
# sample calibrated preds: [0.06139628 0.2524887  0.23558334 0.2387401 ]
# total grad sum: 2167.910961966457
# labels: 0.16275309026241302 0.2407093644142151 0.28128933906555176
# sample calibrated preds: [0.12753305 0.12890881 0.04205233 0.06166054]
# total grad sum: 1690.7827558016952
# labels: 0.19006159901618958 0.25965699553489685 0.3199576139450073
# sample calibrated preds: [0.00624153 0.00532535 0.34043422 0.05407579]
# total grad sum: 1186.611049061512
# labels: 0.10808900743722916 0.2072080373764038 0.25707441568374634
# sample calibrated preds: [0.17789754 0.15959185 0.20142339 0.20672783]
# total grad sum: 1412.0978055119906
# labels: 0.26331645250320435 0.27253687381744385 0.2963557541370392
# sample calibrated preds: [0.2870013  0.29055583 0.31905785 0.3377131 ]
# total grad sum: 1033.8902023810901
# labels: 0.10953456908464432 0.20343278348445892 0.3196551203727722
# sample calibrated preds: [0.3563972 0.2792555 0.3457359 0.3817172]
# total grad sum: 1495.5155088235103
# labels: 0.1657269448041916 0.23098322749137878 0.27537015080451965
# sample calibrated preds: [0.31726938 0.3348482  0.42491943 0.4307228 ]
# total grad sum: 915.3873321117867
# labels: 0.22478099167346954 0.2835359573364258 0.35862866044044495
# sample calibrated preds: [0.2905689  0.42872965 0.30611318 0.29860258]
# total grad sum: 1107.961709064468
# labels: 0.22889310121536255 0.2554096579551697 0.26747652888298035
# sample calibrated preds: [0.16275215 0.27284884 0.17601612 0.25528878]
# total grad sum: 822.1532900523374
# labels: 0.1477704793214798 0.24992677569389343 0.35039928555488586
# sample calibrated preds: [0.08887108 0.09679092 0.18076259 0.0694584 ]
# total grad sum: 1668.0330572346563
# labels: 0.12984232604503632 0.22074604034423828 0.26417985558509827
# sample calibrated preds: [0.08818144 0.10380311 0.01515737 0.06779392]
# total grad sum: 1747.1762083515405
# labels: 0.17028194665908813 0.2161434143781662 0.2741023898124695
# sample calibrated preds: [0.1324735  0.0889521  0.09587345 0.09176749]
# total grad sum: 818.2087694887451
# labels: 0.16652558743953705 0.24992017447948456 0.29666340351104736
# sample calibrated preds: [0.16935484 0.15745336 0.20936924 0.16725951]
# total grad sum: 641.5880716482383
# labels: 0.24879130721092224 0.2797256112098694 0.315703809261322
# sample calibrated preds: [0.23700973 0.23485132 0.23043561 0.24985284]
# total grad sum: 739.3757311491072
# labels: 0.21268947422504425 0.2767351567745209 0.34129461646080017
# sample calibrated preds: [0.33929366 0.32020342 0.33721057 0.3066084 ]
# total grad sum: 548.1405126237489
# labels: 0.15617066621780396 0.19234953820705414 0.2711714506149292
# sample calibrated preds: [0.35461363 0.37155572 0.36931792 0.42028812]
# total grad sum: 623.6927452490405
# labels: 0.27338913083076477 0.32443004846572876 0.37613752484321594
# sample calibrated preds: [0.40774563 0.40962592 0.41393253 0.40051824]
# total grad sum: 394.9832265709976
# labels: 0.22861060500144958 0.24814191460609436 0.2663692235946655
# sample calibrated preds: [0.36443967 0.34668598 0.36831197 0.338229  ]
# total grad sum: 403.05821885025927
# labels: 0.15359416604042053 0.2590615451335907 0.3196873068809509
# sample calibrated preds: [0.3435792  0.28968516 0.28479928 0.3211719 ]
# total grad sum: 392.32397525091426
# labels: 0.15734383463859558 0.2199116051197052 0.252550333738327
# sample calibrated preds: [0.20496014 0.19632319 0.17605242 0.19536759]
# total grad sum: 457.1477894984247
# labels: 0.21683776378631592 0.29101473093032837 0.35097572207450867
# sample calibrated preds: [0.16849005 0.13543017 0.14806831 0.18269652]
# total grad sum: 325.984180581109
# labels: 0.16885386407375336 0.22573620080947876 0.25265777111053467
# sample calibrated preds: [0.19592    0.18098617 0.17489944 0.20820288]
# total grad sum: 617.0303858359823
# Epoch 2/20 - Avg Loss: 0.130369
# labels: 0.16072532534599304 0.2466513216495514 0.2954047620296478
# sample calibrated preds: [0.22275467 0.21675116 0.28217933 0.22689989]
# total grad sum: 355.1900431710058
# labels: 0.2161370813846588 0.26101601123809814 0.2865373492240906
# sample calibrated preds: [0.25363737 0.24856791 0.22576423 0.2554346 ]
# total grad sum: 321.67786183991393
# labels: 0.15617066621780396 0.19829942286014557 0.24925877153873444
# sample calibrated preds: [0.23999985 0.249793   0.22696872 0.2340041 ]
# total grad sum: 798.6114788169399
# labels: 0.2505737543106079 0.2985192537307739 0.35862866044044495
# sample calibrated preds: [0.25204444 0.21963458 0.24057584 0.24453457]
# total grad sum: 618.4362038033928
# labels: 0.2601131498813629 0.30102699995040894 0.35097572207450867
# sample calibrated preds: [0.25144538 0.30142683 0.2733066  0.2415894 ]
# total grad sum: 348.3652140863656
# labels: 0.22889310121536255 0.28194326162338257 0.3295547664165497
# sample calibrated preds: [0.21519355 0.22942148 0.30353492 0.24909665]
# total grad sum: 544.9948204245201
# labels: 0.2565162777900696 0.2897363305091858 0.35880714654922485
# sample calibrated preds: [0.25920624 0.2598811  0.2522843  0.23558596]
# total grad sum: 674.1539887814831
# labels: 0.1657269448041916 0.2220471203327179 0.37613752484321594
# sample calibrated preds: [0.20496936 0.24697042 0.18944766 0.24360056]
# total grad sum: 276.0907093907155
# labels: 0.1477704793214798 0.20004937052726746 0.34129461646080017
# sample calibrated preds: [0.25069347 0.19255316 0.19198105 0.23512469]
# total grad sum: 405.4572556886961
# labels: 0.16275309026241302 0.24916112422943115 0.3199576139450073
# sample calibrated preds: [0.12108298 0.18793392 0.14598992 0.09473728]
# total grad sum: 946.3477676639385
# labels: 0.25717461109161377 0.30025243759155273 0.35039928555488586
# sample calibrated preds: [0.1950998  0.13540606 0.07596657 0.08731731]
# total grad sum: 421.58496803501544
# labels: 0.15734383463859558 0.24088861048221588 0.315703809261322
# sample calibrated preds: [0.13901857 0.16583222 0.18847676 0.16632937]
# total grad sum: 477.18051165644175
# labels: 0.21851083636283875 0.300915390253067 0.4329518675804138
# sample calibrated preds: [0.22917512 0.14871192 0.1938021  0.19890897]
# total grad sum: 552.619966563542
# labels: 0.10808900743722916 0.21814902126789093 0.26641926169395447
# sample calibrated preds: [0.19665667 0.27751336 0.2080163  0.18646601]
# total grad sum: 1337.3385894854296
# labels: 0.16885386407375336 0.2041429579257965 0.23718975484371185
# sample calibrated preds: [0.29287252 0.269478   0.23014511 0.24244712]
# total grad sum: 1035.817208530179
# labels: 0.15359416604042053 0.21368393301963806 0.26490452885627747
# sample calibrated preds: [0.25852722 0.2723983  0.31728345 0.25577456]
# total grad sum: 417.1347326728034
# labels: 0.12984232604503632 0.20512878894805908 0.26331645250320435
# sample calibrated preds: [0.21943133 0.27923468 0.29868084 0.31978807]
# total grad sum: 755.3977872642904
# labels: 0.21268947422504425 0.23911181092262268 0.2607683837413788
# sample calibrated preds: [0.25653547 0.23232815 0.25299832 0.24836694]
# total grad sum: 289.9583650785489
# labels: 0.22478099167346954 0.26390618085861206 0.31638476252555847
# sample calibrated preds: [0.22843151 0.2621066  0.24851115 0.23875216]
# total grad sum: 397.90265304341443
# labels: 0.10953456908464432 0.2294573187828064 0.32815229892730713
# sample calibrated preds: [0.17134999 0.24729776 0.2944601  0.3092534 ]
# total grad sum: 655.7498212883451
# labels: 0.1622576117515564 0.26252812147140503 0.3390956521034241
# sample calibrated preds: [0.25584474 0.33835062 0.34849405 0.29207495]
# total grad sum: 966.689290137171
# labels: 0.15391354262828827 0.21945101022720337 0.2657081186771393
# sample calibrated preds: [0.27953258 0.13459289 0.29349503 0.22719397]
# total grad sum: 556.2950642773162
# labels: 0.2517721951007843 0.28477799892425537 0.3196873068809509
# sample calibrated preds: [0.28658608 0.25422874 0.19392993 0.2858329 ]
# total grad sum: 777.8390206448553
# labels: 0.24928565323352814 0.2584533095359802 0.26747652888298035
# sample calibrated preds: [0.29290053 0.28899714 0.31248948 0.26693505]
# total grad sum: 387.48590888940726
# labels: 0.22861060500144958 0.2577969431877136 0.2893863618373871
# sample calibrated preds: [0.27607116 0.26235384 0.30474538 0.28137174]
# total grad sum: 856.1817638208064
# Epoch 3/20 - Avg Loss: 0.082489
# labels: 0.2505737543106079 0.3040304183959961 0.4329518675804138
# sample calibrated preds: [0.28858066 0.38759276 0.35130075 0.24127437]
# total grad sum: 694.8191960851507
# labels: 0.15734383463859558 0.2078721821308136 0.25265777111053467
# sample calibrated preds: [0.20376374 0.24107455 0.31791377 0.25940472]
# total grad sum: 562.7170601575699
# labels: 0.10808900743722916 0.21015290915966034 0.2963804006576538
# sample calibrated preds: [0.2715948  0.05290748 0.28606284 0.31229928]
# total grad sum: 982.0028825830195
# labels: 0.17028194665908813 0.2575635313987732 0.35862866044044495
# sample calibrated preds: [0.30423313 0.1772346  0.19656326 0.26811722]
# total grad sum: 692.6440679903196
# labels: 0.16244171559810638 0.24105645716190338 0.2711714506149292
# sample calibrated preds: [0.18954818 0.18131156 0.32126218 0.20951399]
# total grad sum: 947.5554410214412
# labels: 0.1477704793214798 0.16448795795440674 0.19006159901618958
# sample calibrated preds: [0.18037483 0.22451276 0.20763457 0.18958601]
# total grad sum: 839.8172097929939
# labels: 0.14869071543216705 0.26270440220832825 0.31638476252555847
# sample calibrated preds: [0.08725882 0.2826056  0.2526823  0.22543702]
# total grad sum: 1342.7179310511501
# labels: 0.2161370813846588 0.23672714829444885 0.2666987478733063
# sample calibrated preds: [0.14166208 0.12863082 0.16877693 0.25982887]
# total grad sum: 997.0130986412601
# labels: 0.15617066621780396 0.26987630128860474 0.3390956521034241
# sample calibrated preds: [0.29612395 0.14772093 0.26389655 0.258648  ]
# total grad sum: 665.934345659146
# labels: 0.12984232604503632 0.26669010519981384 0.35039928555488586
# sample calibrated preds: [0.30757675 0.08557122 0.2857631  0.21959476]
# total grad sum: 499.64991454317
# labels: 0.22046658396720886 0.24175706505775452 0.2601131498813629
# sample calibrated preds: [0.33509442 0.23835762 0.35314146 0.33304244]
# total grad sum: 640.4862765926896
# labels: 0.22861060500144958 0.25991758704185486 0.2954047620296478
# sample calibrated preds: [0.3421273  0.3397283  0.22400188 0.28058034]
# total grad sum: 370.3309814930247
# labels: 0.16885386407375336 0.2410566508769989 0.3196873068809509
# sample calibrated preds: [0.20549373 0.3407677  0.26787895 0.19911617]
# total grad sum: 540.7420764317596
# labels: 0.16072532534599304 0.260579913854599 0.35097572207450867
# sample calibrated preds: [0.2857871  0.26854742 0.26877517 0.22688901]
# total grad sum: 840.6574646981474
# labels: 0.1657269448041916 0.227952778339386 0.26417985558509827
# sample calibrated preds: [0.1954153  0.19213212 0.11973333 0.254955  ]
# total grad sum: 1714.3869332480508
# labels: 0.21268947422504425 0.25791168212890625 0.29666340351104736
# sample calibrated preds: [0.22387938 0.18141535 0.2579185  0.26436666]
# total grad sum: 662.8723718925166
# labels: 0.21631598472595215 0.25752049684524536 0.34129461646080017
# sample calibrated preds: [0.22412342 0.28730786 0.16201073 0.26936984]
# total grad sum: 490.9460626006589
# labels: 0.22478099167346954 0.258945107460022 0.2972326874732971
# sample calibrated preds: [0.32607326 0.3264415  0.31707117 0.26018912]
# total grad sum: 1249.437006081832
# labels: 0.15391354262828827 0.22594338655471802 0.2517721951007843
# sample calibrated preds: [0.3004364  0.31514823 0.27239484 0.2302829 ]
# total grad sum: 451.31100373788445
# labels: 0.10953456908464432 0.20608842372894287 0.28128933906555176
# sample calibrated preds: [0.27676043 0.15501511 0.2790449  0.10882331]
# total grad sum: 1399.3890920685594
# labels: 0.17093053460121155 0.2499178946018219 0.3295547664165497
# sample calibrated preds: [0.18551674 0.24146277 0.33372217 0.24247517]
# total grad sum: 376.141786186107
# labels: 0.1797984540462494 0.26244598627090454 0.3196551203727722
# sample calibrated preds: [0.24546637 0.24068145 0.13256153 0.20083266]
# total grad sum: 1473.9534894158141
# labels: 0.2607683837413788 0.2848430275917053 0.32815229892730713
# sample calibrated preds: [0.2707481  0.25212505 0.24301836 0.16063577]
# total grad sum: 634.0123434348308
# labels: 0.26331645250320435 0.305462121963501 0.37613752484321594
# sample calibrated preds: [0.24171624 0.26268312 0.2912366  0.2106338 ]
# total grad sum: 626.5696730427663
# labels: 0.24879130721092224 0.2855905294418335 0.35880714654922485
# sample calibrated preds: [0.2776078  0.2698474  0.22354548 0.21388067]
# total grad sum: 582.607458189283
# Epoch 4/20 - Avg Loss: 0.066030
# labels: 0.12984232604503632 0.2524060904979706 0.34129461646080017
# sample calibrated preds: [0.09209298 0.3599817  0.3332661  0.27887067]
# total grad sum: 422.23713150591567
# labels: 0.20552457869052887 0.2435198277235031 0.3199576139450073
# sample calibrated preds: [0.24113593 0.20357    0.22700885 0.23760495]
# total grad sum: 796.1681688854806
# labels: 0.10953456908464432 0.2515188157558441 0.37613752484321594
# sample calibrated preds: [0.30347502 0.32141083 0.3744481  0.13013469]
# total grad sum: 751.6544950043997
# labels: 0.24657988548278809 0.26533329486846924 0.28128933906555176
# sample calibrated preds: [0.33285153 0.28709504 0.28721136 0.29231063]
# total grad sum: 757.8240389809395
# labels: 0.22046658396720886 0.2799488306045532 0.35880714654922485
# sample calibrated preds: [0.26882467 0.16375446 0.26980364 0.26039425]
# total grad sum: 338.8758989011826
# labels: 0.1477704793214798 0.20194950699806213 0.25717461109161377
# sample calibrated preds: [0.22243048 0.18965302 0.10659529 0.14045714]
# total grad sum: 783.5750012814588
# labels: 0.14869071543216705 0.20890936255455017 0.2954047620296478
# sample calibrated preds: [0.15109079 0.1612381  0.20050351 0.16118678]
# total grad sum: 522.7899358244782
# labels: 0.22889310121536255 0.2809484004974365 0.31638476252555847
# sample calibrated preds: [0.20555593 0.18528336 0.20154503 0.1576757 ]
# total grad sum: 305.6731226672323
# labels: 0.15617066621780396 0.22474604845046997 0.265219509601593
# sample calibrated preds: [0.28425494 0.27581647 0.26792884 0.2636069 ]
# total grad sum: 670.7643601382307
# labels: 0.17093053460121155 0.23837393522262573 0.26747652888298035
# sample calibrated preds: [0.33019644 0.2981738  0.32132462 0.30423355]
# total grad sum: 219.0489864785261
# labels: 0.1622576117515564 0.2531816065311432 0.2972326874732971
# sample calibrated preds: [0.26230806 0.29809996 0.24590836 0.30776438]
# total grad sum: 263.49704890793555
# labels: 0.16275309026241302 0.2655729651451111 0.3196551203727722
# sample calibrated preds: [0.2987574  0.2939318  0.2660932  0.26779136]
# total grad sum: 411.1275515587602
# labels: 0.17028194665908813 0.2585139572620392 0.3196873068809509
# sample calibrated preds: [0.2403626  0.24386811 0.25704706 0.21448492]
# total grad sum: 291.2478957970018
# labels: 0.16652558743953705 0.22011786699295044 0.2505737543106079
# sample calibrated preds: [0.1675637  0.20026901 0.19434999 0.16281475]
# total grad sum: 293.88458666816314
# labels: 0.1657269448041916 0.30244192481040955 0.4329518675804138
# sample calibrated preds: [0.16167004 0.14806986 0.13280253 0.1578546 ]
# total grad sum: 551.7689196719223
# labels: 0.19006159901618958 0.26288193464279175 0.32815229892730713
# sample calibrated preds: [0.21054456 0.16246273 0.14782578 0.14923793]
# total grad sum: 262.52673174741
# labels: 0.10808900743722916 0.2019716501235962 0.2639140188694
# sample calibrated preds: [0.16012423 0.12190432 0.1797667  0.22216767]
# total grad sum: 230.37811006482607
# labels: 0.1797984540462494 0.21547868847846985 0.23718975484371185
# sample calibrated preds: [0.2045097  0.29024044 0.19965428 0.21052079]
# total grad sum: 582.7406293397821
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[85], line 206
#     204 y_cal = model.cal_scale * logits + model.cal_bias
#     205 loss = loss_fn(y_cal, labels)
# --> 206 loss.backward()
#     207 torch.nn.utils.clip_grad_norm_(model.parameters(), 1.0)
#     208 optimizer.step()
#
# File c:\Users\Ed\AppData\Local\Programs\Python\Python313\Lib\site-packages\torch\_tensor.py:625, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     615 if has_torch_function_unary(self):
#     616     return handle_torch_function(
#     617         Tensor.backward,
#     618         (self,),
#    (...)    623         inputs=inputs,
#     624     )
# --> 625 torch.autograd.backward(
#     626     self, gradient, retain_graph, create_graph, inputs=inputs
#     627 )
#
# File c:\Users\Ed\AppData\Local\Programs\Python\Python313\Lib\site-packages\torch\autograd\__init__.py:354, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     349     retain_graph = create_graph
#     351 # The reason we repeat the same comment below is that
#     352 # some Python versions print out the first line of a multi-line function
#     353 # calls in the traceback and some print out the last line
# --> 354 _engine_run_backward(
#     355     tensors,
#     356     grad_tensors_,
#     357     retain_graph,
#     358     create_graph,
#     359     inputs_tuple,
#     360     allow_unreachable=True,
#     361     accumulate_grad=True,
#     362 )
#
# File c:\Users\Ed\AppData\Local\Programs\Python\Python313\Lib\site-packages\torch\autograd\graph.py:841, in _engine_run_backward(t_outputs, *args, **kwargs)
#     839     unregister_hooks = _register_logging_hooks_on_whole_graph(t_outputs)
#     840 try:
# --> 841     return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     842         t_outputs, *args, **kwargs
#     843     )  # Calls into the C++ engine to run the backward pass
#     844 finally:
#     845     if attach_logging_hooks:
#
# KeyboardInterrupt:

# %% [markdown]
# # Experimental Area

# %%
from torch.optim import AdamW

loss_fn = nn.MSELoss()   # use MSE for continuous urgency
optimizer = AdamW([
    {'params': model.encoder.parameters(), 'lr': 2e-5},
    {'params': model.head.parameters(),    'lr': 1e-3}
], weight_decay=0.0)

epochs = 50
for epoch in range(epochs):
    total_loss = 0.0
    num_examples = 0
    model.train()

    for i, batch in enumerate(loader):
        input_ids = batch["input_ids"].to(device)
        attention_mask = batch["attention_mask"].to(device)
        labels = batch["label"].float().to(device)

        optimizer.zero_grad()
        preds = model(input_ids=input_ids, attention_mask=attention_mask)  # (B,)
        loss = loss_fn(preds, labels)
        loss.backward()

        # diagnostic: check grads on the head AFTER backward
        if i == 0:  # print only first batch per epoch to reduce noise
            total_grad = 0.0
            for n, p in model.named_parameters():
                if p.grad is not None:
                    total_grad += p.grad.abs().sum().item()
            print(f"Epoch {epoch+1} batch {i} - loss {loss.item():.6f} - total_grad {total_grad:.6f}")

        optimizer.step()

        batch_size = input_ids.size(0)
        total_loss += loss.item() * batch_size
        num_examples += batch_size

    avg_loss = total_loss / max(1, num_examples)
    print(f"Epoch {epoch+1}/{epochs} - Avg Loss: {avg_loss:.6f}")
# Out:
# Epoch 1 batch 0 - loss 0.186249 - total_grad 1936.411919
# Epoch 1/50 - Avg Loss: 0.093838
# Epoch 2 batch 0 - loss 0.006669 - total_grad 121.913118
# Epoch 2/50 - Avg Loss: 0.010722
# Epoch 3 batch 0 - loss 0.001521 - total_grad 23.022838
# Epoch 3/50 - Avg Loss: 0.004438
# Epoch 4 batch 0 - loss 0.003092 - total_grad 17.938324
# Epoch 4/50 - Avg Loss: 0.004767
# Epoch 5 batch 0 - loss 0.009016 - total_grad 38.039118
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[10], line 23
#      21 preds = model(input_ids=input_ids, attention_mask=attention_mask)  # (B,)
#      22 loss = loss_fn(preds, labels)
# ---> 23 loss.backward()
#      25 # diagnostic: check grads on the head AFTER backward
#      26 if i == 0:  # print only first batch per epoch to reduce noise
#
# File c:\Users\Ed\AppData\Local\Programs\Python\Python313\Lib\site-packages\torch\_tensor.py:625, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     615 if has_torch_function_unary(self):
#     616     return handle_torch_function(
#     617         Tensor.backward,
#     618         (self,),
#    (...)    623         inputs=inputs,
#     624     )
# --> 625 torch.autograd.backward(
#     626     self, gradient, retain_graph, create_graph, inputs=inputs
#     627 )
#
# File c:\Users\Ed\AppData\Local\Programs\Python\Python313\Lib\site-packages\torch\autograd\__init__.py:354, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     349     retain_graph = create_graph
#     351 # The reason we repeat the same comment below is that
#     352 # some Python versions print out the first line of a multi-line function
#     353 # calls in the traceback and some print out the last line
# --> 354 _engine_run_backward(
#     355     tensors,
#     356     grad_tensors_,
#     357     retain_graph,
#     358     create_graph,
#     359     inputs_tuple,
#     360     allow_unreachable=True,
#     361     accumulate_grad=True,
#     362 )
#
# File c:\Users\Ed\AppData\Local\Programs\Python\Python313\Lib\site-packages\torch\autograd\graph.py:841, in _engine_run_backward(t_outputs, *args, **kwargs)
#     839     unregister_hooks = _register_logging_hooks_on_whole_graph(t_outputs)
#     840 try:
# --> 841     return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     842         t_outputs, *args, **kwargs
#     843     )  # Calls into the C++ engine to run the backward pass
#     844 finally:
#     845     if attach_logging_hooks:
#
# KeyboardInterrupt:

# %%
# 1) Print model raw outputs (no sigmoid) on some test sentences
model.eval()
with torch.no_grad():
    enc = tokenizer(toy_sentences[:8], padding=True, truncation=True, return_tensors="pt").to(device)
    raw_preds = model(enc["input_ids"], enc["attention_mask"])   # (B,)
print("raw preds:", raw_preds.cpu().numpy())

# 2) If you normalized labels during training, show mean/std you used
print("label mean:", mean.item(), "label std:", std.item())  # if you computed them earlier

# 3) If you find raw_preds ~ 0.2–0.4 and test prints were ~0.6, that proves sigmoid was the culprit:
print("sigmoid(raw):", torch.sigmoid(raw_preds).cpu().numpy())
# Out:
# raw preds: [0.47254494 0.29902485 0.29369384 0.39706188 0.34071228 0.15216428
#  0.44116083 0.2920759 ]
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 9
#       6 print("raw preds:", raw_preds.cpu().numpy())
#       8 # 2) If you normalized labels during training, show mean/std you used
# ----> 9 print("label mean:", mean.item(), "label std:", std.item())  # if you computed them earlier
#      11 # 3) If you find raw_preds ~ 0.2–0.4 and test prints were ~0.6, that proves sigmoid was the culprit:
#      12 print("sigmoid(raw):", torch.sigmoid(raw_preds).cpu().numpy())
#
# NameError: name 'mean' is not defined

# %%
from transformers import BertTokenizer

# Load the same tokenizer your encoder uses
tokenizer = BertTokenizer.from_pretrained("bert-base-uncased")

text = "[H]C([H])=O"

# Tokenize
tokens = tokenizer.tokenize(text)
token_ids = tokenizer.convert_tokens_to_ids(tokens)

print("Original text:", text)
print("Tokens:", tokens)
print("Token IDs:", token_ids)
# Out:
# Original text: [H]C([H])=O
# Tokens: ['[', 'h', ']', 'c', '(', '[', 'h', ']', ')', '=', 'o']
# Token IDs: [1031, 1044, 1033, 1039, 1006, 1031, 1044, 1033, 1007, 1027, 1051]

# %%
import numpy as np
print("Label statistics:")
print(f"  Mean: {toy_urgency.mean():.4f}")
print(f"  Std : {toy_urgency.std():.4f}")
print(f"  Min/Max: {toy_urgency.min():.4f} / {toy_urgency.max():.4f}")
# Out:
# Label statistics:
#   Mean: 0.2499
#   Std : 0.0611
#   Min/Max: 0.1081 / 0.4330

# %% [markdown]
# # Testing block

# %%
import math
import numpy as np
import pandas as pd
import torch
from sklearn.metrics import mean_absolute_error

# -------------------------
# Diagnostics: show df shape & columns
# -------------------------
print("Original df shape:", getattr(df, "shape", None))
print("Columns:", list(df.columns))

# If column names are weird, show first few rows to inspect
print("\nFirst 10 rows of df (for inspection):")
display(df.head(10)) if "display" in globals() else print(df.head(10).to_string(index=False))

# -------------------------
# Choose a safe slice for rows 101..121 (inclusive)
# -------------------------
START = 1001
END_EXCLUSIVE = 1102

df_test = pd.read_csv(r'C:\\Users\\Ed\\Downloads\\qm8.csv', nrows=21000)
df_test = df_test.iloc[1001:1102].reset_index(drop=True)
df_test = df_test[['smiles', 'E1-CC2']]

n = len(df)
if START >= n:
    # If df has fewer rows than START, fall back to last 21 rows (or all rows if <21)
    fallback_count = min(21, n)
    start_idx = max(0, n - fallback_count)
    end_idx = n
    print(f"\nWARNING: df has only {n} rows, so rows {START}-{END_EXCLUSIVE-1} don't exist.")
    print(f"Falling back to rows {start_idx}..{end_idx-1} (last {fallback_count} rows).")
else:
    start_idx = START
    end_idx = min(END_EXCLUSIVE, n)
    print(f"\nSelecting rows {start_idx}..{end_idx-1} from df (if available).")

print("df_test shape:", df_test.shape)

# -------------------------
# Identify text and label columns (robustly)
# -------------------------
if "smiles" in df_test.columns:
    text_col = "smiles"
else:
    text_col = df_test.columns[0]

# your label column seems to be 'E1-CC2' in this run — if present, use it; else second column
if "E1-CC2" in df_test.columns:
    label_col = "E1-CC2"
elif "urgency" in df_test.columns:
    label_col = "urgency"
else:
    # fallback to second column if present
    label_col = df_test.columns[1] if df_test.shape[1] > 1 else None

print(f"Using text column: '{text_col}', label column: '{label_col}'")

# -------------------------
# Drop rows missing text or labels
# -------------------------
if label_col is None:
    raise RuntimeError("No suitable label column found in df_test. Please ensure a numeric label column exists.")

# Coerce label to numeric and drop NaNs
df_test[label_col] = pd.to_numeric(df_test[label_col], errors="coerce")
before_drop = len(df_test)
df_test = df_test.dropna(subset=[text_col, label_col]).reset_index(drop=True)
after_drop = len(df_test)
print(f"Dropped {before_drop - after_drop} rows with missing text or non-numeric labels. Remaining: {after_drop}")

if len(df_test) == 0:
    raise RuntimeError("No rows left in df_test after cleaning. Please check your DataFrame and indices.")

# -------------------------
# Prediction helper (batched)
# -------------------------
model.eval()

# --- SETTINGS (update these to match training) ---
mode = "regression"    # "regression" or "binary"
# If you normalized labels for training, set these (otherwise set to None)
label_mean = None      # e.g. mean.item() or float
label_std  = None      # e.g. std.item() or float

# --- safe predict function ---
def predict_batch(texts, batch_size=32, max_length=32, device=device):
    model.eval()
    preds = []
    for i in range(0, len(texts), batch_size):
        batch_texts = texts[i:i+batch_size]
        enc = tokenizer(
            batch_texts,
            truncation=True,
            padding=True,
            max_length=max_length,
            return_tensors="pt"
        )
        input_ids = enc["input_ids"].to(device)
        attention_mask = enc["attention_mask"].to(device)
        with torch.no_grad():
            logits = model(input_ids=input_ids, attention_mask=attention_mask)  # (B,)

            # If you trained a calibration layer (scale + bias), apply it here.
            if hasattr(model, "cal_scale") and hasattr(model, "cal_bias"):
                logits = model.cal_scale * logits + model.cal_bias

            if mode == "binary":
                out = torch.sigmoid(logits).cpu().numpy()
            else:
                out = logits.cpu().numpy()
                # if labels were normalized during training, unnormalize here
                if (label_mean is not None) and (label_std is not None):
                    out = out * label_std + label_mean

        preds.extend(out.tolist())
    return np.array(preds)


# --- Use it on your df_test ---
texts = df_test[text_col].astype(str).tolist()
preds = predict_batch(texts, batch_size=16, max_length=32)
df_test["predicted_urgency"] = preds

# --- Do NOT clamp labels for regression unless you have a good reason ---
# df_test[label_col] = df_test[label_col].clip(0.0, 1.0)  # remove for regression

# --- Metrics ---
mae = mean_absolute_error(df_test[label_col].values, df_test["predicted_urgency"].values)

def safe_pearson(a, b):
    a = np.asarray(a, dtype=float)
    b = np.asarray(b, dtype=float)
    if len(a) < 2:
        return float("nan")
    am = a - a.mean(); bm = b - b.mean()
    denom = math.sqrt((am**2).sum() * (bm**2).sum())
    if denom == 0:
        return float("nan")
    return float((am * bm).sum() / denom)

pearson = safe_pearson(df_test[label_col].values, df_test["predicted_urgency"].values)
print(f"MAE on slice: {mae:.4f}   Pearson r: {pearson:.4f}")

print("Results (sorted by abs_error desc):")
N = 50
cols = [text_col, label_col, "predicted_urgency", "abs_error"]
df_test["abs_error"] = (df_test[label_col] - df_test["predicted_urgency"]).abs()
print(df_test[cols].head(N).to_string(index=False,
    formatters={
        text_col: "{{:.{}}}".format(80).format,   # truncate long strings to 80 chars
        label_col: "{:.4f}".format,
        "predicted_urgency": "{:.4f}".format,
        "abs_error": "{:.4f}".format
    }))

# -------------------------
# Optional: show the raw df_test if you want
# -------------------------
print("\nFinal df_test shape:", df_test.shape)
# Out:
# Original df shape: (100, 17)
# Columns: ['smiles', 'E1-CC2', 'E2-CC2', 'f1-CC2', 'f2-CC2', 'E1-PBE0', 'E2-PBE0', 'f1-PBE0', 'f2-PBE0', 'E1-PBE0.1', 'E2-PBE0.1', 'f1-PBE0.1', 'f2-PBE0.1', 'E1-CAM', 'E2-CAM', 'f1-CAM', 'f2-CAM']
#
# First 10 rows of df (for inspection):
#                       smiles   E1-CC2   E2-CC2       f1-CC2   f2-CC2  E1-PBE0  E2-PBE0  f1-PBE0      f2-PBE0  E1-PBE0.1  E2-PBE0.1  f1-PBE0.1    f2-PBE0.1   E1-CAM   E2-CAM  f1-CAM  f2-CAM
#            [H]C([H])([H])[H] 0.432952 0.432960 2.497283e-01 0.249736 0.430218 0.430236 0.181436 1.815015e-01   0.430218   0.430236   0.181436 1.815015e-01 0.409931 0.409939  0.1832  0.1832
#                 [H]N([H])[H] 0.265220 0.350081 6.701544e-02 0.030049 0.268386 0.349106 0.040761 3.164115e-02   0.268386   0.349106   0.040761 3.164115e-02 0.253853 0.334481  0.0575  0.0238
#                      [H]O[H] 0.286537 0.363579 3.775532e-02 0.000000 0.291377 0.362091 0.019503 1.000000e-08   0.291377   0.362091   0.019503 1.000000e-08 0.278519 0.350074  0.0333  0.0000
#                    [H]C#C[H] 0.358629 0.358629 0.000000e+00 0.000000 0.256321 0.268469 0.000000 0.000000e+00   0.256321   0.268469   0.000000 0.000000e+00 0.244879 0.255051  0.0000  0.0000
#                       [H]C#N 0.319958 0.336074 0.000000e+00 0.000000 0.295139 0.311657 0.000000 0.000000e+00   0.295139   0.311657   0.000000 0.000000e+00 0.283425 0.296993  0.0000  0.0000
#                  [H]C([H])=O 0.153914 0.291234 0.000000e+00 0.091023 0.148553 0.312962 0.000000 1.579165e-01   0.148553   0.312962   0.000000 1.579165e-01 0.146839 0.304442  0.0000  0.0954
# [H]C([H])([H])C([H])([H])[H] 0.376138 0.376146 0.000000e+00 0.000000 0.372867 0.372891 0.000000 0.000000e+00   0.372867   0.372891   0.000000 0.000000e+00 0.354965 0.354976  0.0000  0.0000
#           [H]OC([H])([H])[H] 0.266691 0.333191 9.443000e-04 0.071608 0.277884 0.331415 0.001311 5.682431e-02   0.277884   0.331415   0.001311 5.682431e-02 0.261225 0.325294  0.0003  0.0653
#         [H]C#CC([H])([H])[H] 0.273389 0.285750 0.000000e+00 0.001194 0.251415 0.262750 0.000000 1.653170e-03   0.251415   0.262750   0.000000 1.653170e-03 0.243832 0.253357  0.0000  0.0009
#            [H]C([H])([H])C#N 0.319655 0.334414 1.000000e-08 0.002747 0.289962 0.305077 0.000000 2.763860e-03   0.289962   0.305077   0.000000 2.763860e-03 0.283900 0.296563  0.0000  0.0017
#
# WARNING: df has only 100 rows, so rows 1001-1101 don't exist.
# Falling back to rows 79..99 (last 21 rows).
# df_test shape: (101, 2)
# Using text column: 'smiles', label column: 'E1-CC2'
# Dropped 0 rows with missing text or non-numeric labels. Remaining: 101
# MAE on slice: 0.0258   Pearson r: 0.7183
# Results (sorted by abs_error desc):
#                                             smiles E1-CC2 predicted_urgency abs_error
#                          [H]C(=O)c1nc([H])c([H])o1 0.1435            0.1638    0.0203
#                  [H]C(=O)c1c([H])c([H])n([H])c1[H] 0.1522            0.2009    0.0487
#                       [H]C(=O)c1nc([H])n([H])c1[H] 0.1515            0.1829    0.0313
#                       [H]C(=O)c1c([H])oc([H])c1[H] 0.1490            0.2155    0.0665
#                            [H]C(=O)c1nc([H])oc1[H] 0.1499            0.1743    0.0243
#                  [H]C(=O)n1c([H])c([H])c([H])c1[H] 0.2007            0.2191    0.0183
#                       [H]C(=O)n1c([H])nc([H])c1[H] 0.1848            0.2123    0.0275
#               [H]c1oc(=NC([H])([H])[H])n([H])c1[H] 0.2090            0.2453    0.0363
#                    [H]c1oc(=NC([H])([H])[H])oc1[H] 0.2292            0.2303    0.0011
# [H]c1c([H])c(C([H])([H])C([H])([H])[H])n([H])c1[H] 0.2208            0.2537    0.0329
#      [H]c1oc(C([H])([H])C([H])([H])[H])c([H])c1[H] 0.2379            0.2584    0.0205
#         [H]c1nc([H])c(C([H])([H])C([H])([H])[H])o1 0.2390            0.2435    0.0045
#      [H]c1nc(C([H])([H])C([H])([H])[H])n([H])c1[H] 0.2338            0.2395    0.0057
#           [H]c1nc(C([H])([H])C([H])([H])[H])oc1[H] 0.2438            0.2020    0.0418
#      [H]c1c([H])c(N([H])C([H])([H])[H])n([H])c1[H] 0.2164            0.2407    0.0243
#           [H]c1oc(N([H])C([H])([H])[H])c([H])c1[H] 0.2044            0.2524    0.0480
#              [H]c1nc([H])c(N([H])C([H])([H])[H])o1 0.2075            0.2352    0.0278
#                [H]c1nc(N([H])C([H])([H])[H])oc1[H] 0.2256            0.2560    0.0304
#           [H]c1c([H])c(OC([H])([H])[H])n([H])c1[H] 0.2009            0.2416    0.0407
#                [H]c1oc(OC([H])([H])[H])c([H])c1[H] 0.2227            0.2558    0.0331
#                [H]c1nc([H])n([H])c1OC([H])([H])[H] 0.2316            0.2340    0.0024
#                   [H]c1nc([H])c(OC([H])([H])[H])o1 0.2228            0.2358    0.0130
#                [H]c1nc(OC([H])([H])[H])n([H])c1[H] 0.2322            0.2317    0.0006
#                     [H]c1nc(OC([H])([H])[H])oc1[H] 0.2441            0.2358    0.0083
#                [H]c1nc(C([H])([H])N([H])[H])oc1[H] 0.2469            0.2499    0.0030
#           [H]OC([H])([H])c1c([H])c([H])c([H])n1[H] 0.2278            0.2630    0.0352
#                [H]OC([H])([H])c1oc([H])c([H])c1[H] 0.2377            0.2692    0.0315
#                [H]OC([H])([H])c1c([H])nc([H])n1[H] 0.2351            0.2656    0.0305
#                     [H]OC([H])([H])c1oc([H])nc1[H] 0.2398            0.2667    0.0269
#                [H]OC([H])([H])c1nc([H])c([H])n1[H] 0.2404            0.2577    0.0173
#                   [H]OC([H])([H])c1nc([H])c([H])o1 0.2465            0.2505    0.0040
# [H]c1c(C([H])([H])C([H])([H])[H])c([H])n([H])c1[H] 0.2299            0.2547    0.0249
#      [H]c1nc(C([H])([H])C([H])([H])[H])c([H])n1[H] 0.2382            0.2475    0.0093
#      [H]c1oc([H])c(C([H])([H])C([H])([H])[H])c1[H] 0.2407            0.2479    0.0072
#         [H]c1nc(C([H])([H])C([H])([H])[H])c([H])o1 0.2391            0.2475    0.0084
#      [H]c1c(N([H])C([H])([H])[H])c([H])n([H])c1[H] 0.2043            0.2401    0.0357
#           [H]c1nc(N([H])C([H])([H])[H])c([H])n1[H] 0.2048            0.2435    0.0387
#           [H]c1oc([H])c(N([H])C([H])([H])[H])c1[H] 0.2070            0.2428    0.0359
#              [H]c1nc(N([H])C([H])([H])[H])c([H])o1 0.2001            0.2431    0.0429
#           [H]c1c(OC([H])([H])[H])c([H])n([H])c1[H] 0.2148            0.2365    0.0218
#                [H]c1nc(OC([H])([H])[H])c([H])n1[H] 0.2131            0.2444    0.0313
#                [H]c1oc([H])c(OC([H])([H])[H])c1[H] 0.2237            0.2556    0.0319
#                   [H]c1nc(OC([H])([H])[H])c([H])o1 0.2071            0.2242    0.0170
#           [H]OC([H])([H])c1c([H])c([H])n([H])c1[H] 0.2334            0.2664    0.0330
#                [H]OC([H])([H])c1nc([H])n([H])c1[H] 0.2390            0.2587    0.0197
#                [H]OC([H])([H])c1c([H])oc([H])c1[H] 0.2411            0.2717    0.0306
#                     [H]OC([H])([H])c1nc([H])oc1[H] 0.2387            0.2689    0.0302
# [H]c1c([H])c([H])n(C([H])([H])C([H])([H])[H])c1[H] 0.2396            0.2365    0.0031
#      [H]c1nc([H])n(C([H])([H])C([H])([H])[H])c1[H] 0.2409            0.2387    0.0022
#         [H]c1c([H])c2n(c1[H])C([H])([H])C2([H])[H] 0.2413            0.1976    0.0437
#
# Final df_test shape: (101, 4)

# %% [markdown]
# # Correlation plot

# %%
import matplotlib.pyplot as plt
import numpy as np
import math

# Extract arrays
y_true = df_test[label_col].values.astype(float)
y_pred = df_test["predicted_urgency"].values.astype(float)

# Compute Pearson correlation
def pearson_corr(a, b):
    a = a - a.mean()
    b = b - b.mean()
    denom = np.sqrt((a**2).sum() * (b**2).sum())
    return np.nan if denom == 0 else (a * b).sum() / denom

r = pearson_corr(y_true, y_pred)

# Create scatter plot
plt.figure(figsize=(6, 6))
plt.scatter(y_true, y_pred, alpha=0.6)
plt.plot(
    [y_true.min(), y_true.max()],
    [y_true.min(), y_true.max()],
    linestyle="--"
)
plt.xlabel("True E1")
plt.ylabel("Predicted E1")
plt.title(f"True vs Predicted E1 (Pearson r = {r:.3f})")
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
# Fit on validation preds/trues (use your validation split, not test)
pred_val = y_pred  # numpy array
true_val = y_true

a, b = np.polyfit(pred_val, true_val, 1)   # fits true ≈ a*pred + b
print("calibration: a=", a, "b=", b)

# Apply to test
df_test["pred_calibrated"] = a * df_test["predicted_urgency"].values + b

# Evaluate
from sklearn.metrics import mean_absolute_error
print("MAE before:", mean_absolute_error(y_true, y_pred))
print("MAE after :", mean_absolute_error(y_true, df_test["pred_calibrated"].values))
# Out:
# calibration: a= 0.7413298464773578 b= 0.04917179174763088
# MAE before: 0.02432231229664113
# MAE after : 0.020407899169376253

# %%
print("Train label stats:", toy_urgency.min().item(), toy_urgency.mean().item(), toy_urgency.max().item())
print("Test label stats:", df_test[label_col].min(), df_test[label_col].mean(), df_test[label_col].max())
# Out:
# Train label stats: 0.10808900743722916 0.24988378584384918 0.4329518675804138
# Test label stats: 0.14346461 0.22664009683168318 0.32961778

# %%
# 1) show calibration params
print("cal_scale:", float(model.cal_scale.detach().cpu().numpy()))
print("cal_bias :", float(model.cal_bias.detach().cpu().numpy()))

# 2) raw vs calibrated stats on a small sample
sample_texts = texts[:128]   # from your df_test list
enc = tokenizer(sample_texts, return_tensors="pt", padding=True, truncation=True, max_length=128)
enc = {k: v.to(device) for k,v in enc.items()}
model.eval()
with torch.no_grad():
    raw = model(enc["input_ids"], enc["attention_mask"])                  # (B,)
    cal = (model.cal_scale * raw + model.cal_bias)
raw = raw.cpu().numpy()
cal = cal.cpu().numpy()
print("raw mean/std/min/max:", raw.mean(), raw.std(), raw.min(), raw.max())
print("cal mean/std/min/max:", cal.mean(), cal.std(), cal.min(), cal.max())

# 3) correlation of raw->labels and cal->labels
import numpy as np
labels = np.array(df_test[label_col].tolist()[:len(raw)])
def pearson(a,b):
    a=a-np.mean(a); b=b-np.mean(b)
    return np.sum(a*b)/np.sqrt(np.sum(a*a)*np.sum(b*b))
print("pearson raw vs labels:", pearson(raw, labels))
print("pearson calibrated vs labels:", pearson(cal, labels))
# Out:
# cal_scale: 0.540034294128418
# cal_bias : 0.24174773693084717
# raw mean/std/min/max: -0.0035941957 0.06262613 -0.1280972 0.1145164
# cal mean/std/min/max: 0.23980673 0.03382026 0.17257085 0.30359054
# pearson raw vs labels: 0.7500836225527161
# pearson calibrated vs labels: 0.7500836405927541

# %%
# 1) Show optimizer param groups and a few sample param names (helps spot missing head)
for i, g in enumerate(optimizer.param_groups):
    nparam = sum(p.numel() for p in g['params'])
    ntrain = sum(1 for p in g['params'] if getattr(p, 'requires_grad', False))
    print(f"opt group {i}: lr={g.get('lr')}, weight_decay={g.get('weight_decay')}, params={nparam}, trainable={ntrain}")
    # print up to 6 sample names by matching ids
    names = []
    for p in g['params'][:6]:
        for n,q in model.named_parameters():
            if q is p:
                names.append(n); break
        else:
            names.append("<unnamed>")
    print("  sample names:", names)

# 2) Show the last 40 named parameters so we can confirm the head is present
all_named = list(model.named_parameters())
print("\nTotal named params:", len(all_named))
for n,p in all_named[-40:]:
    print(" ", n, tuple(p.shape))
# Out:
# opt group 0: lr=2e-05, weight_decay=0.01, params=44103936, trainable=103
#   sample names: ['encoder.embeddings.word_embeddings.weight', 'encoder.embeddings.position_embeddings.weight', 'encoder.embeddings.token_type_embeddings.weight', 'encoder.embeddings.LayerNorm.weight', 'encoder.embeddings.LayerNorm.bias', 'encoder.encoder.layer.0.attention.self.query.weight']
# opt group 1: lr=0.01, weight_decay=0.01, params=7871489, trainable=6
#   sample names: ['head.net.0.weight', 'head.net.0.bias', 'head.net.3.weight', 'head.net.3.bias', 'head.net.6.weight', 'head.net.6.bias']
#
# Total named params: 109
#   encoder.encoder.layer.4.attention.self.query.weight (768, 768)
#   encoder.encoder.layer.4.attention.self.query.bias (768,)
#   encoder.encoder.layer.4.attention.self.key.weight (768, 768)
#   encoder.encoder.layer.4.attention.self.key.bias (768,)
#   encoder.encoder.layer.4.attention.self.value.weight (768, 768)
#   encoder.encoder.layer.4.attention.self.value.bias (768,)
#   encoder.encoder.layer.4.attention.output.dense.weight (768, 768)
#   encoder.encoder.layer.4.attention.output.dense.bias (768,)
#   encoder.encoder.layer.4.attention.output.LayerNorm.weight (768,)
#   encoder.encoder.layer.4.attention.output.LayerNorm.bias (768,)
#   encoder.encoder.layer.4.intermediate.dense.weight (3072, 768)
#   encoder.encoder.layer.4.intermediate.dense.bias (3072,)
#   encoder.encoder.layer.4.output.dense.weight (768, 3072)
#   encoder.encoder.layer.4.output.dense.bias (768,)
#   encoder.encoder.layer.4.output.LayerNorm.weight (768,)
#   encoder.encoder.layer.4.output.LayerNorm.bias (768,)
#   encoder.encoder.layer.5.attention.self.query.weight (768, 768)
#   encoder.encoder.layer.5.attention.self.query.bias (768,)
#   encoder.encoder.layer.5.attention.self.key.weight (768, 768)
#   encoder.encoder.layer.5.attention.self.key.bias (768,)
#   encoder.encoder.layer.5.attention.self.value.weight (768, 768)
#   encoder.encoder.layer.5.attention.self.value.bias (768,)
#   encoder.encoder.layer.5.attention.output.dense.weight (768, 768)
#   encoder.encoder.layer.5.attention.output.dense.bias (768,)
#   encoder.encoder.layer.5.attention.output.LayerNorm.weight (768,)
#   encoder.encoder.layer.5.attention.output.LayerNorm.bias (768,)
#   encoder.encoder.layer.5.intermediate.dense.weight (3072, 768)
#   encoder.encoder.layer.5.intermediate.dense.bias (3072,)
#   encoder.encoder.layer.5.output.dense.weight (768, 3072)
#   encoder.encoder.layer.5.output.dense.bias (768,)
#   encoder.encoder.layer.5.output.LayerNorm.weight (768,)
#   encoder.encoder.layer.5.output.LayerNorm.bias (768,)
#   encoder.pooler.dense.weight (768, 768)
#   encoder.pooler.dense.bias (768,)
#   head.net.0.weight (6144, 768)
#   head.net.0.bias (6144,)
#   head.net.3.weight (512, 6144)
#   head.net.3.bias (512,)
#   head.net.6.weight (1, 512)
#   head.net.6.bias (1,)
