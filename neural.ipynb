# %%
import pandas as pd
import kagglehub
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
from transformers import AutoTokenizer, AutoModel, BertConfig, BertModel

# ------------------------------------------------------
# 1. Toy corpus with urgency scores
# ------------------------------------------------------

# Download latest version
path = kagglehub.dataset_download("shivanshuman/quantum-machine-8-aka-qm8")

df = pd.read_csv(path, nrows=100)

# Extract the first column as a list of strings
toy_sentences = df.iloc[:, 0].astype(str).tolist()

# Extract the second column as a PyTorch float tensor
toy_urgency = torch.tensor(df.iloc[:, 1].values, dtype=torch.float32)

# ------------------------------------------------------
# 2. Dataset class
# ------------------------------------------------------

class UrgencyDataset(Dataset):
    def __init__(self, sentences, scores, tokenizer, max_len=32):
        self.sentences = sentences
        self.scores = scores
        self.tokenizer = tokenizer
        self.max_len = max_len

    def __len__(self):
        return len(self.sentences)

    def __getitem__(self, idx):
        text = self.sentences[idx]
        score = self.scores[idx]

        encoding = self.tokenizer(
            text,
            truncation=True,
            max_length=self.max_len,
            padding="max_length",
            return_tensors="pt"
        )

        return {
            "input_ids": encoding["input_ids"].squeeze(0),
            "attention_mask": encoding["attention_mask"].squeeze(0),
            "label": score
        }

# -------------------------
# 3) MLP head (configurable)
# -------------------------
class MLPHead(nn.Module):
    def __init__(self, input_dim, hidden_sizes, dropout=0.1, activation=nn.GELU):
        """
        input_dim: dimensionality of encoder pooled vector (e.g., 768)
        hidden_sizes: list of ints for successive hidden layers; final output -> 1
        dropout: dropout prob between layers
        activation: activation class (not instance), default GELU
        """
        super().__init__()
        layers = []
        prev = input_dim
        for h in hidden_sizes:
            layers.append(nn.Linear(prev, h))
            layers.append(activation())
            layers.append(nn.Dropout(dropout))
            prev = h
        # final linear to single logit
        layers.append(nn.Linear(prev, 1))
        self.net = nn.Sequential(*layers)

    def forward(self, x):
        # x: (B, input_dim)
        logits = self.net(x)          # (B,1)
        return logits.squeeze(-1)     # (B,)

# -------------------------
# 4) Full model with BERT + custom MLP head
# -------------------------
class TransformerUrgencyRegressor(nn.Module):
    def __init__(self, model_name="bert-large-uncased", mlp_hidden_sizes=None, mlp_dropout=0.1):
        super().__init__()
        self.encoder = AutoModel.from_pretrained(model_name)
        H = self.encoder.config.hidden_size
        # default MLP: 8x expansion then a smaller layer
        if mlp_hidden_sizes is None:
            mlp_hidden_sizes = [H * 8, 512]
        self.head = MLPHead(input_dim=H, hidden_sizes=mlp_hidden_sizes, dropout=mlp_dropout)

        # Optional: freeze encoder for fast experiments (uncomment to use)
        # for p in self.encoder.parameters():
        #     p.requires_grad = False

    def forward(self, input_ids, attention_mask):
        outputs = self.encoder(input_ids=input_ids, attention_mask=attention_mask, return_dict=True)
        # Use CLS embedding (position 0). Alternatively use pooled_output if available:
        cls_rep = outputs.last_hidden_state[:, 0, :]  # (B, H)
        logit = self.head(cls_rep)                   # (B,)
        return logit

# -------------------------
# 5) Training setup
# -------------------------
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
tokenizer = AutoTokenizer.from_pretrained("bert-large-uncased")

dataset = UrgencyDataset(toy_sentences, toy_urgency, tokenizer)
loader = DataLoader(dataset, batch_size=4, shuffle=True)

# instantiate model with a custom MLP: change the list to whatever you want
model = TransformerUrgencyRegressor(model_name="bert-large-uncased",
                                    mlp_hidden_sizes=[768 * 8, 512],
                                    mlp_dropout=0.25).to(device)

optimizer = optim.Adam(model.parameters(), lr=1e-3, weight_decay=0.01)
loss_fn = nn.BCEWithLogitsLoss()

# -------------------------
# 6) Training loop
# -------------------------
epochs = 200
print("Training...\n")

for epoch in range(epochs):
    total_loss = 0.0
    num_examples = 0
    model.train()

    for batch in loader:
        input_ids = batch["input_ids"].to(device)
        attention_mask = batch["attention_mask"].to(device)
        labels = batch["label"].to(device)

        optimizer.zero_grad()
        logits = model(input_ids=input_ids, attention_mask=attention_mask)  # (B,)
        loss = loss_fn(logits, labels)
        loss.backward()
        optimizer.step()

        batch_size = input_ids.size(0)
        total_loss += loss.item() * batch_size
        num_examples += batch_size

    avg_loss = total_loss / max(1, num_examples)
    print(f"Epoch {epoch+1}/{epochs} - Avg Loss: {avg_loss:.6f}")

# ------------------y------------------------------------
# 6. Test predictions
# ------------------------------------------------------

print("\nPredictions:")
model.eval()
with torch.no_grad():
    for i, sentence in enumerate(toy_sentences):
        encoding = tokenizer(sentence, return_tensors="pt", padding=True, truncation=True).to(device)
        logit = model(encoding["input_ids"], encoding["attention_mask"])
        score = torch.sigmoid(logit).item()  # convert logit → 0-1
        print(f"Sentence: '{sentence}'")
        print(f"  True urgency: {toy_urgency[i].item():.2f}")
        print(f"  Predicted urgency: {score:.2f}\n")
# Out:
# Training...
#
# Epoch 1/200 - Avg Loss: 0.532889
# Epoch 2/200 - Avg Loss: 0.531076
# Epoch 3/200 - Avg Loss: 0.531081
# Epoch 4/200 - Avg Loss: 0.530748
# Epoch 5/200 - Avg Loss: 0.530831
# Epoch 6/200 - Avg Loss: 0.530950
# Epoch 7/200 - Avg Loss: 0.530921
# Epoch 8/200 - Avg Loss: 0.531181
# Epoch 9/200 - Avg Loss: 0.530891
# Epoch 10/200 - Avg Loss: 0.530822

# %%
with torch.no_grad():
    for i, sentence in enumerate(toy_sentences):
        encoding = tokenizer(
            sentence,
            return_tensors="pt",
            truncation=True,
            padding=True,
            max_length=512
        ).to(device)

        # Correct way:
        output = model(**encoding)
        logit = output.logits.squeeze(-1)          # shape: (1,) → scalar
        score = torch.sigmoid(logit).item()        # → float between 0 and 1

        print(f"Sentence: '{sentence}'")
        print(f"  True urgency: {toy_urgency[i].item():.4f}")
        print(f"  Predicted urgency: {score:.4f}\n")
# Out:
# Sentence: '[H]C([H])([H])[H]'
#   True urgency: 0.4330
#   Predicted urgency: 0.5559
#
# Sentence: '[H]N([H])[H]'
#   True urgency: 0.2652
#   Predicted urgency: 0.5559
#
# Sentence: '[H]O[H]'
#   True urgency: 0.2865
#   Predicted urgency: 0.5559
#
# Sentence: '[H]C#C[H]'
#   True urgency: 0.3586
#   Predicted urgency: 0.5559
#
# Sentence: '[H]C#N'
#   True urgency: 0.3200
#   Predicted urgency: 0.5559
#
# Sentence: '[H]C([H])=O'
#   True urgency: 0.1539
#   Predicted urgency: 0.5559
#
# Sentence: '[H]C([H])([H])C([H])([H])[H]'
#   True urgency: 0.3761
#   Predicted urgency: 0.5559
#
# Sentence: '[H]OC([H])([H])[H]'
#   True urgency: 0.2667
#   Predicted urgency: 0.5559
#
# Sentence: '[H]C#CC([H])([H])[H]'
#   True urgency: 0.2734
#   Predicted urgency: 0.5559
#
# Sentence: '[H]C([H])([H])C#N'
#   True urgency: 0.3197
#   Predicted urgency: 0.5559
#
# Sentence: '[H]C(=O)C([H])([H])[H]'
#   True urgency: 0.1657
#   Predicted urgency: 0.5559
#
# Sentence: '[H]C(=O)N([H])[H]'
#   True urgency: 0.2163
#   Predicted urgency: 0.5559
#
# Sentence: '[H]C([H])([H])C([H])([H])C([H])([H])[H]'
#   True urgency: 0.3588
#   Predicted urgency: 0.5559
#
# Sentence: '[H]OC([H])([H])C([H])([H])[H]'
#   True urgency: 0.2667
#   Predicted urgency: 0.5559
#
# Sentence: '[H]C([H])([H])OC([H])([H])[H]'
#   True urgency: 0.2741
#   Predicted urgency: 0.5559
#
# Sentence: '[H]C1([H])C([H])([H])C1([H])[H]'
#   True urgency: 0.3282
#   Predicted urgency: 0.5559
#
# Sentence: '[H]C1([H])OC1([H])[H]'
#   True urgency: 0.2964
#   Predicted urgency: 0.5559
#
# Sentence: '[H]C([H])([H])C(=O)C([H])([H])[H]'
#   True urgency: 0.1703
#   Predicted urgency: 0.5559
#
# Sentence: '[H]N([H])C(=O)C([H])([H])[H]'
#   True urgency: 0.2160
#   Predicted urgency: 0.5559
#
# Sentence: '[H]N([H])C(=O)N([H])[H]'
#   True urgency: 0.2472
#   Predicted urgency: 0.5559
#
# Sentence: '[H]C([H])([H])C([H])(C([H])([H])[H])C([H])([H])[H]'
#   True urgency: 0.3510
#   Predicted urgency: 0.5559
#
# Sentence: '[H]OC([H])(C([H])([H])[H])C([H])([H])[H]'
#   True urgency: 0.2675
#   Predicted urgency: 0.5559
#
# Sentence: '[H]C#CC#C[H]'
#   True urgency: 0.2055
#   Predicted urgency: 0.5559
#
# Sentence: '[H]C#CC#N'
#   True urgency: 0.2238
#   Predicted urgency: 0.5559
#
# Sentence: 'N#CC#N'
#   True urgency: 0.2488
#   Predicted urgency: 0.5559
#
# Sentence: '[H]C#CC([H])=O'
#   True urgency: 0.1478
#   Predicted urgency: 0.5559
#
# Sentence: '[H]C(=O)C#N'
#   True urgency: 0.1487
#   Predicted urgency: 0.5559
#
# Sentence: '[H]C(=O)C([H])=O'
#   True urgency: 0.1081
#   Predicted urgency: 0.5559
#
# Sentence: '[H]C([H])([H])C#CC([H])([H])[H]'
#   True urgency: 0.2972
#   Predicted urgency: 0.5559
#
# Sentence: '[H]C#CC([H])([H])C([H])([H])[H]'
#   True urgency: 0.2713
#   Predicted urgency: 0.5559
#
# Sentence: '[H]C([H])([H])C([H])([H])C#N'
#   True urgency: 0.3164
#   Predicted urgency: 0.5559
#
# Sentence: '[H]N([H])C([H])([H])C#N'
#   True urgency: 0.2493
#   Predicted urgency: 0.5559
#
# Sentence: '[H]C#CC([H])([H])O[H]'
#   True urgency: 0.2515
#   Predicted urgency: 0.5559
#
# Sentence: '[H]OC([H])([H])C#N'
#   True urgency: 0.2668
#   Predicted urgency: 0.5559
#
# Sentence: '[H]C(=O)C([H])([H])C([H])([H])[H]'
#   True urgency: 0.1628
#   Predicted urgency: 0.5559
#
# Sentence: '[H]C(=O)N([H])C([H])([H])[H]'
#   True urgency: 0.2185
#   Predicted urgency: 0.5559
#
# Sentence: '[H]C(=O)OC([H])([H])[H]'
#   True urgency: 0.2205
#   Predicted urgency: 0.5559
#
# Sentence: '[H]OC([H])([H])C([H])=O'
#   True urgency: 0.1573
#   Predicted urgency: 0.5559
#
# Sentence: '[H]C([H])([H])C([H])([H])C([H])([H])C([H])([H])[H]'
#   True urgency: 0.3504
#   Predicted urgency: 0.5559
#
# Sentence: '[H]OC([H])([H])C([H])([H])C([H])([H])[H]'
#   True urgency: 0.2664
#   Predicted urgency: 0.5559
#
# Sentence: '[H]C([H])([H])OC([H])([H])C([H])([H])[H]'
#   True urgency: 0.2725
#   Predicted urgency: 0.5559
#
# Sentence: '[H]OC([H])([H])C([H])([H])O[H]'
#   True urgency: 0.2601
#   Predicted urgency: 0.5559
#
# Sentence: '[H]C([H])([H])C1([H])C([H])([H])C1([H])[H]'
#   True urgency: 0.3121
#   Predicted urgency: 0.5559
#
# Sentence: '[H]C([H])([H])C1([H])OC1([H])[H]'
#   True urgency: 0.2967
#   Predicted urgency: 0.5559
#
# Sentence: '[H]C([H])([H])N1C([H])([H])C1([H])[H]'
#   True urgency: 0.2645
#   Predicted urgency: 0.5559
#
# Sentence: '[H]OC1([H])C([H])([H])C1([H])[H]'
#   True urgency: 0.2518
#   Predicted urgency: 0.5559
#
# Sentence: '[H]C1([H])C([H])([H])C([H])([H])C1([H])[H]'
#   True urgency: 0.3296
#   Predicted urgency: 0.5559
#
# Sentence: '[H]C1([H])OC([H])([H])C1([H])[H]'
#   True urgency: 0.2572
#   Predicted urgency: 0.5559
#
# Sentence: '[H]ON=C(C([H])([H])[H])C([H])([H])[H]'
#   True urgency: 0.2372
#   Predicted urgency: 0.5559
#
# Sentence: '[H]c1c([H])c([H])n([H])c1[H]'
#   True urgency: 0.2342
#   Predicted urgency: 0.5559
#
# Sentence: '[H]c1nc([H])n([H])c1[H]'
#   True urgency: 0.2477
#   Predicted urgency: 0.5559
#
# Sentence: '[H]c1oc([H])c([H])c1[H]'
#   True urgency: 0.2470
#   Predicted urgency: 0.5559
#
# Sentence: '[H]c1nc([H])c([H])o1'
#   True urgency: 0.2466
#   Predicted urgency: 0.5559
#
# Sentence: '[H]C([H])([H])C(C([H])([H])[H])(C([H])([H])[H])C([H])([H])[H]'
#   True urgency: 0.3391
#   Predicted urgency: 0.5559
#
# Sentence: '[H]OC(C([H])([H])[H])(C([H])([H])[H])C([H])([H])[H]'
#   True urgency: 0.2649
#   Predicted urgency: 0.5559
#
# Sentence: '[H]C#CC(=O)C([H])([H])[H]'
#   True urgency: 0.1536
#   Predicted urgency: 0.5559
#
# Sentence: '[H]C([H])([H])C(=O)C#N'
#   True urgency: 0.1562
#   Predicted urgency: 0.5559
#
# Sentence: '[H]C#CC(=O)N([H])[H]'
#   True urgency: 0.1901
#   Predicted urgency: 0.5559
#
# Sentence: '[H]C(=O)C(=O)C([H])([H])[H]'
#   True urgency: 0.1095
#   Predicted urgency: 0.5559
#
# Sentence: '[H]C(=O)C(=O)N([H])[H]'
#   True urgency: 0.1298
#   Predicted urgency: 0.5559
#
# Sentence: '[H]C#CC([H])(C([H])([H])[H])C([H])([H])[H]'
#   True urgency: 0.2712
#   Predicted urgency: 0.5559
#
# Sentence: '[H]C([H])([H])C([H])(C#N)C([H])([H])[H]'
#   True urgency: 0.3157
#   Predicted urgency: 0.5559
#
# Sentence: '[H]N([H])C([H])(C#N)C([H])([H])[H]'
#   True urgency: 0.2608
#   Predicted urgency: 0.5559
#
# Sentence: '[H]C#CC([H])(O[H])C([H])([H])[H]'
#   True urgency: 0.2633
#   Predicted urgency: 0.5559
#
# Sentence: '[H]OC([H])(C#N)C([H])([H])[H]'
#   True urgency: 0.2813
#   Predicted urgency: 0.5559
#
# Sentence: '[H]C(=O)C([H])(C([H])([H])[H])C([H])([H])[H]'
#   True urgency: 0.1624
#   Predicted urgency: 0.5559
#
# Sentence: '[H]OC([H])(C([H])=O)C([H])([H])[H]'
#   True urgency: 0.1607
#   Predicted urgency: 0.5559
#
# Sentence: '[H]C(=O)N(C([H])([H])[H])C([H])([H])[H]'
#   True urgency: 0.2168
#   Predicted urgency: 0.5559
#
# Sentence: '[H]OC([H])([H])C(=O)C([H])([H])[H]'
#   True urgency: 0.1798
#   Predicted urgency: 0.5559
#
# Sentence: '[H]C([H])([H])C(=O)C([H])([H])C([H])([H])[H]'
#   True urgency: 0.1709
#   Predicted urgency: 0.5559
#
# Sentence: '[H]N([H])C(=O)C([H])([H])C([H])([H])[H]'
#   True urgency: 0.2161
#   Predicted urgency: 0.5559
#
# Sentence: '[H]N(C(=O)C([H])([H])[H])C([H])([H])[H]'
#   True urgency: 0.2199
#   Predicted urgency: 0.5559
#
# Sentence: '[H]N([H])C(=O)N([H])C([H])([H])[H]'
#   True urgency: 0.2493
#   Predicted urgency: 0.5559
#
# Sentence: '[H]N=C(OC([H])([H])[H])C([H])([H])[H]'
#   True urgency: 0.2506
#   Predicted urgency: 0.5559
#
# Sentence: '[H]C([H])([H])OC(=O)C([H])([H])[H]'
#   True urgency: 0.2248
#   Predicted urgency: 0.5559
#
# Sentence: '[H]N([H])C(=O)OC([H])([H])[H]'
#   True urgency: 0.2662
#   Predicted urgency: 0.5559
#
# Sentence: '[H]OC([H])([H])C(=O)N([H])[H]'
#   True urgency: 0.2127
#   Predicted urgency: 0.5559
#
# Sentence: '[H]OC([H])([H])C([H])(C([H])([H])[H])C([H])([H])[H]'
#   True urgency: 0.2657
#   Predicted urgency: 0.5559
#
# Sentence: '[H]OC([H])([H])C([H])(O[H])C([H])([H])[H]'
#   True urgency: 0.2754
#   Predicted urgency: 0.5559
#
# Sentence: '[H]C([H])([H])C([H])([H])C([H])(C([H])([H])[H])C([H])([H])[H]'
#   True urgency: 0.3413
#   Predicted urgency: 0.5559
#
# Sentence: '[H]OC([H])(C([H])([H])[H])C([H])([H])C([H])([H])[H]'
#   True urgency: 0.2664
#   Predicted urgency: 0.5559
#
# Sentence: '[H]C([H])([H])OC([H])(C([H])([H])[H])C([H])([H])[H]'
#   True urgency: 0.2721
#   Predicted urgency: 0.5559
#
# Sentence: '[H]C([H])([H])C1(C([H])([H])[H])C([H])([H])C1([H])[H]'
#   True urgency: 0.2954
#   Predicted urgency: 0.5559
#
# Sentence: '[H]C([H])([H])C1(C([H])([H])[H])OC1([H])[H]'
#   True urgency: 0.2858
#   Predicted urgency: 0.5559
#
# Sentence: '[H]OC1(C([H])([H])[H])C([H])([H])C1([H])[H]'
#   True urgency: 0.2639
#   Predicted urgency: 0.5559
#
# Sentence: '[H]N=C1OC([H])([H])C1([H])[H]'
#   True urgency: 0.2565
#   Predicted urgency: 0.5559
#
# Sentence: '[H]C1([H])C(=O)C([H])([H])C1([H])[H]'
#   True urgency: 0.1623
#   Predicted urgency: 0.5559
#
# Sentence: '[H]N1C(=O)C([H])([H])C1([H])[H]'
#   True urgency: 0.2286
#   Predicted urgency: 0.5559
#
# Sentence: '[H]C1([H])OC(=O)C1([H])[H]'
#   True urgency: 0.2289
#   Predicted urgency: 0.5559
#
# Sentence: '[H]N1C([H])([H])C(=O)C1([H])[H]'
#   True urgency: 0.1665
#   Predicted urgency: 0.5559
#
# Sentence: '[H]C1([H])OC([H])([H])C1=O'
#   True urgency: 0.1689
#   Predicted urgency: 0.5559
#
# Sentence: '[H]C([H])([H])C1([H])C([H])([H])C([H])([H])C1([H])[H]'
#   True urgency: 0.3197
#   Predicted urgency: 0.5559
#
# Sentence: '[H]C([H])([H])C1([H])OC([H])([H])C1([H])[H]'
#   True urgency: 0.2642
#   Predicted urgency: 0.5559
#
# Sentence: '[H]C([H])([H])C1([H])C([H])([H])OC1([H])[H]'
#   True urgency: 0.2571
#   Predicted urgency: 0.5559
#
# Sentence: '[H]OC1([H])C([H])([H])C([H])([H])C1([H])[H]'
#   True urgency: 0.2666
#   Predicted urgency: 0.5559
#
# Sentence: '[H]OC1([H])C([H])([H])OC1([H])[H]'
#   True urgency: 0.2526
#   Predicted urgency: 0.5559
#
# Sentence: '[H]C([H])([H])C1([H])C([H])([H])C1([H])C([H])([H])[H]'
#   True urgency: 0.2964
#   Predicted urgency: 0.5559
#
# Sentence: '[H]OC1([H])C([H])([H])C1([H])C([H])([H])[H]'
#   True urgency: 0.2673
#   Predicted urgency: 0.5559
#
# Sentence: '[H]C([H])([H])N1C([H])([H])C1([H])C([H])([H])[H]'
#   True urgency: 0.2527
#   Predicted urgency: 0.5559
#
# Sentence: '[H]C([H])([H])C1([H])OC1([H])C([H])([H])[H]'
#   True urgency: 0.2894
#   Predicted urgency: 0.5559
#
# Sentence: '[H]OC1([H])C([H])([H])C1([H])O[H]'
#   True urgency: 0.2557
#   Predicted urgency: 0.5559
#
# Sentence: '[H]C1([H])C2([H])C([H])([H])C1([H])C2([H])[H]'
#   True urgency: 0.3429
#   Predicted urgency: 0.5559
#
# Sentence: '[H]C1([H])C2([H])OC1([H])C2([H])[H]'
#   True urgency: 0.2658
#   Predicted urgency: 0.5559
#
# Sentence: '[H]C#CC([H])([H])C#C[H]'
#   True urgency: 0.2698
#   Predicted urgency: 0.5559
#
# Sentence: '[H]C#CC([H])([H])C#N'
#   True urgency: 0.2719
#   Predicted urgency: 0.5559
#
# Sentence: '[H]C([H])(C#N)C#N'
#   True urgency: 0.3129
#   Predicted urgency: 0.5559
#
# Sentence: '[H]C#CC([H])([H])C([H])=O'
#   True urgency: 0.1644
#   Predicted urgency: 0.5559
#
# Sentence: '[H]C(=O)C([H])([H])C#N'
#   True urgency: 0.1646
#   Predicted urgency: 0.5559
#
# Sentence: '[H]N=C([H])N([H])C([H])=O'
#   True urgency: 0.1839
#   Predicted urgency: 0.5559
#
# Sentence: '[H]N=C([H])OC([H])=O'
#   True urgency: 0.2142
#   Predicted urgency: 0.5559
#
# Sentence: '[H]C(=O)N([H])C([H])=O'
#   True urgency: 0.1727
#   Predicted urgency: 0.5559
#
# Sentence: '[H]C#CC#CC([H])([H])[H]'
#   True urgency: 0.2040
#   Predicted urgency: 0.5559
#
# Sentence: '[H]C([H])([H])C#CC#N'
#   True urgency: 0.2214
#   Predicted urgency: 0.5559
#
# Sentence: '[H]C(=O)C#CC([H])([H])[H]'
#   True urgency: 0.1490
#   Predicted urgency: 0.5559
#
# Sentence: '[H]OC([H])([H])C#CC([H])([H])[H]'
#   True urgency: 0.2490
#   Predicted urgency: 0.5559
#
# Sentence: '[H]C([H])([H])C#CC([H])([H])C([H])([H])[H]'
#   True urgency: 0.2700
#   Predicted urgency: 0.5559
#
# Sentence: '[H]C(=NC([H])([H])[H])OC([H])([H])[H]'
#   True urgency: 0.2256
#   Predicted urgency: 0.5559
#
# Sentence: '[H]C#CC([H])([H])C([H])([H])C([H])([H])[H]'
#   True urgency: 0.2715
#   Predicted urgency: 0.5559
#
# Sentence: '[H]C([H])([H])C([H])([H])C([H])([H])C#N'
#   True urgency: 0.3166
#   Predicted urgency: 0.5559
#
# Sentence: '[H]N(C([H])([H])[H])C([H])([H])C#N'
#   True urgency: 0.2385
#   Predicted urgency: 0.5559
#
# Sentence: '[H]C#CC([H])([H])OC([H])([H])[H]'
#   True urgency: 0.2562
#   Predicted urgency: 0.5559
#
# Sentence: '[H]C([H])([H])OC([H])([H])C#N'
#   True urgency: 0.2677
#   Predicted urgency: 0.5559
#
# Sentence: '[H]C#CC([H])([H])C([H])([H])O[H]'
#   True urgency: 0.2717
#   Predicted urgency: 0.5559
#
# Sentence: '[H]OC([H])([H])C([H])([H])C#N'
#   True urgency: 0.2759
#   Predicted urgency: 0.5559
#
# Sentence: '[H]C(=O)C([H])([H])C([H])([H])C([H])([H])[H]'
#   True urgency: 0.1625
#   Predicted urgency: 0.5559
#
# Sentence: '[H]C(=O)N([H])C([H])([H])C([H])([H])[H]'
#   True urgency: 0.2173
#   Predicted urgency: 0.5559
#
# Sentence: '[H]C(=O)OC([H])([H])C([H])([H])[H]'
#   True urgency: 0.2192
#   Predicted urgency: 0.5559
#
# Sentence: '[H]C(=O)C([H])([H])OC([H])([H])[H]'
#   True urgency: 0.1622
#   Predicted urgency: 0.5559
#
# Sentence: '[H]OC([H])([H])C([H])([H])C([H])=O'
#   True urgency: 0.1605
#   Predicted urgency: 0.5559
#
# Sentence: '[H]C([H])([H])C([H])([H])C([H])([H])C([H])([H])C([H])([H])[H]'
#   True urgency: 0.3416
#   Predicted urgency: 0.5559
#
# Sentence: '[H]OC([H])([H])C([H])([H])C([H])([H])C([H])([H])[H]'
#   True urgency: 0.2659
#   Predicted urgency: 0.5559
#
# Sentence: '[H]C([H])([H])OC([H])([H])C([H])([H])C([H])([H])[H]'
#   True urgency: 0.2721
#   Predicted urgency: 0.5559
#
# Sentence: '[H]C([H])([H])C([H])([H])OC([H])([H])C([H])([H])[H]'
#   True urgency: 0.2697
#   Predicted urgency: 0.5559
#
# Sentence: '[H]OC([H])([H])C([H])([H])OC([H])([H])[H]'
#   True urgency: 0.2796
#   Predicted urgency: 0.5559
#
# Sentence: '[H]OC([H])([H])C([H])([H])C([H])([H])O[H]'
#   True urgency: 0.2666
#   Predicted urgency: 0.5559
#
# Sentence: '[H]C#CC1([H])C([H])([H])C1([H])[H]'
#   True urgency: 0.2540
#   Predicted urgency: 0.5559
#
# Sentence: '[H]C#CC1([H])N([H])C1([H])[H]'
#   True urgency: 0.2455
#   Predicted urgency: 0.5559
#
# Sentence: '[H]C#CC1([H])OC1([H])[H]'
#   True urgency: 0.2532
#   Predicted urgency: 0.5559
#
# Sentence: '[H]C1([H])C([H])([H])C1([H])C#N'
#   True urgency: 0.2889
#   Predicted urgency: 0.5559
#
# Sentence: '[H]N1C([H])([H])C1([H])C#N'
#   True urgency: 0.2615
#   Predicted urgency: 0.5559
#
# Sentence: '[H]C1([H])OC1([H])C#N'
#   True urgency: 0.2702
#   Predicted urgency: 0.5559
#
# Sentence: '[H]C(=O)C1([H])C([H])([H])C1([H])[H]'
#   True urgency: 0.1684
#   Predicted urgency: 0.5559
#
# Sentence: '[H]C(=O)C1([H])N([H])C1([H])[H]'
#   True urgency: 0.1639
#   Predicted urgency: 0.5559
#
# Sentence: '[H]C(=O)C1([H])OC1([H])[H]'
#   True urgency: 0.1606
#   Predicted urgency: 0.5559
#
# Sentence: '[H]C(=O)N1C([H])([H])C1([H])[H]'
#   True urgency: 0.1941
#   Predicted urgency: 0.5559
#
# Sentence: '[H]C([H])([H])C([H])([H])C1([H])C([H])([H])C1([H])[H]'
#   True urgency: 0.3114
#   Predicted urgency: 0.5559
#
# Sentence: '[H]C([H])([H])C([H])([H])C1([H])OC1([H])[H]'
#   True urgency: 0.2958
#   Predicted urgency: 0.5559
#
# Sentence: '[H]C([H])([H])C([H])([H])N1C([H])([H])C1([H])[H]'
#   True urgency: 0.2626
#   Predicted urgency: 0.5559
#
# Sentence: '[H]C([H])([H])OC1([H])C([H])([H])C1([H])[H]'
#   True urgency: 0.2775
#   Predicted urgency: 0.5559
#
# Sentence: '[H]OC([H])([H])C1([H])C([H])([H])C1([H])[H]'
#   True urgency: 0.2651
#   Predicted urgency: 0.5559
#
# Sentence: '[H]OC([H])([H])C1([H])N([H])C1([H])[H]'
#   True urgency: 0.2655
#   Predicted urgency: 0.5559
#
# Sentence: '[H]OC([H])([H])C1([H])OC1([H])[H]'
#   True urgency: 0.2804
#   Predicted urgency: 0.5559
#
# Sentence: '[H]C1=C([H])C([H])([H])C([H])([H])C1([H])[H]'
#   True urgency: 0.2763
#   Predicted urgency: 0.5559
#
# Sentence: '[H]C1=NC([H])([H])C([H])([H])O1'
#   True urgency: 0.2501
#   Predicted urgency: 0.5559
#
# Sentence: '[H]C1=C([H])C([H])([H])OC1([H])[H]'
#   True urgency: 0.2344
#   Predicted urgency: 0.5559
#
# Sentence: '[H]C1([H])C([H])([H])C([H])([H])C([H])([H])C1([H])[H]'
#   True urgency: 0.3380
#   Predicted urgency: 0.5559
#
# Sentence: '[H]C1([H])OC([H])([H])C([H])([H])C1([H])[H]'
#   True urgency: 0.2677
#   Predicted urgency: 0.5559
#
# Sentence: '[H]C1([H])OC([H])([H])C([H])([H])O1'
#   True urgency: 0.2805
#   Predicted urgency: 0.5559
#
# Sentence: '[H]C1([H])C([H])([H])C2([H])C([H])([H])C12[H]'
#   True urgency: 0.2921
#   Predicted urgency: 0.5559
#
# Sentence: '[H]C1([H])OC2([H])C([H])([H])C12[H]'
#   True urgency: 0.2545
#   Predicted urgency: 0.5559
#
# Sentence: '[H]C1([H])C([H])([H])C2([H])OC12[H]'
#   True urgency: 0.2836
#   Predicted urgency: 0.5559
#
# Sentence: '[H]c1nn([H])c([H])c1[H]'
#   True urgency: 0.2430
#   Predicted urgency: 0.5559
#
# Sentence: '[H]c1nnn([H])c1[H]'
#   True urgency: 0.2240
#   Predicted urgency: 0.5559
#
# Sentence: '[H]c1nc([H])n([H])n1'
#   True urgency: 0.2597
#   Predicted urgency: 0.5559
#
# Sentence: '[H]c1nnc([H])n1[H]'
#   True urgency: 0.2285
#   Predicted urgency: 0.5559
#
# Sentence: '[H]c1nn([H])nc1[H]'
#   True urgency: 0.2396
#   Predicted urgency: 0.5559
#
# Sentence: '[H]c1noc([H])c1[H]'
#   True urgency: 0.2434
#   Predicted urgency: 0.5559
#
# Sentence: '[H]c1nnoc1[H]'
#   True urgency: 0.2204
#   Predicted urgency: 0.5559
#
# Sentence: '[H]c1noc([H])n1'
#   True urgency: 0.2307
#   Predicted urgency: 0.5559
#
# Sentence: '[H]c1nnc([H])o1'
#   True urgency: 0.2302
#   Predicted urgency: 0.5559
#
# Sentence: '[H]c1nnno1'
#   True urgency: 0.2224
#   Predicted urgency: 0.5559
#
# Sentence: '[H]c1nonc1[H]'
#   True urgency: 0.2407
#   Predicted urgency: 0.5559
#
# Sentence: '[H]c1nnon1'
#   True urgency: 0.2139
#   Predicted urgency: 0.5559
#
# Sentence: 'n1nnon1'
#   True urgency: 0.2135
#   Predicted urgency: 0.5559
#
# Sentence: '[H]C#CC(=NO[H])C([H])([H])[H]'
#   True urgency: 0.2119
#   Predicted urgency: 0.5559
#
# Sentence: '[H]ON=C(C([H])([H])[H])C([H])([H])O[H]'
#   True urgency: 0.2443
#   Predicted urgency: 0.5559
#
# Sentence: '[H]ON=C(C([H])([H])[H])C([H])([H])C([H])([H])[H]'
#   True urgency: 0.2349
#   Predicted urgency: 0.5559
#
# Sentence: '[H]ON=C1C([H])([H])C([H])([H])C1([H])[H]'
#   True urgency: 0.2262
#   Predicted urgency: 0.5559
#
# Sentence: '[H]ON=C1C([H])([H])N([H])C1([H])[H]'
#   True urgency: 0.2170
#   Predicted urgency: 0.5559
#
# Sentence: '[H]ON=C1C([H])([H])OC1([H])[H]'
#   True urgency: 0.2307
#   Predicted urgency: 0.5559
#
# Sentence: 'FC(F)(F)F'
#   True urgency: 0.5138
#   Predicted urgency: 0.5559
#
# Sentence: '[H]c1c([H])n([H])c(=O)n1[H]'
#   True urgency: 0.2180
#   Predicted urgency: 0.5559
#
# Sentence: '[H]c1oc(=O)n([H])c1[H]'
#   True urgency: 0.2349
#   Predicted urgency: 0.5559
#
# Sentence: '[H]c1oc(=O)oc1[H]'
#   True urgency: 0.2581
#   Predicted urgency: 0.5559
#
# Sentence: '[H]c1c([H])c(C([H])([H])[H])n([H])c1[H]'
#   True urgency: 0.2242
#   Predicted urgency: 0.5559
#
# Sentence: '[H]c1oc(C([H])([H])[H])c([H])c1[H]'
#   True urgency: 0.2405
#   Predicted urgency: 0.5559
#
# Sentence: '[H]c1nc([H])c(C([H])([H])[H])o1'
#   True urgency: 0.2407
#   Predicted urgency: 0.5559
#
# Sentence: '[H]c1nc(C([H])([H])[H])oc1[H]'
#   True urgency: 0.2468
#   Predicted urgency: 0.5559
#
# Sentence: '[H]c1c([H])c(N([H])[H])n([H])c1[H]'
#   True urgency: 0.2158
#   Predicted urgency: 0.5559
#
# Sentence: '[H]c1oc(N([H])[H])c([H])c1[H]'
#   True urgency: 0.2113
#   Predicted urgency: 0.5559
#
# Sentence: '[H]c1nc([H])c(N([H])[H])o1'
#   True urgency: 0.2174
#   Predicted urgency: 0.5559
#
# Sentence: '[H]c1nc(N([H])[H])oc1[H]'
#   True urgency: 0.2321
#   Predicted urgency: 0.5559
#
# Sentence: '[H]Oc1c([H])c([H])c([H])n1[H]'
#   True urgency: 0.2072
#   Predicted urgency: 0.5559
#
# Sentence: '[H]Oc1c([H])nc([H])n1[H]'
#   True urgency: 0.2162
#   Predicted urgency: 0.5559
#
# Sentence: '[H]Oc1nc([H])c([H])n1[H]'
#   True urgency: 0.2318
#   Predicted urgency: 0.5559
#
# Sentence: '[H]c1c(C([H])([H])[H])c([H])n([H])c1[H]'
#   True urgency: 0.2305
#   Predicted urgency: 0.5559
#
# Sentence: '[H]c1nc(C([H])([H])[H])c([H])n1[H]'
#   True urgency: 0.2388
#   Predicted urgency: 0.5559
#
# Sentence: '[H]c1oc([H])c(C([H])([H])[H])c1[H]'
#   True urgency: 0.2410
#   Predicted urgency: 0.5559
#
# Sentence: '[H]c1nc(C([H])([H])[H])c([H])o1'
#   True urgency: 0.2391
#   Predicted urgency: 0.5559
#
# Sentence: '[H]c1c(N([H])[H])c([H])n([H])c1[H]'
#   True urgency: 0.2062
#   Predicted urgency: 0.5559
#
# Sentence: '[H]c1nc(N([H])[H])c([H])n1[H]'
#   True urgency: 0.2110
#   Predicted urgency: 0.5559
#
# Sentence: '[H]c1oc([H])c(N([H])[H])c1[H]'
#   True urgency: 0.2133
#   Predicted urgency: 0.5559
#
# Sentence: '[H]c1nc(N([H])[H])c([H])o1'
#   True urgency: 0.2065
#   Predicted urgency: 0.5559
#
# Sentence: '[H]Oc1c([H])c([H])n([H])c1[H]'
#   True urgency: 0.2155
#   Predicted urgency: 0.5559
#
# Sentence: '[H]Oc1nc([H])n([H])c1[H]'
#   True urgency: 0.2181
#   Predicted urgency: 0.5559
#
# Sentence: '[H]Oc1nc([H])oc1[H]'
#   True urgency: 0.2138
#   Predicted urgency: 0.5559
#
# Sentence: '[H]c1c([H])c([H])n(C([H])([H])[H])c1[H]'
#   True urgency: 0.2414
#   Predicted urgency: 0.5559
#
# Sentence: '[H]c1nc([H])n(C([H])([H])[H])c1[H]'
#   True urgency: 0.2427
#   Predicted urgency: 0.5559
#
# Sentence: '[H]c1c([H])c([H])c([H])c([H])c1[H]'
#   True urgency: 0.1946
#   Predicted urgency: 0.5559
#
# Sentence: '[H]c1nc([H])c([H])c([H])c1[H]'
#   True urgency: 0.1971
#   Predicted urgency: 0.5559
#
# Sentence: '[H]c1nc([H])c([H])nc1[H]'
#   True urgency: 0.1912
#   Predicted urgency: 0.5559
#
# Sentence: '[H]c1nc([H])c([H])c([H])n1'
#   True urgency: 0.2048
#   Predicted urgency: 0.5559
#
# Sentence: '[H]c1nc([H])nc([H])n1'
#   True urgency: 0.1754
#   Predicted urgency: 0.5559
#
# Sentence: '[H]C#CC(C([H])([H])[H])(C([H])([H])[H])C([H])([H])[H]'
#   True urgency: 0.2725
#   Predicted urgency: 0.5559
#
# Sentence: '[H]C([H])([H])C(C#N)(C([H])([H])[H])C([H])([H])[H]'
#   True urgency: 0.3307
#   Predicted urgency: 0.5559
#
# Sentence: '[H]N([H])C(C#N)(C([H])([H])[H])C([H])([H])[H]'
#   True urgency: 0.2615
#   Predicted urgency: 0.5559
#
# Sentence: '[H]C#CC(O[H])(C([H])([H])[H])C([H])([H])[H]'
#   True urgency: 0.2639
#   Predicted urgency: 0.5559
#
# Sentence: '[H]OC(C#N)(C([H])([H])[H])C([H])([H])[H]'
#   True urgency: 0.2759
#   Predicted urgency: 0.5559
#
# Sentence: '[H]C(=O)C(C([H])([H])[H])(C([H])([H])[H])C([H])([H])[H]'
#   True urgency: 0.1637
#   Predicted urgency: 0.5559
#
# Sentence: '[H]OC(C([H])=O)(C([H])([H])[H])C([H])([H])[H]'
#   True urgency: 0.1603
#   Predicted urgency: 0.5559
#
# Sentence: '[H]OC([H])([H])C(C([H])([H])[H])(C([H])([H])[H])C([H])([H])[H]'
#   True urgency: 0.2640
#   Predicted urgency: 0.5559
#
# Sentence: '[H]OC([H])([H])C(O[H])(C([H])([H])[H])C([H])([H])[H]'
#   True urgency: 0.2668
#   Predicted urgency: 0.5559
#
# Sentence: '[H]C([H])([H])C([H])([H])C(C([H])([H])[H])(C([H])([H])[H])C([H])([H])[H]'
#   True urgency: 0.3294
#   Predicted urgency: 0.5559
#
# Sentence: '[H]OC(C([H])([H])[H])(C([H])([H])[H])C([H])([H])C([H])([H])[H]'
#   True urgency: 0.2639
#   Predicted urgency: 0.5559
#
# Sentence: '[H]C([H])([H])OC(C([H])([H])[H])(C([H])([H])[H])C([H])([H])[H]'
#   True urgency: 0.2678
#   Predicted urgency: 0.5559
#
# Sentence: '[H]C([H])([H])C#CC(=O)C([H])([H])[H]'
#   True urgency: 0.1547
#   Predicted urgency: 0.5559
#
# Sentence: '[H]N([H])C(=O)C#CC([H])([H])[H]'
#   True urgency: 0.1911
#   Predicted urgency: 0.5559
#
# Sentence: '[H]C([H])([H])C#CC([H])(C([H])([H])[H])C([H])([H])[H]'
#   True urgency: 0.2698
#   Predicted urgency: 0.5559
#
# Sentence: '[H]OC([H])(C#CC([H])([H])[H])C([H])([H])[H]'
#   True urgency: 0.2611
#   Predicted urgency: 0.5559
#
# Sentence: '[H]C#CC([H])([H])C(=O)C([H])([H])[H]'
#   True urgency: 0.1699
#   Predicted urgency: 0.5559
#
# Sentence: '[H]C([H])([H])C(=O)C([H])([H])C#N'
#   True urgency: 0.1733
#   Predicted urgency: 0.5559
#
# Sentence: '[H]C#CC([H])([H])C(=O)N([H])[H]'
#   True urgency: 0.2166
#   Predicted urgency: 0.5559
#
# Sentence: '[H]N([H])C(=O)C([H])([H])C#N'
#   True urgency: 0.2181
#   Predicted urgency: 0.5559
#
# Sentence: '[H]N=C(N([H])C([H])=O)C([H])([H])[H]'
#   True urgency: 0.2008
#   Predicted urgency: 0.5559
#
# Sentence: '[H]N=C(OC([H])=O)C([H])([H])[H]'
#   True urgency: 0.2020
#   Predicted urgency: 0.5559
#
# Sentence: '[H]C(=O)C([H])([H])C(=O)C([H])([H])[H]'
#   True urgency: 0.1607
#   Predicted urgency: 0.5559
#
# Sentence: '[H]N=C([H])N([H])C(=O)C([H])([H])[H]'
#   True urgency: 0.1858
#   Predicted urgency: 0.5559
#
# Sentence: '[H]C(=O)N([H])C(=O)C([H])([H])[H]'
#   True urgency: 0.1757
#   Predicted urgency: 0.5559
#
# Sentence: '[H]N=C([H])OC(=O)C([H])([H])[H]'
#   True urgency: 0.2129
#   Predicted urgency: 0.5559
#
# Sentence: '[H]C(=O)C([H])([H])C(=O)N([H])[H]'
#   True urgency: 0.1628
#   Predicted urgency: 0.5559
#
# Sentence: '[H]N=C([H])N([H])C(=O)N([H])[H]'
#   True urgency: 0.2098
#   Predicted urgency: 0.5559
#
# Sentence: '[H]C(=O)N([H])C(=O)N([H])[H]'
#   True urgency: 0.1919
#   Predicted urgency: 0.5559
#
# Sentence: '[H]N=C([H])OC(=O)N([H])[H]'
#   True urgency: 0.2320
#   Predicted urgency: 0.5559
#
# Sentence: '[H]C#CC([H])([H])C([H])(C([H])([H])[H])C([H])([H])[H]'
#   True urgency: 0.2703
#   Predicted urgency: 0.5559
#
# Sentence: '[H]C([H])([H])C([H])(C([H])([H])[H])C([H])([H])C#N'
#   True urgency: 0.3155
#   Predicted urgency: 0.5559
#
# Sentence: '[H]C#CC([H])([H])C([H])(O[H])C([H])([H])[H]'
#   True urgency: 0.2708
#   Predicted urgency: 0.5559
#
# Sentence: '[H]OC([H])(C([H])([H])[H])C([H])([H])C#N'
#   True urgency: 0.2736
#   Predicted urgency: 0.5559
#
# Sentence: '[H]C([H])([H])N(C([H])([H])[H])C([H])([H])C#N'
#   True urgency: 0.2320
#   Predicted urgency: 0.5559
#
# Sentence: '[H]C(=O)C([H])([H])C([H])(C([H])([H])[H])C([H])([H])[H]'
#   True urgency: 0.1621
#   Predicted urgency: 0.5559
#
# Sentence: '[H]C(=O)N([H])C([H])(C([H])([H])[H])C([H])([H])[H]'
#   True urgency: 0.2170
#   Predicted urgency: 0.5559
#
# Sentence: '[H]C(=O)OC([H])(C([H])([H])[H])C([H])([H])[H]'
#   True urgency: 0.2188
#   Predicted urgency: 0.5559
#
# Sentence: '[H]OC([H])(C([H])([H])[H])C([H])([H])C([H])=O'
#   True urgency: 0.1592
#   Predicted urgency: 0.5559
#
# Sentence: '[H]C(=O)C([H])([H])N(C([H])([H])[H])C([H])([H])[H]'
#   True urgency: 0.1611
#   Predicted urgency: 0.5559
#
# Sentence: '[H]OC([H])([H])C([H])([H])C(=O)C([H])([H])[H]'
#   True urgency: 0.1707
#   Predicted urgency: 0.5559
#
# Sentence: '[H]C([H])([H])C(=O)C([H])([H])C([H])([H])C([H])([H])[H]'
#   True urgency: 0.1704
#   Predicted urgency: 0.5559
#
# Sentence: '[H]N([H])C(=O)C([H])([H])C([H])([H])C([H])([H])[H]'
#   True urgency: 0.2158
#   Predicted urgency: 0.5559
#
# Sentence: '[H]N(C(=O)C([H])([H])[H])C([H])([H])C([H])([H])[H]'
#   True urgency: 0.2182
#   Predicted urgency: 0.5559
#
# Sentence: '[H]N([H])C(=O)N([H])C([H])([H])C([H])([H])[H]'
#   True urgency: 0.2482
#   Predicted urgency: 0.5559
#
# Sentence: '[H]C([H])([H])C(=O)OC([H])([H])C([H])([H])[H]'
#   True urgency: 0.2238
#   Predicted urgency: 0.5559
#
# Sentence: '[H]N([H])C(=O)OC([H])([H])C([H])([H])[H]'
#   True urgency: 0.2651
#   Predicted urgency: 0.5559
#
# Sentence: '[H]C([H])([H])OC([H])([H])C(=O)C([H])([H])[H]'
#   True urgency: 0.1706
#   Predicted urgency: 0.5559
#
# Sentence: '[H]N([H])C(=O)C([H])([H])OC([H])([H])[H]'
#   True urgency: 0.2130
#   Predicted urgency: 0.5559
#
# Sentence: '[H]OC([H])([H])C([H])([H])C(=O)N([H])[H]'
#   True urgency: 0.2170
#   Predicted urgency: 0.5559
#
# Sentence: '[H]C([H])(C(=O)[O-])C([H])([H])[N+]([H])([H])[H]'
#   True urgency: 0.1349
#   Predicted urgency: 0.5559
#
# Sentence: '[H]OC([H])([H])C([H])([H])C([H])(C([H])([H])[H])C([H])([H])[H]'
#   True urgency: 0.2653
#   Predicted urgency: 0.5559
#
# Sentence: '[H]OC([H])([H])C([H])([H])C([H])(O[H])C([H])([H])[H]'
#   True urgency: 0.2665
#   Predicted urgency: 0.5559
#
# Sentence: '[H]C([H])([H])C([H])([H])C([H])([H])C([H])(C([H])([H])[H])C([H])([H])[H]'
#   True urgency: 0.3360
#   Predicted urgency: 0.5559
#
# Sentence: '[H]OC([H])(C([H])([H])[H])C([H])([H])C([H])([H])C([H])([H])[H]'
#   True urgency: 0.2675
#   Predicted urgency: 0.5559
#
# Sentence: '[H]C([H])([H])C([H])([H])OC([H])(C([H])([H])[H])C([H])([H])[H]'
#   True urgency: 0.2692
#   Predicted urgency: 0.5559
#
# Sentence: '[H]C([H])([H])OC([H])([H])C([H])(C([H])([H])[H])C([H])([H])[H]'
#   True urgency: 0.2719
#   Predicted urgency: 0.5559
#
# Sentence: '[H]OC([H])(C([H])([H])[H])C([H])([H])OC([H])([H])[H]'
#   True urgency: 0.2762
#   Predicted urgency: 0.5559
#
# Sentence: '[H]C([H])([H])C(=O)C(=O)C([H])([H])[H]'
#   True urgency: 0.1095
#   Predicted urgency: 0.5559
#
# Sentence: '[H]N([H])C(=O)C(=O)C([H])([H])[H]'
#   True urgency: 0.1307
#   Predicted urgency: 0.5559
#
# Sentence: '[H]N([H])C(C(=O)[O-])=[N+]([H])[H]'
#   True urgency: 0.1629
#   Predicted urgency: 0.5559
#
# Sentence: '[H]N([H])C(=O)C(=O)N([H])[H]'
#   True urgency: 0.1627
#   Predicted urgency: 0.5559
#
# Sentence: '[H]C([H])([H])C(=O)C([H])(C([H])([H])[H])C([H])([H])[H]'
#   True urgency: 0.1670
#   Predicted urgency: 0.5559
#
# Sentence: '[H]N([H])C(=O)C([H])(C([H])([H])[H])C([H])([H])[H]'
#   True urgency: 0.2159
#   Predicted urgency: 0.5559
#
# Sentence: '[H]OC([H])(C(=O)C([H])([H])[H])C([H])([H])[H]'
#   True urgency: 0.1763
#   Predicted urgency: 0.5559
#
# Sentence: '[H]OC([H])(C(=O)N([H])[H])C([H])([H])[H]'
#   True urgency: 0.2245
#   Predicted urgency: 0.5559
#
# Sentence: '[H]C([H])([H])C(=O)N(C([H])([H])[H])C([H])([H])[H]'
#   True urgency: 0.2155
#   Predicted urgency: 0.5559
#
# Sentence: '[H]N([H])C(=O)N(C([H])([H])[H])C([H])([H])[H]'
#   True urgency: 0.2416
#   Predicted urgency: 0.5559
#
# Sentence: '[H]C([H])([H])C([H])(C([H])([H])[H])C([H])(C([H])([H])[H])C([H])([H])[H]'
#   True urgency: 0.3355
#   Predicted urgency: 0.5559
#
# Sentence: '[H]OC([H])(C([H])([H])[H])C([H])(C([H])([H])[H])C([H])([H])[H]'
#   True urgency: 0.2641
#   Predicted urgency: 0.5559
#
# Sentence: '[H]OC([H])(C([H])([H])[H])C([H])(O[H])C([H])([H])[H]'
#   True urgency: 0.2635
#   Predicted urgency: 0.5559
#
# Sentence: '[H]C([H])([H])C1(C([H])([H])[H])C([H])([H])C([H])([H])C1([H])[H]'
#   True urgency: 0.3088
#   Predicted urgency: 0.5559
#
# Sentence: '[H]C([H])([H])C1(C([H])([H])[H])OC([H])([H])C1([H])[H]'
#   True urgency: 0.2585
#   Predicted urgency: 0.5559
#
# Sentence: '[H]C([H])([H])C1(C([H])([H])[H])C([H])([H])OC1([H])[H]'
#   True urgency: 0.2560
#   Predicted urgency: 0.5559
#
# Sentence: '[H]OC1(C([H])([H])[H])C([H])([H])C([H])([H])C1([H])[H]'
#   True urgency: 0.2625
#   Predicted urgency: 0.5559
#
# Sentence: '[H]OC1(C([H])([H])[H])C([H])([H])OC1([H])[H]'
#   True urgency: 0.2555
#   Predicted urgency: 0.5559
#
# Sentence: '[H]OC1([H])C([H])([H])C1(C([H])([H])[H])C([H])([H])[H]'
#   True urgency: 0.2656
#   Predicted urgency: 0.5559
#
# Sentence: '[H]OC1([H])C([H])([H])C1(O[H])C([H])([H])[H]'
#   True urgency: 0.2648
#   Predicted urgency: 0.5559
#
# Sentence: '[H]C([H])([H])C1([H])C([H])([H])C1(C([H])([H])[H])C([H])([H])[H]'
#   True urgency: 0.2858
#   Predicted urgency: 0.5559
#
# Sentence: '[H]OC1(C([H])([H])[H])C([H])([H])C1([H])C([H])([H])[H]'
#   True urgency: 0.2625
#   Predicted urgency: 0.5559
#
# Sentence: '[H]C([H])([H])C1([H])OC1(C([H])([H])[H])C([H])([H])[H]'
#   True urgency: 0.2806
#   Predicted urgency: 0.5559
#
# Sentence: '[H]C([H])([H])N1C([H])([H])C1(C([H])([H])[H])C([H])([H])[H]'
#   True urgency: 0.2466
#   Predicted urgency: 0.5559
#
# Sentence: '[H]N=C1OC([H])(C([H])([H])[H])C1([H])[H]'
#   True urgency: 0.2556
#   Predicted urgency: 0.5559
#
# Sentence: '[H]C([H])([H])C1([H])C([H])([H])C(=O)C1([H])[H]'
#   True urgency: 0.1628
#   Predicted urgency: 0.5559
#
# Sentence: '[H]N1C(=O)C([H])([H])C1([H])C([H])([H])[H]'
#   True urgency: 0.2263
#   Predicted urgency: 0.5559
#
# Sentence: '[H]C([H])([H])C1([H])OC(=O)C1([H])[H]'
#   True urgency: 0.2273
#   Predicted urgency: 0.5559
#
# Sentence: '[H]C([H])([H])N1C([H])([H])C(=O)C1([H])[H]'
#   True urgency: 0.1927
#   Predicted urgency: 0.5559
#
# Sentence: '[H]OC1([H])C([H])([H])C(=O)C1([H])[H]'
#   True urgency: 0.1618
#   Predicted urgency: 0.5559
#
# Sentence: '[H]C([H])([H])C1([H])C([H])([H])C([H])(C([H])([H])[H])C1([H])[H]'
#   True urgency: 0.3105
#   Predicted urgency: 0.5559
#
# Sentence: '[H]C([H])([H])C1([H])OC([H])(C([H])([H])[H])C1([H])[H]'
#   True urgency: 0.2676
#   Predicted urgency: 0.5559
#
# Sentence: '[H]OC1([H])C([H])([H])C([H])(C([H])([H])[H])C1([H])[H]'
#   True urgency: 0.2604
#   Predicted urgency: 0.5559
#
# Sentence: '[H]OC1([H])C([H])([H])N(C([H])([H])[H])C1([H])[H]'
#   True urgency: 0.2374
#   Predicted urgency: 0.5559
#
# Sentence: '[H]OC1([H])C([H])([H])C([H])(O[H])C1([H])[H]'
#   True urgency: 0.2596
#   Predicted urgency: 0.5559
#
# Sentence: '[H]C([H])([H])C12C([H])([H])C([H])(C1([H])[H])C2([H])[H]'
#   True urgency: 0.3257
#   Predicted urgency: 0.5559
#
# Sentence: '[H]C([H])([H])C12OC([H])(C1([H])[H])C2([H])[H]'
#   True urgency: 0.2559
#   Predicted urgency: 0.5559
#
# Sentence: '[H]C([H])([H])C12C([H])([H])N(C1([H])[H])C2([H])[H]'
#   True urgency: 0.2383
#   Predicted urgency: 0.5559
#
# Sentence: '[H]OC12C([H])([H])C([H])(C1([H])[H])C2([H])[H]'
#   True urgency: 0.2655
#   Predicted urgency: 0.5559
#
# Sentence: '[H]OC12C([H])([H])N(C1([H])[H])C2([H])[H]'
#   True urgency: 0.2519
#   Predicted urgency: 0.5559
#
# Sentence: '[H]C#CC(=O)C#C[H]'
#   True urgency: 0.1426
#   Predicted urgency: 0.5559
#
# Sentence: '[H]C#CC(=O)C#N'
#   True urgency: 0.1450
#   Predicted urgency: 0.5559
#
# Sentence: 'N#CC(=O)C#N'
#   True urgency: 0.1457
#   Predicted urgency: 0.5559
#
# Sentence: '[H]C#CC(=O)C([H])=O'
#   True urgency: 0.1044
#   Predicted urgency: 0.5559
#
# Sentence: '[H]C(=O)C(=O)C#N'
#   True urgency: 0.1042
#   Predicted urgency: 0.5559
#
# Sentence: '[H]C#CC([H])(C#C[H])C([H])([H])[H]'
#   True urgency: 0.2728
#   Predicted urgency: 0.5559
#
# Sentence: '[H]C#CC([H])(C#N)C([H])([H])[H]'
#   True urgency: 0.2708
#   Predicted urgency: 0.5559
#
# Sentence: '[H]C([H])([H])C([H])(C#N)C#N'
#   True urgency: 0.3109
#   Predicted urgency: 0.5559
#
# Sentence: '[H]C#CC([H])(C#N)N([H])[H]'
#   True urgency: 0.2562
#   Predicted urgency: 0.5559
#
# Sentence: '[H]N([H])C([H])(C#N)C#N'
#   True urgency: 0.2585
#   Predicted urgency: 0.5559
#
# Sentence: '[H]C#CC([H])(C#C[H])O[H]'
#   True urgency: 0.2578
#   Predicted urgency: 0.5559
#
# Sentence: '[H]C#CC([H])(C#N)O[H]'
#   True urgency: 0.2595
#   Predicted urgency: 0.5559
#
# Sentence: '[H]OC([H])(C#N)C#N'
#   True urgency: 0.2795
#   Predicted urgency: 0.5559
#
# Sentence: '[H]C#CC([H])(C([H])=O)C([H])([H])[H]'
#   True urgency: 0.1634
#   Predicted urgency: 0.5559
#
# Sentence: '[H]C(=O)C([H])(C#N)C([H])([H])[H]'
#   True urgency: 0.1629
#   Predicted urgency: 0.5559
#
# Sentence: '[H]C#CC([H])(O[H])C([H])=O'
#   True urgency: 0.1731
#   Predicted urgency: 0.5559
#
# Sentence: '[H]OC([H])(C#N)C([H])=O'
#   True urgency: 0.1733
#   Predicted urgency: 0.5559
#
# Sentence: '[H]C(=O)C([H])(C([H])=O)C([H])([H])[H]'
#   True urgency: 0.1510
#   Predicted urgency: 0.5559
#
# Sentence: '[H]N=C([H])N(C([H])=O)C([H])([H])[H]'
#   True urgency: 0.2046
#   Predicted urgency: 0.5559
#
# Sentence: '[H]C(=O)N(C([H])=O)C([H])([H])[H]'
#   True urgency: 0.1913
#   Predicted urgency: 0.5559
#
# Sentence: '[H]OC([H])(C([H])=O)C([H])=O'
#   True urgency: 0.1572
#   Predicted urgency: 0.5559
#
# Sentence: '[H]N([H])C(C#N)=NC([H])([H])[H]'
#   True urgency: 0.2015
#   Predicted urgency: 0.5559
#
# Sentence: '[H]C(=O)C(=NC([H])([H])[H])N([H])[H]'
#   True urgency: 0.1494
#   Predicted urgency: 0.5559
#
# Sentence: '[H]C#CC(=O)C([H])([H])C([H])([H])[H]'
#   True urgency: 0.1545
#   Predicted urgency: 0.5559
#
# Sentence: '[H]C([H])([H])C([H])([H])C(=O)C#N'
#   True urgency: 0.1569
#   Predicted urgency: 0.5559
#
# Sentence: '[H]N=C(C#N)N([H])C([H])([H])[H]'
#   True urgency: 0.2121
#   Predicted urgency: 0.5559
#
# Sentence: '[H]C#CC(=O)N([H])C([H])([H])[H]'
#   True urgency: 0.1919
#   Predicted urgency: 0.5559
#
# Sentence: '[H]C#CC(=O)OC([H])([H])[H]'
#   True urgency: 0.1961
#   Predicted urgency: 0.5559
#
# Sentence: '[H]C([H])([H])OC(=O)C#N'
#   True urgency: 0.2017
#   Predicted urgency: 0.5559
#
# Sentence: '[H]C#CC(=O)C([H])([H])O[H]'
#   True urgency: 0.1547
#   Predicted urgency: 0.5559
#
# Sentence: '[H]OC([H])([H])C(=O)C#N'
#   True urgency: 0.1572
#   Predicted urgency: 0.5559
#
# Sentence: '[H]C(=O)C(=O)C([H])([H])C([H])([H])[H]'
#   True urgency: 0.1094
#   Predicted urgency: 0.5559
#
# Sentence: '[H]N=C(C([H])=O)N([H])C([H])([H])[H]'
#   True urgency: 0.1437
#   Predicted urgency: 0.5559
#
# Sentence: '[H]C(=O)C(=O)N([H])C([H])([H])[H]'
#   True urgency: 0.1312
#   Predicted urgency: 0.5559
#
# Sentence: '[H]C(=O)C(=O)OC([H])([H])[H]'
#   True urgency: 0.1326
#   Predicted urgency: 0.5559
#
# Sentence: '[H]OC([H])([H])C(=O)C([H])=O'
#   True urgency: 0.1079
#   Predicted urgency: 0.5559
#
# Sentence: '[H]C([H])([H])C([H])([H])C(=O)C([H])([H])C([H])([H])[H]'
#   True urgency: 0.1715
#   Predicted urgency: 0.5559
#
# Sentence: '[H]OC([H])([H])C(=O)C([H])([H])C([H])([H])[H]'
#   True urgency: 0.1714
#   Predicted urgency: 0.5559
#
# Sentence: '[H]N(C(=O)C([H])([H])C([H])([H])[H])C([H])([H])[H]'
#   True urgency: 0.2187
#   Predicted urgency: 0.5559
#
# Sentence: '[H]C([H])([H])OC(=O)C([H])([H])C([H])([H])[H]'
#   True urgency: 0.2255
#   Predicted urgency: 0.5559
#
# Sentence: '[H]OC([H])([H])C(=O)N([H])C([H])([H])[H]'
#   True urgency: 0.2133
#   Predicted urgency: 0.5559
#
# Sentence: '[H]N(C(=O)N([H])C([H])([H])[H])C([H])([H])[H]'
#   True urgency: 0.2378
#   Predicted urgency: 0.5559
#
# Sentence: '[H]N(C(=O)OC([H])([H])[H])C([H])([H])[H]'
#   True urgency: 0.2651
#   Predicted urgency: 0.5559
#
# Sentence: '[H]N([H])C([H])([H])C(=O)OC([H])([H])[H]'
#   True urgency: 0.2262
#   Predicted urgency: 0.5559
#
# Sentence: '[H]OC([H])([H])C(=O)OC([H])([H])[H]'
#   True urgency: 0.2347
#   Predicted urgency: 0.5559
#
# Sentence: '[H]OC([H])([H])C(=O)C([H])([H])O[H]'
#   True urgency: 0.1707
#   Predicted urgency: 0.5559
#
# Sentence: '[H]C([H])([H])N=C(OC([H])([H])[H])C([H])([H])[H]'
#   True urgency: 0.2306
#   Predicted urgency: 0.5559
#
# Sentence: '[H]C#CC([H])(C([H])([H])[H])C([H])([H])O[H]'
#   True urgency: 0.2717
#   Predicted urgency: 0.5559
#
# Sentence: '[H]OC([H])([H])C([H])(C#N)C([H])([H])[H]'
#   True urgency: 0.2741
#   Predicted urgency: 0.5559
#
# Sentence: '[H]C#CC([H])(C([H])([H])[H])C([H])([H])C([H])([H])[H]'
#   True urgency: 0.2713
#   Predicted urgency: 0.5559
#
# Sentence: '[H]C([H])([H])C([H])([H])C([H])(C#N)C([H])([H])[H]'
#   True urgency: 0.3156
#   Predicted urgency: 0.5559
#
# Sentence: '[H]N([H])C([H])(C#N)C([H])([H])C([H])([H])[H]'
#   True urgency: 0.2594
#   Predicted urgency: 0.5559
#
# Sentence: '[H]C#CC([H])(O[H])C([H])([H])C([H])([H])[H]'
#   True urgency: 0.2621
#   Predicted urgency: 0.5559
#
# Sentence: '[H]OC([H])(C#N)C([H])([H])C([H])([H])[H]'
#   True urgency: 0.2791
#   Predicted urgency: 0.5559
#
# Sentence: '[H]N(C([H])([H])[H])C([H])(C#N)C([H])([H])[H]'
#   True urgency: 0.2389
#   Predicted urgency: 0.5559
#
# Sentence: '[H]C#CC([H])(OC([H])([H])[H])C([H])([H])[H]'
#   True urgency: 0.2623
#   Predicted urgency: 0.5559
#
# Sentence: '[H]C([H])([H])OC([H])(C#N)C([H])([H])[H]'
#   True urgency: 0.2770
#   Predicted urgency: 0.5559
#
# Sentence: '[H]OC([H])([H])C([H])(C#N)N([H])[H]'
#   True urgency: 0.2595
#   Predicted urgency: 0.5559
#
# Sentence: '[H]N([H])C([H])([H])C([H])(C#N)N([H])[H]'
#   True urgency: 0.2506
#   Predicted urgency: 0.5559
#
# Sentence: '[H]OC([H])(C#N)C([H])([H])N([H])[H]'
#   True urgency: 0.2530
#   Predicted urgency: 0.5559
#
# Sentence: '[H]C#CC([H])(O[H])C([H])([H])O[H]'
#   True urgency: 0.2572
#   Predicted urgency: 0.5559
#
# Sentence: '[H]OC([H])([H])C([H])(C#N)O[H]'
#   True urgency: 0.2708
#   Predicted urgency: 0.5559
#
# Sentence: '[H]OC([H])([H])C([H])(C([H])=O)C([H])([H])[H]'
#   True urgency: 0.1637
#   Predicted urgency: 0.5559
#
# Sentence: '[H]C(=O)C([H])(C([H])([H])[H])C([H])([H])C([H])([H])[H]'
#   True urgency: 0.1617
#   Predicted urgency: 0.5559
#
# Sentence: '[H]OC([H])(C([H])=O)C([H])([H])C([H])([H])[H]'
#   True urgency: 0.1710
#   Predicted urgency: 0.5559
#
# Sentence: '[H]C(=O)N(C([H])([H])[H])C([H])([H])C([H])([H])[H]'
#   True urgency: 0.2157
#   Predicted urgency: 0.5559
#
# Sentence: '[H]C(=O)C([H])(OC([H])([H])[H])C([H])([H])[H]'
#   True urgency: 0.1609
#   Predicted urgency: 0.5559
#
# Sentence: '[H]OC([H])([H])C([H])(O[H])C([H])=O'
#   True urgency: 0.1687
#   Predicted urgency: 0.5559
#
# Sentence: '[H]OC([H])([H])C([H])(C([H])([H])[H])C([H])([H])O[H]'
#   True urgency: 0.2654
#   Predicted urgency: 0.5559
#
# Sentence: '[H]C([H])([H])C([H])([H])C([H])(C([H])([H])[H])C([H])([H])C([H])([H])[H]'
#   True urgency: 0.3347
#   Predicted urgency: 0.5559
#
# Sentence: '[H]OC([H])([H])C([H])(C([H])([H])[H])C([H])([H])C([H])([H])[H]'
#   True urgency: 0.2652
#   Predicted urgency: 0.5559
#
# Sentence: '[H]C([H])([H])OC([H])(C([H])([H])[H])C([H])([H])C([H])([H])[H]'
#   True urgency: 0.2717
#   Predicted urgency: 0.5559
#
# Sentence: '[H]OC([H])(C([H])([H])C([H])([H])[H])C([H])([H])C([H])([H])[H]'
#   True urgency: 0.2665
#   Predicted urgency: 0.5559
#
# Sentence: '[H]OC([H])([H])C([H])(O[H])C([H])([H])C([H])([H])[H]'
#   True urgency: 0.2694
#   Predicted urgency: 0.5559
#
# Sentence: '[H]OC([H])([H])C([H])(OC([H])([H])[H])C([H])([H])[H]'
#   True urgency: 0.2759
#   Predicted urgency: 0.5559
#
# Sentence: '[H]OC([H])([H])C([H])(O[H])C([H])([H])O[H]'
#   True urgency: 0.2671
#   Predicted urgency: 0.5559
#
# Sentence: '[H]C#CC1(C([H])([H])[H])C([H])([H])C1([H])[H]'
#   True urgency: 0.2574
#   Predicted urgency: 0.5559
#
# Sentence: '[H]C([H])([H])C1(C#N)C([H])([H])C1([H])[H]'
#   True urgency: 0.2932
#   Predicted urgency: 0.5559
#
# Sentence: '[H]C#CC1(C([H])([H])[H])N([H])C1([H])[H]'
#   True urgency: 0.2577
#   Predicted urgency: 0.5559
#
# Sentence: '[H]N1C([H])([H])C1(C#N)C([H])([H])[H]'
#   True urgency: 0.2701
#   Predicted urgency: 0.5559
#
# Sentence: '[H]C#CC1(C([H])([H])[H])OC1([H])[H]'
#   True urgency: 0.2582
#   Predicted urgency: 0.5559
#
# Sentence: '[H]C([H])([H])C1(C#N)OC1([H])[H]'
#   True urgency: 0.2763
#   Predicted urgency: 0.5559
#
# Sentence: '[H]N([H])C1(C#N)C([H])([H])C1([H])[H]'
#   True urgency: 0.2680
#   Predicted urgency: 0.5559
#
# Sentence: '[H]C#CC1(O[H])C([H])([H])C1([H])[H]'
#   True urgency: 0.2441
#   Predicted urgency: 0.5559
#
# Sentence: '[H]OC1(C#N)C([H])([H])C1([H])[H]'
#   True urgency: 0.2682
#   Predicted urgency: 0.5559
#
# Sentence: '[H]C(=O)C1(C([H])([H])[H])C([H])([H])C1([H])[H]'
#   True urgency: 0.1695
#   Predicted urgency: 0.5559
#
# Sentence: '[H]C(=O)C1(C([H])([H])[H])N([H])C1([H])[H]'
#   True urgency: 0.1649
#   Predicted urgency: 0.5559
#
# Sentence: '[H]C(=O)C1(C([H])([H])[H])OC1([H])[H]'
#   True urgency: 0.1609
#   Predicted urgency: 0.5559
#
# Sentence: '[H]OC1(C([H])=O)C([H])([H])C1([H])[H]'
#   True urgency: 0.1757
#   Predicted urgency: 0.5559
#
# Sentence: '[H]OC([H])([H])C1(C([H])([H])[H])C([H])([H])C1([H])[H]'
#   True urgency: 0.2644
#   Predicted urgency: 0.5559
#
# Sentence: '[H]OC([H])([H])C1(C([H])([H])[H])N([H])C1([H])[H]'
#   True urgency: 0.2605
#   Predicted urgency: 0.5559
#
# Sentence: '[H]OC([H])([H])C1(C([H])([H])[H])OC1([H])[H]'
#   True urgency: 0.2789
#   Predicted urgency: 0.5559
#
# Sentence: '[H]C([H])([H])C([H])([H])C1(C([H])([H])[H])C([H])([H])C1([H])[H]'
#   True urgency: 0.2945
#   Predicted urgency: 0.5559
#
# Sentence: '[H]C([H])([H])C([H])([H])C1(C([H])([H])[H])OC1([H])[H]'
#   True urgency: 0.2863
#   Predicted urgency: 0.5559
#
# Sentence: '[H]OC1(C([H])([H])C([H])([H])[H])C([H])([H])C1([H])[H]'
#   True urgency: 0.2686
#   Predicted urgency: 0.5559
#
# Sentence: '[H]C([H])([H])OC1(C([H])([H])[H])C([H])([H])C1([H])[H]'
#   True urgency: 0.2763
#   Predicted urgency: 0.5559
#
# Sentence: '[H]OC([H])([H])C1(O[H])C([H])([H])C1([H])[H]'
#   True urgency: 0.2710
#   Predicted urgency: 0.5559
#
# Sentence: '[H]C([H])([H])C1([H])C(=O)C([H])([H])C1([H])[H]'
#   True urgency: 0.1619
#   Predicted urgency: 0.5559
#
# Sentence: '[H]N1C(=O)C([H])(C([H])([H])[H])C1([H])[H]'
#   True urgency: 0.2246
#   Predicted urgency: 0.5559
#
# Sentence: '[H]N=C1OC([H])([H])C1([H])C([H])([H])[H]'
#   True urgency: 0.2543
#   Predicted urgency: 0.5559
#
# Sentence: '[H]C([H])([H])C1([H])C(=O)OC1([H])[H]'
#   True urgency: 0.2251
#   Predicted urgency: 0.5559
#
# Sentence: '[H]N1C([H])([H])C(=O)C1([H])C([H])([H])[H]'
#   True urgency: 0.1638
#   Predicted urgency: 0.5559
#
# Sentence: '[H]C1([H])OC([H])(C([H])([H])[H])C1=O'
#   True urgency: 0.1659
#   Predicted urgency: 0.5559
#
# Sentence: '[H]C([H])([H])N1C(=O)C([H])([H])C1([H])[H]'
#   True urgency: 0.2300
#   Predicted urgency: 0.5559
#
# Sentence: '[H]N=C1OC([H])([H])C1([H])N([H])[H]'
#   True urgency: 0.2401
#   Predicted urgency: 0.5559
#
# Sentence: '[H]N([H])C1([H])C(=O)OC1([H])[H]'
#   True urgency: 0.2097
#   Predicted urgency: 0.5559
#
# Sentence: '[H]OC1([H])C(=O)C([H])([H])C1([H])[H]'
#   True urgency: 0.1645
#   Predicted urgency: 0.5559
#
# Sentence: '[H]OC1([H])C(=O)N([H])C1([H])[H]'
#   True urgency: 0.2152
#   Predicted urgency: 0.5559
#
# Sentence: '[H]N=C1OC([H])([H])C1([H])O[H]'
#   True urgency: 0.2456
#   Predicted urgency: 0.5559
#
# Sentence: '[H]OC1([H])C(=O)OC1([H])[H]'
#   True urgency: 0.2129
#   Predicted urgency: 0.5559
#
# Sentence: '[H]C([H])([H])C1([H])C([H])([H])C([H])([H])C1([H])C([H])([H])[H]'
#   True urgency: 0.3087
#   Predicted urgency: 0.5559
#
# Sentence: '[H]OC1([H])C([H])([H])C([H])([H])C1([H])C([H])([H])[H]'
#   True urgency: 0.2585
#   Predicted urgency: 0.5559
#
# Sentence: '[H]C([H])([H])C1([H])OC([H])([H])C1([H])C([H])([H])[H]'
#   True urgency: 0.2649
#   Predicted urgency: 0.5559
#
# Sentence: '[H]OC1([H])C([H])([H])OC1([H])C([H])([H])[H]'
#   True urgency: 0.2583
#   Predicted urgency: 0.5559
#
# Sentence: '[H]OC1([H])C([H])([H])C([H])([H])C1([H])O[H]'
#   True urgency: 0.2535
#   Predicted urgency: 0.5559
#
# Sentence: '[H]N=C1N([H])C([H])=NC1([H])[H]'
#   True urgency: 0.2161
#   Predicted urgency: 0.5559
#
# Sentence: '[H]C1=C([H])C([H])([H])C(=O)C1([H])[H]'
#   True urgency: 0.2368
#   Predicted urgency: 0.5559
#
# Sentence: '[H]C1=C([H])C([H])([H])C(=O)N1[H]'
#   True urgency: 0.2016
#   Predicted urgency: 0.5559
#
# Sentence: '[H]C1=NC([H])([H])C(=O)N1[H]'
#   True urgency: 0.1882
#   Predicted urgency: 0.5559
#
# Sentence: '[H]C1=NC([H])([H])C(=O)O1'
#   True urgency: 0.2039
#   Predicted urgency: 0.5559
#
# Sentence: '[H]N=C1OC([H])([H])C([H])=C1[H]'
#   True urgency: 0.2153
#   Predicted urgency: 0.5559
#
# Sentence: '[H]C1=C([H])C([H])([H])C([H])([H])C1=O'
#   True urgency: 0.1458
#   Predicted urgency: 0.5559
#
# Sentence: '[H]C1=C([H])C([H])([H])N([H])C1=O'
#   True urgency: 0.1807
#   Predicted urgency: 0.5559
#
# Sentence: '[H]N=C1OC([H])([H])C([H])([H])C1([H])[H]'
#   True urgency: 0.2503
#   Predicted urgency: 0.5559
#
# Sentence: '[H]N=C1OC([H])([H])OC1([H])[H]'
#   True urgency: 0.2507
#   Predicted urgency: 0.5559
#
# Sentence: '[H]N=C1OC([H])([H])C([H])([H])O1'
#   True urgency: 0.2736
#   Predicted urgency: 0.5559
#
# Sentence: '[H]C1([H])C(=O)C([H])([H])C([H])([H])C1([H])[H]'
#   True urgency: 0.1608
#   Predicted urgency: 0.5559
#
# Sentence: '[H]N1C(=O)C([H])([H])C([H])([H])C1([H])[H]'
#   True urgency: 0.2156
#   Predicted urgency: 0.5559
#
# Sentence: '[H]C1([H])OC(=O)C([H])([H])C1([H])[H]'
#   True urgency: 0.2196
#   Predicted urgency: 0.5559
#
# Sentence: '[H]C1([H])OC([H])([H])C([H])([H])C1=O'
#   True urgency: 0.1604
#   Predicted urgency: 0.5559
#
# Sentence: '[H]C1([H])OC(=O)C([H])([H])O1'
#   True urgency: 0.2210
#   Predicted urgency: 0.5559
#
# Sentence: '[H]N1C(=O)N([H])C([H])([H])C1([H])[H]'
#   True urgency: 0.2528
#   Predicted urgency: 0.5559
#
# Sentence: '[H]N1C(=O)OC([H])([H])C1([H])[H]'
#   True urgency: 0.2635
#   Predicted urgency: 0.5559
#
# Sentence: '[H]C1([H])OC(=O)OC1([H])[H]'
#   True urgency: 0.2720
#   Predicted urgency: 0.5559
#
# Sentence: '[H]C1=C(C([H])([H])[H])C([H])([H])C([H])([H])C1([H])[H]'
#   True urgency: 0.2618
#   Predicted urgency: 0.5559
#
# Sentence: '[H]C1=C(C([H])([H])[H])C([H])([H])OC1([H])[H]'
#   True urgency: 0.2393
#   Predicted urgency: 0.5559
#
# Sentence: '[H]C([H])([H])C1=NC([H])([H])C([H])([H])O1'
#   True urgency: 0.2531
#   Predicted urgency: 0.5559
#
# Sentence: '[H]C1=C([H])C([H])([H])C([H])(C([H])([H])[H])C1([H])[H]'
#   True urgency: 0.2744
#   Predicted urgency: 0.5559
#
# Sentence: '[H]C1=NC([H])([H])C([H])(C([H])([H])[H])O1'
#   True urgency: 0.2481
#   Predicted urgency: 0.5559
#
# Sentence: '[H]OC1([H])C([H])([H])C([H])=C([H])C1([H])[H]'
#   True urgency: 0.2736
#   Predicted urgency: 0.5559
#
# Sentence: '[H]C1=C([H])C([H])(C([H])([H])[H])C([H])([H])C1([H])[H]'
#   True urgency: 0.2725
#   Predicted urgency: 0.5559
#
# Sentence: '[H]C1=NC([H])(C([H])([H])[H])C([H])([H])O1'
#   True urgency: 0.2477
#   Predicted urgency: 0.5559
#
# Sentence: '[H]C1=C([H])C([H])(C([H])([H])[H])OC1([H])[H]'
#   True urgency: 0.2303
#   Predicted urgency: 0.5559
#
# Sentence: '[H]OC1([H])C([H])=C([H])C([H])([H])C1([H])[H]'
#   True urgency: 0.2499
#   Predicted urgency: 0.5559
#
# Sentence: '[H]C([H])([H])C1([H])C([H])([H])C([H])([H])C([H])([H])C1([H])[H]'
#   True urgency: 0.3316
#   Predicted urgency: 0.5559
#
# Sentence: '[H]C([H])([H])C1([H])OC([H])([H])C([H])([H])C1([H])[H]'
#   True urgency: 0.2589
#   Predicted urgency: 0.5559
#
# Sentence: '[H]C([H])([H])C1([H])C([H])([H])OC([H])([H])C1([H])[H]'
#   True urgency: 0.2621
#   Predicted urgency: 0.5559
#
# Sentence: '[H]C1([H])OC([H])([H])C([H])(C([H])([H])[H])O1'
#   True urgency: 0.2785
#   Predicted urgency: 0.5559
#
# Sentence: '[H]C([H])([H])C1([H])OC([H])([H])C([H])([H])O1'
#   True urgency: 0.2795
#   Predicted urgency: 0.5559
#
# Sentence: '[H]OC1([H])C([H])([H])C([H])([H])C([H])([H])C1([H])[H]'
#   True urgency: 0.2657
#   Predicted urgency: 0.5559
#
# Sentence: '[H]OC1([H])C([H])([H])OC([H])([H])C1([H])[H]'
#   True urgency: 0.2645
#   Predicted urgency: 0.5559
#
# Sentence: '[H]C([H])([H])C1([H])C([H])(C([H])([H])[H])C1([H])C([H])([H])[H]'
#   True urgency: 0.2819
#   Predicted urgency: 0.5559
#
# Sentence: '[H]OC1([H])C([H])(C([H])([H])[H])C1([H])C([H])([H])[H]'
#   True urgency: 0.2550
#   Predicted urgency: 0.5559
#
# Sentence: '[H]C([H])([H])N1C([H])(C([H])([H])[H])C1([H])C([H])([H])[H]'
#   True urgency: 0.2351
#   Predicted urgency: 0.5559
#
# Sentence: '[H]OC1([H])C([H])(O[H])C1([H])C([H])([H])[H]'
#   True urgency: 0.2333
#   Predicted urgency: 0.5559
#
# Sentence: '[H]C([H])([H])C12C([H])([H])C([H])([H])C1([H])C2([H])[H]'
#   True urgency: 0.2759
#   Predicted urgency: 0.5559
#
# Sentence: '[H]C([H])([H])C12OC([H])([H])C1([H])C2([H])[H]'
#   True urgency: 0.2542
#   Predicted urgency: 0.5559
#
# ...
#
# Sentence: '[H]Oc1c([H])oc(N([H])[H])c1[H]'
#   True urgency: 0.2061
#   Predicted urgency: 0.5559
#
# Sentence: '[H]Oc1c([H])c(N([H])[H])c([H])n1[H]'
#   True urgency: 0.1976
#   Predicted urgency: 0.5559
#
# Sentence: '[H]Oc1nc(N([H])[H])c([H])n1[H]'
#   True urgency: 0.2081
#   Predicted urgency: 0.5559
#
# Sentence: '[H]Oc1nc(N([H])[H])c([H])o1'
#   True urgency: 0.2205
#   Predicted urgency: 0.5559
#
# Sentence: '[H]c1oc(N([H])[H])nc1N([H])[H]'
#   True urgency: 0.2138
#   Predicted urgency: 0.5559
#
# Sentence: '[H]Oc1nc(N([H])[H])n([H])c1[H]'
#   True urgency: 0.1995
#   Predicted urgency: 0.5559
#
# Sentence: '[H]Oc1nc(N([H])[H])oc1[H]'
#   True urgency: 0.2203
#   Predicted urgency: 0.5559
#
# Sentence: '[H]Oc1c([H])c(O[H])n([H])c1[H]'
#   True urgency: 0.1987
#   Predicted urgency: 0.5559
#
# Sentence: '[H]Oc1nc(O[H])n([H])c1[H]'
#   True urgency: 0.2145
#   Predicted urgency: 0.5559
#
# Sentence: '[H]c1c([H])c(C([H])([H])[H])n([H])c1C([H])([H])[H]'
#   True urgency: 0.2154
#   Predicted urgency: 0.5559
#
# Sentence: '[H]c1c(C([H])([H])[H])oc(C([H])([H])[H])c1[H]'
#   True urgency: 0.2354
#   Predicted urgency: 0.5559
#
# Sentence: '[H]c1c([H])c(C([H])([H])[H])n([H])c1N([H])[H]'
#   True urgency: 0.2080
#   Predicted urgency: 0.5559
#
# Sentence: '[H]c1c(N([H])[H])oc(C([H])([H])[H])c1[H]'
#   True urgency: 0.2059
#   Predicted urgency: 0.5559
#
# Sentence: '[H]Oc1c([H])c([H])c(C([H])([H])[H])n1[H]'
#   True urgency: 0.2015
#   Predicted urgency: 0.5559
#
# Sentence: '[H]c1nc(C([H])([H])[H])oc1C([H])([H])[H]'
#   True urgency: 0.2394
#   Predicted urgency: 0.5559
#
# Sentence: '[H]c1nc(N([H])[H])oc1C([H])([H])[H]'
#   True urgency: 0.2267
#   Predicted urgency: 0.5559
#
# Sentence: '[H]Oc1nc([H])c(C([H])([H])[H])n1[H]'
#   True urgency: 0.2238
#   Predicted urgency: 0.5559
#
# Sentence: '[H]Oc1nc([H])c(C([H])([H])[H])o1'
#   True urgency: 0.2437
#   Predicted urgency: 0.5559
#
# Sentence: '[H]c1nc(C([H])([H])[H])oc1N([H])[H]'
#   True urgency: 0.2143
#   Predicted urgency: 0.5559
#
# Sentence: '[H]Oc1c([H])nc(C([H])([H])[H])n1[H]'
#   True urgency: 0.2104
#   Predicted urgency: 0.5559
#
# Sentence: '[H]c1c([H])c(N([H])[H])n([H])c1N([H])[H]'
#   True urgency: 0.2051
#   Predicted urgency: 0.5559
#
# Sentence: '[H]c1c(N([H])[H])oc(N([H])[H])c1[H]'
#   True urgency: 0.2066
#   Predicted urgency: 0.5559
#
# Sentence: '[H]Oc1c([H])c([H])c(N([H])[H])n1[H]'
#   True urgency: 0.2041
#   Predicted urgency: 0.5559
#
# Sentence: '[H]Oc1oc(N([H])[H])c([H])c1[H]'
#   True urgency: 0.2224
#   Predicted urgency: 0.5559
#
# Sentence: '[H]c1nc(N([H])[H])oc1N([H])[H]'
#   True urgency: 0.2270
#   Predicted urgency: 0.5559
#
# Sentence: '[H]Oc1nc([H])c(N([H])[H])n1[H]'
#   True urgency: 0.2187
#   Predicted urgency: 0.5559
#
# Sentence: '[H]Oc1nc([H])c(N([H])[H])o1'
#   True urgency: 0.2443
#   Predicted urgency: 0.5559
#
# Sentence: '[H]Oc1c([H])c([H])c(O[H])n1[H]'
#   True urgency: 0.1955
#   Predicted urgency: 0.5559
#
# Sentence: '[H]Oc1nc([H])c(O[H])n1[H]'
#   True urgency: 0.2061
#   Predicted urgency: 0.5559
#
# Sentence: '[H]c1c(C([H])([H])[H])n([H])c(=O)n1[H]'
#   True urgency: 0.2139
#   Predicted urgency: 0.5559
#
# Sentence: '[H]c1c(C([H])([H])[H])oc(=O)n1[H]'
#   True urgency: 0.2293
#   Predicted urgency: 0.5559
#
# Sentence: '[H]c1oc(=O)n([H])c1C([H])([H])[H]'
#   True urgency: 0.2318
#   Predicted urgency: 0.5559
#
# Sentence: '[H]c1oc(=O)oc1C([H])([H])[H]'
#   True urgency: 0.2596
#   Predicted urgency: 0.5559
#
# Sentence: '[H]c1c(N([H])[H])n([H])c(=O)n1[H]'
#   True urgency: 0.1996
#   Predicted urgency: 0.5559
#
# Sentence: '[H]c1c(N([H])[H])oc(=O)n1[H]'
#   True urgency: 0.2072
#   Predicted urgency: 0.5559
#
# Sentence: '[H]c1oc(=O)n([H])c1N([H])[H]'
#   True urgency: 0.2113
#   Predicted urgency: 0.5559
#
# Sentence: '[H]c1oc(=O)oc1N([H])[H]'
#   True urgency: 0.2218
#   Predicted urgency: 0.5559
#
# Sentence: '[H]Oc1c([H])n([H])c(=O)n1[H]'
#   True urgency: 0.1964
#   Predicted urgency: 0.5559
#
# Sentence: '[H]Oc1oc(=O)n([H])c1[H]'
#   True urgency: 0.2203
#   Predicted urgency: 0.5559
#
# Sentence: '[H]Oc1oc(=O)oc1[H]'
#   True urgency: 0.2367
#   Predicted urgency: 0.5559
#
# Sentence: '[H]c1c(C([H])([H])[H])c([H])n(C([H])([H])[H])c1[H]'
#   True urgency: 0.2273
#   Predicted urgency: 0.5559
#
# Sentence: '[H]c1c(N([H])[H])c([H])n(C([H])([H])[H])c1[H]'
#   True urgency: 0.2037
#   Predicted urgency: 0.5559
#
# Sentence: '[H]Oc1c([H])c([H])n(C([H])([H])[H])c1[H]'
#   True urgency: 0.2146
#   Predicted urgency: 0.5559
#
# Sentence: '[H]c1nc(C([H])([H])[H])c([H])n1C([H])([H])[H]'
#   True urgency: 0.2343
#   Predicted urgency: 0.5559
#
# Sentence: '[H]c1nc(N([H])[H])c([H])n1C([H])([H])[H]'
#   True urgency: 0.2070
#   Predicted urgency: 0.5559
#
# Sentence: '[H]Oc1nc([H])n(C([H])([H])[H])c1[H]'
#   True urgency: 0.2147
#   Predicted urgency: 0.5559
#
# Sentence: '[H]c1c([H])n([H])c([H])c([H])c1=O'
#   True urgency: 0.1661
#   Predicted urgency: 0.5559
#
# Sentence: '[H]c1c([H])n([H])c([H])nc1=O'
#   True urgency: 0.1648
#   Predicted urgency: 0.5559
#
# Sentence: '[H]c1oc([H])c([H])c(=O)c1[H]'
#   True urgency: 0.2138
#   Predicted urgency: 0.5559
#
# Sentence: '[H]c1nc(=O)c([H])c([H])o1'
#   True urgency: 0.1628
#   Predicted urgency: 0.5559
#
# Sentence: '[H]c1nc(=O)nc([H])o1'
#   True urgency: 0.1711
#   Predicted urgency: 0.5559
#
# Sentence: '[H]N=c1oc([H])c([H])c([H])c1[H]'
#   True urgency: 0.1622
#   Predicted urgency: 0.5559
#
# Sentence: '[H]N=c1nc([H])c([H])c([H])o1'
#   True urgency: 0.1557
#   Predicted urgency: 0.5559
#
# Sentence: '[H]N=c1oc([H])c([H])nc1[H]'
#   True urgency: 0.1594
#   Predicted urgency: 0.5559
#
# Sentence: '[H]N=c1oc([H])nc([H])c1[H]'
#   True urgency: 0.1765
#   Predicted urgency: 0.5559
#
# Sentence: '[H]N=c1nc([H])nc([H])o1'
#   True urgency: 0.1590
#   Predicted urgency: 0.5559
#
# Sentence: '[H]c1c([H])c([H])n([H])c(=O)c1[H]'
#   True urgency: 0.1638
#   Predicted urgency: 0.5559
#
# Sentence: '[H]c1nc(=O)n([H])c([H])c1[H]'
#   True urgency: 0.1564
#   Predicted urgency: 0.5559
#
# Sentence: '[H]c1nc([H])c(=O)n([H])c1[H]'
#   True urgency: 0.1438
#   Predicted urgency: 0.5559
#
# Sentence: '[H]c1nc([H])n([H])c(=O)c1[H]'
#   True urgency: 0.1788
#   Predicted urgency: 0.5559
#
# Sentence: '[H]c1nc([H])n([H])c(=O)n1'
#   True urgency: 0.1561
#   Predicted urgency: 0.5559
#
# Sentence: '[H]c1oc(=O)c([H])c([H])c1[H]'
#   True urgency: 0.1702
#   Predicted urgency: 0.5559
#
# Sentence: '[H]c1nc(=O)oc([H])c1[H]'
#   True urgency: 0.1539
#   Predicted urgency: 0.5559
#
# Sentence: '[H]c1nc([H])c(=O)oc1[H]'
#   True urgency: 0.1424
#   Predicted urgency: 0.5559
#
# Sentence: '[H]c1nc([H])c([H])c(=O)o1'
#   True urgency: 0.1880
#   Predicted urgency: 0.5559
#
# Sentence: '[H]c1nc([H])oc(=O)n1'
#   True urgency: 0.1558
#   Predicted urgency: 0.5559
#
# Sentence: '[H]c1c([H])c([H])c(C([H])([H])[H])c([H])c1[H]'
#   True urgency: 0.1912
#   Predicted urgency: 0.5559
#
# Sentence: '[H]c1nc([H])c([H])c(C([H])([H])[H])c1[H]'
#   True urgency: 0.1958
#   Predicted urgency: 0.5559
#
# Sentence: '[H]c1nc([H])c(C([H])([H])[H])c([H])c1[H]'
#   True urgency: 0.1923
#   Predicted urgency: 0.5559
#
# Sentence: '[H]c1nc([H])c(C([H])([H])[H])nc1[H]'
#   True urgency: 0.1864
#   Predicted urgency: 0.5559
#
# Sentence: '[H]c1nc([H])c(C([H])([H])[H])c([H])n1'
#   True urgency: 0.1613
#   Predicted urgency: 0.5559
#
# Sentence: '[H]c1nc(C([H])([H])[H])c([H])c([H])c1[H]'
#   True urgency: 0.1929
#   Predicted urgency: 0.5559
#
# Sentence: '[H]c1nc(C([H])([H])[H])nc([H])c1[H]'
#   True urgency: 0.2006
#   Predicted urgency: 0.5559
#
# Sentence: '[H]c1nc([H])c(C([H])([H])[H])nc1[H]'
#   True urgency: 0.1864
#   Predicted urgency: 0.5559
#
# Sentence: '[H]c1nc([H])c([H])c(C([H])([H])[H])n1'
#   True urgency: 0.2027
#   Predicted urgency: 0.5559
#
# Sentence: '[H]c1nc([H])nc(C([H])([H])[H])n1'
#   True urgency: 0.1715
#   Predicted urgency: 0.5559
#
# Sentence: '[H]c1c([H])c([H])c(N([H])[H])c([H])c1[H]'
#   True urgency: 0.1760
#   Predicted urgency: 0.5559
#
# Sentence: '[H]c1nc([H])c(N([H])[H])c([H])c1[H]'
#   True urgency: 0.1719
#   Predicted urgency: 0.5559
#
# Sentence: '[H]c1nc([H])c(N([H])[H])nc1[H]'
#   True urgency: 0.1623
#   Predicted urgency: 0.5559
#
# Sentence: '[H]c1nc([H])c(N([H])[H])c([H])n1'
#   True urgency: 0.1613
#   Predicted urgency: 0.5559
#
# Sentence: '[H]c1nc(N([H])[H])c([H])c([H])c1[H]'
#   True urgency: 0.1738
#   Predicted urgency: 0.5559
#
# Sentence: '[H]c1nc(N([H])[H])nc([H])c1[H]'
#   True urgency: 0.1660
#   Predicted urgency: 0.5559
#
# Sentence: '[H]c1nc([H])c(N([H])[H])nc1[H]'
#   True urgency: 0.1624
#   Predicted urgency: 0.5559
#
# Sentence: '[H]c1nc([H])c([H])c(N([H])[H])n1'
#   True urgency: 0.1784
#   Predicted urgency: 0.5559
#
# Sentence: '[H]c1nc([H])nc(N([H])[H])n1'
#   True urgency: 0.1890
#   Predicted urgency: 0.5559
#
# Sentence: '[H]Oc1c([H])c([H])c([H])c([H])c1[H]'
#   True urgency: 0.1841
#   Predicted urgency: 0.5559
#
# Sentence: '[H]Oc1c([H])c([H])nc([H])c1[H]'
#   True urgency: 0.1961
#   Predicted urgency: 0.5559
#
# Sentence: '[H]Oc1c([H])nc([H])c([H])c1[H]'
#   True urgency: 0.1813
#   Predicted urgency: 0.5559
#
# Sentence: '[H]Oc1nc([H])c([H])nc1[H]'
#   True urgency: 0.1756
#   Predicted urgency: 0.5559
#
# Sentence: '[H]Oc1c([H])nc([H])nc1[H]'
#   True urgency: 0.1834
#   Predicted urgency: 0.5559
#
# Sentence: '[H]Oc1nc([H])c([H])c([H])c1[H]'
#   True urgency: 0.1838
#   Predicted urgency: 0.5559
#
# Sentence: '[H]Oc1nc([H])c([H])c([H])n1'
#   True urgency: 0.1666
#   Predicted urgency: 0.5559
#
# Sentence: '[H]Oc1nc([H])c([H])nc1[H]'
#   True urgency: 0.1756
#   Predicted urgency: 0.5559
#
# Sentence: '[H]Oc1nc([H])nc([H])c1[H]'
#   True urgency: 0.1993
#   Predicted urgency: 0.5559
#
# Sentence: '[H]Oc1nc([H])nc([H])n1'
#   True urgency: 0.1766
#   Predicted urgency: 0.5559
#
# Sentence: '[H]c1c(C([H])([H])[H])c(C([H])([H])[H])n([H])c1[H]'
#   True urgency: 0.2210
#   Predicted urgency: 0.5559
#
# Sentence: '[H]c1oc(C([H])([H])[H])c(C([H])([H])[H])c1[H]'
#   True urgency: 0.2345
#   Predicted urgency: 0.5559
#
# Sentence: '[H]c1nc(C([H])([H])[H])c(C([H])([H])[H])n1[H]'
#   True urgency: 0.2295
#   Predicted urgency: 0.5559
#
# Sentence: '[H]c1nc(C([H])([H])[H])c(C([H])([H])[H])o1'
#   True urgency: 0.2320
#   Predicted urgency: 0.5559
#
# Sentence: '[H]c1c(N([H])[H])c(C([H])([H])[H])n([H])c1[H]'
#   True urgency: 0.2047
#   Predicted urgency: 0.5559
#
# Sentence: '[H]c1oc(C([H])([H])[H])c(N([H])[H])c1[H]'
#   True urgency: 0.2060
#   Predicted urgency: 0.5559
#
# Sentence: '[H]c1nc(N([H])[H])c(C([H])([H])[H])o1'
#   True urgency: 0.2017
#   Predicted urgency: 0.5559
#
# Sentence: '[H]c1c(C([H])([H])[H])c(N([H])[H])n([H])c1[H]'
#   True urgency: 0.2226
#   Predicted urgency: 0.5559
#
# Sentence: '[H]c1oc(N([H])[H])c(C([H])([H])[H])c1[H]'
#   True urgency: 0.2037
#   Predicted urgency: 0.5559
#
# Sentence: '[H]c1nc(C([H])([H])[H])c(N([H])[H])o1'
#   True urgency: 0.2345
#   Predicted urgency: 0.5559
#
# Sentence: '[H]Oc1c([H])c([H])n([H])c1C([H])([H])[H]'
#   True urgency: 0.2107
#   Predicted urgency: 0.5559
#
# Sentence: '[H]Oc1c(C([H])([H])[H])oc([H])c1[H]'
#   True urgency: 0.2137
#   Predicted urgency: 0.5559
#
# Sentence: '[H]Oc1nc([H])n([H])c1C([H])([H])[H]'
#   True urgency: 0.2166
#   Predicted urgency: 0.5559
#
# Sentence: '[H]Oc1nc([H])oc1C([H])([H])[H]'
#   True urgency: 0.2069
#   Predicted urgency: 0.5559
#
# Sentence: '[H]Oc1c(C([H])([H])[H])c([H])c([H])n1[H]'
#   True urgency: 0.1977
#   Predicted urgency: 0.5559
#
# Sentence: '[H]Oc1c(C([H])([H])[H])nc([H])n1[H]'
#   True urgency: 0.2057
#   Predicted urgency: 0.5559
#
# Sentence: '[H]c1oc(N([H])[H])c(N([H])[H])c1[H]'
#   True urgency: 0.2087
#   Predicted urgency: 0.5559
#
# Sentence: '[H]c1nc(N([H])[H])c(N([H])[H])o1'
#   True urgency: 0.2090
#   Predicted urgency: 0.5559
#
# Sentence: '[H]Oc1c([H])c([H])n([H])c1N([H])[H]'
#   True urgency: 0.2065
#   Predicted urgency: 0.5559
#
# Sentence: '[H]Oc1c(N([H])[H])oc([H])c1[H]'
#   True urgency: 0.2028
#   Predicted urgency: 0.5559
#
# Sentence: '[H]Oc1nc([H])n([H])c1N([H])[H]'
#   True urgency: 0.2207
#   Predicted urgency: 0.5559
#
# Sentence: '[H]Oc1nc([H])oc1N([H])[H]'
#   True urgency: 0.2057
#   Predicted urgency: 0.5559
#
# Sentence: '[H]Oc1c(N([H])[H])c([H])c([H])n1[H]'
#   True urgency: 0.2065
#   Predicted urgency: 0.5559
#
# Sentence: '[H]Oc1c(N([H])[H])nc([H])n1[H]'
#   True urgency: 0.2174
#   Predicted urgency: 0.5559
#
# Sentence: '[H]Oc1oc([H])c([H])c1N([H])[H]'
#   True urgency: 0.2031
#   Predicted urgency: 0.5559
#
# Sentence: '[H]Oc1c([H])c([H])n([H])c1O[H]'
#   True urgency: 0.1941
#   Predicted urgency: 0.5559
#
# Sentence: '[H]Oc1nc([H])n([H])c1O[H]'
#   True urgency: 0.1977
#   Predicted urgency: 0.5559
#
# Sentence: '[H]c1c(C([H])([H])[H])c(C([H])([H])[H])c([H])n1[H]'
#   True urgency: 0.2279
#   Predicted urgency: 0.5559
#
# Sentence: '[H]c1c(N([H])[H])c(C([H])([H])[H])c([H])n1[H]'
#   True urgency: 0.2007
#   Predicted urgency: 0.5559
#
# Sentence: '[H]Oc1c(C([H])([H])[H])c([H])n([H])c1[H]'
#   True urgency: 0.2085
#   Predicted urgency: 0.5559
#
# Sentence: '[H]c1oc([H])c(C([H])([H])[H])c1C([H])([H])[H]'
#   True urgency: 0.2443
#   Predicted urgency: 0.5559
#
# Sentence: '[H]c1oc([H])c(C([H])([H])[H])c1N([H])[H]'
#   True urgency: 0.2100
#   Predicted urgency: 0.5559
#
# Sentence: '[H]c1c(N([H])[H])c(N([H])[H])c([H])n1[H]'
#   True urgency: 0.1971
#   Predicted urgency: 0.5559
#
# Sentence: '[H]Oc1c(N([H])[H])c([H])n([H])c1[H]'
#   True urgency: 0.2096
#   Predicted urgency: 0.5559
#
# Sentence: '[H]c1oc([H])c(N([H])[H])c1N([H])[H]'
#   True urgency: 0.2128
#   Predicted urgency: 0.5559
#
# Sentence: '[H]Oc1c(O[H])c([H])n([H])c1[H]'
#   True urgency: 0.2004
#   Predicted urgency: 0.5559
#
# Sentence: '[H]c1c([H])c(C([H])([H])[H])n(C([H])([H])[H])c1[H]'
#   True urgency: 0.2316
#   Predicted urgency: 0.5559
#
# Sentence: '[H]c1c([H])c(N([H])[H])n(C([H])([H])[H])c1[H]'
#   True urgency: 0.2105
#   Predicted urgency: 0.5559
#
# Sentence: '[H]Oc1c([H])c([H])c([H])n1C([H])([H])[H]'
#   True urgency: 0.2035
#   Predicted urgency: 0.5559
#
# Sentence: '[H]c1nc(C([H])([H])[H])n(C([H])([H])[H])c1[H]'
#   True urgency: 0.2415
#   Predicted urgency: 0.5559
#
# Sentence: '[H]Oc1nc([H])c([H])n1C([H])([H])[H]'
#   True urgency: 0.2335
#   Predicted urgency: 0.5559
#
# Sentence: '[H]c1nc([H])n(C([H])([H])[H])c1C([H])([H])[H]'
#   True urgency: 0.2382
#   Predicted urgency: 0.5559
#
# Sentence: '[H]Oc1c([H])nc([H])n1C([H])([H])[H]'
#   True urgency: 0.2115
#   Predicted urgency: 0.5559
#
# Sentence: '[H]c1c([H])n(C([H])([H])[H])c(=O)n1[H]'
#   True urgency: 0.2204
#   Predicted urgency: 0.5559
#
# Sentence: '[H]c1oc(=O)n(C([H])([H])[H])c1[H]'
#   True urgency: 0.2288
#   Predicted urgency: 0.5559
#
# Sentence: '[H]C#Cc1c([H])c([H])c([H])n1[H]'
#   True urgency: 0.2076
#   Predicted urgency: 0.5559
#
# Sentence: '[H]C#Cc1oc([H])c([H])c1[H]'
#   True urgency: 0.2082
#   Predicted urgency: 0.5559
#
# Sentence: '[H]C#Cc1c([H])nc([H])n1[H]'
#   True urgency: 0.2170
#   Predicted urgency: 0.5559
#
# Sentence: '[H]C#Cc1oc([H])nc1[H]'
#   True urgency: 0.2163
#   Predicted urgency: 0.5559
#
# Sentence: '[H]C#Cc1nc([H])c([H])n1[H]'
#   True urgency: 0.2077
#   Predicted urgency: 0.5559
#
# Sentence: '[H]C#Cc1nc([H])c([H])o1'
#   True urgency: 0.2087
#   Predicted urgency: 0.5559
#
# Sentence: '[H]c1c([H])c(C#N)n([H])c1[H]'
#   True urgency: 0.2137
#   Predicted urgency: 0.5559
#
# Sentence: '[H]c1oc(C#N)c([H])c1[H]'
#   True urgency: 0.2159
#   Predicted urgency: 0.5559
#
# Sentence: '[H]c1nc([H])n([H])c1C#N'
#   True urgency: 0.2273
#   Predicted urgency: 0.5559
#
# Sentence: '[H]c1nc([H])c(C#N)o1'
#   True urgency: 0.2268
#   Predicted urgency: 0.5559
#
# Sentence: '[H]c1nc(C#N)n([H])c1[H]'
#   True urgency: 0.2121
#   Predicted urgency: 0.5559
#
# Sentence: '[H]c1nc(C#N)oc1[H]'
#   True urgency: 0.2131
#   Predicted urgency: 0.5559
#
# Sentence: '[H]C#Cc1c([H])c([H])n([H])c1[H]'
#   True urgency: 0.2237
#   Predicted urgency: 0.5559
#
# Sentence: '[H]C#Cc1nc([H])n([H])c1[H]'
#   True urgency: 0.2301
#   Predicted urgency: 0.5559
#
# Sentence: '[H]C#Cc1c([H])oc([H])c1[H]'
#   True urgency: 0.2282
#   Predicted urgency: 0.5559
#
# Sentence: '[H]C#Cc1nc([H])oc1[H]'
#   True urgency: 0.2325
#   Predicted urgency: 0.5559
#
# Sentence: '[H]c1c(C#N)c([H])n([H])c1[H]'
#   True urgency: 0.2267
#   Predicted urgency: 0.5559
#
# Sentence: '[H]c1nc(C#N)c([H])n1[H]'
#   True urgency: 0.2405
#   Predicted urgency: 0.5559
#
# Sentence: '[H]c1oc([H])c(C#N)c1[H]'
#   True urgency: 0.2299
#   Predicted urgency: 0.5559
#
# Sentence: '[H]c1nc(C#N)c([H])o1'
#   True urgency: 0.2446
#   Predicted urgency: 0.5559
#
# Sentence: '[H]C(=O)c1c([H])c([H])c([H])n1[H]'
#   True urgency: 0.1521
#   Predicted urgency: 0.5559
#
# Sentence: '[H]C(=O)c1oc([H])c([H])c1[H]'
#   True urgency: 0.1481
#   Predicted urgency: 0.5559
#
# Sentence: '[H]C(=O)c1c([H])nc([H])n1[H]'
#   True urgency: 0.1501
#   Predicted urgency: 0.5559
#
# Sentence: '[H]C(=O)c1oc([H])nc1[H]'
#   True urgency: 0.1470
#   Predicted urgency: 0.5559

# %%
import numpy as np
print("Label statistics:")
print(f"  Mean: {toy_urgency.mean():.4f}")
print(f"  Std : {toy_urgency.std():.4f}")
print(f"  Min/Max: {toy_urgency.min():.4f} / {toy_urgency.max():.4f}")
# Out:
# Label statistics:
#   Mean: 0.2299
#   Std : 0.0468
#   Min/Max: 0.0873 / 0.5138

# %% [markdown]
# # Testing block

# %%
import math
import numpy as np
import pandas as pd
import torch

# -------------------------
# Diagnostics: show df shape & columns
# -------------------------
print("Original df shape:", getattr(df, "shape", None))
print("Columns:", list(df.columns))

# If column names are weird, show first few rows to inspect
print("\nFirst 10 rows of df (for inspection):")
display(df.head(10)) if "display" in globals() else print(df.head(10).to_string(index=False))

# -------------------------
# Choose a safe slice for rows 101..121 (inclusive)
# -------------------------
START = 20001
END_EXCLUSIVE = 20101

n = len(df)
if START >= n:
    # If df has fewer rows than START, fall back to last 21 rows (or all rows if <21)
    fallback_count = min(21, n)
    start_idx = max(0, n - fallback_count)
    end_idx = n
    print(f"\nWARNING: df has only {n} rows, so rows {START}-{END_EXCLUSIVE-1} don't exist.")
    print(f"Falling back to rows {start_idx}..{end_idx-1} (last {fallback_count} rows).")
else:
    start_idx = START
    end_idx = min(END_EXCLUSIVE, n)
    print(f"\nSelecting rows {start_idx}..{end_idx-1} from df (if available).")

df_test = pd.read_csv(r"/Users/Ed/Downloads/qm8.csv", nrows=21000)
df_test = df_test.iloc[20001:20101].reset_index(drop=True)
df_test = df_test[['smiles', 'E1-CC2']]
print("df_test shape:", df_test.shape)

# -------------------------
# Identify text and label columns (robustly)
# -------------------------
if "smiles" in df_test.columns:
    text_col = "smiles"
else:
    text_col = df_test.columns[0]

# your label column seems to be 'E1-CC2' in this run — if present, use it; else second column
if "E1-CC2" in df_test.columns:
    label_col = "E1-CC2"
elif "urgency" in df_test.columns:
    label_col = "urgency"
else:
    # fallback to second column if present
    label_col = df_test.columns[1] if df_test.shape[1] > 1 else None

print(f"Using text column: '{text_col}', label column: '{label_col}'")

# -------------------------
# Drop rows missing text or labels
# -------------------------
if label_col is None:
    raise RuntimeError("No suitable label column found in df_test. Please ensure a numeric label column exists.")

# Coerce label to numeric and drop NaNs
df_test[label_col] = pd.to_numeric(df_test[label_col], errors="coerce")
before_drop = len(df_test)
df_test = df_test.dropna(subset=[text_col, label_col]).reset_index(drop=True)
after_drop = len(df_test)
print(f"Dropped {before_drop - after_drop} rows with missing text or non-numeric labels. Remaining: {after_drop}")

if len(df_test) == 0:
    raise RuntimeError("No rows left in df_test after cleaning. Please check your DataFrame and indices.")

# -------------------------
# Prediction helper (batched)
# -------------------------
model.eval()

def predict_batch(texts, batch_size=16):
    preds = []
    for i in range(0, len(texts), batch_size):
        batch_texts = texts[i:i+batch_size]
        # tokenizer can accept a list for batching
        enc = tokenizer(batch_texts,
                        truncation=True,
                        padding=True,
                        max_length=32,
                        return_tensors="pt")
        input_ids = enc["input_ids"].to(device)
        attention_mask = enc["attention_mask"].to(device)
        with torch.no_grad():
            logits = model(input_ids=input_ids, attention_mask=attention_mask)  # shape (B,)
            probs = torch.sigmoid(logits).cpu().numpy()
        preds.extend(probs.tolist())
    return np.array(preds)

# Run predictions
texts = df_test[text_col].astype(str).tolist()
preds = predict_batch(texts, batch_size=16)
df_test["predicted_urgency"] = preds

# Clamp labels to [0,1] just in case
df_test[label_col] = df_test[label_col].clip(0.0, 1.0)

# -------------------------
# Metrics: MAE, Pearson r
# -------------------------
df_test["abs_error"] = (df_test[label_col] - df_test["predicted_urgency"]).abs()
mae = df_test["abs_error"].mean()

def safe_pearson(a, b):
    a = np.asarray(a, dtype=float)
    b = np.asarray(b, dtype=float)
    if len(a) < 2:
        return float("nan")
    am = a - a.mean()
    bm = b - b.mean()
    denom = math.sqrt((am**2).sum() * (bm**2).sum())
    if denom == 0:
        return float("nan")
    return float((am * bm).sum() / denom)

pearson = safe_pearson(df_test[label_col].values, df_test["predicted_urgency"].values)

# -------------------------
# Print results (sorted by abs error)
# -------------------------
print(f"\nMAE on selected slice: {mae:.4f}")
print(f"Pearson r: {pearson:.4f}\n")

print("Results (sorted by abs_error desc):")
print(df_test[[text_col, label_col, "predicted_urgency", "abs_error"]]
      .sort_values("abs_error", ascending=False)
      .to_string(index=False, formatters={
          label_col: "{:.4f}".format,
          "predicted_urgency": "{:.4f}".format,
          "abs_error": "{:.4f}".format
      }))

# -------------------------
# Optional: show the raw df_test if you want
# -------------------------
print("\nFinal df_test shape:", df_test.shape)
#      [H]c1onc(C2([H])C([H])([H])C2([H])[H])c1[H] 0.2379            0.3801    0.1422
#           [H]c1nc(C2([H])N([H])C2([H])[H])nn1[H] 0.2367            0.3789    0.1422
#                [H]n1nnc2c1OC([H])([H])C2([H])[H] 0.2143            0.3557    0.1414
#           [H]c1noc(C2([H])N([H])C2([H])[H])c1[H] 0.2307            0.3718    0.1411
#      [H]c1nn([H])c(C2([H])N([H])C2([H])[H])c1[H] 0.2380            0.3772    0.1392
#           [H]c1onc(C2([H])N([H])C2([H])[H])c1[H] 0.2387            0.3710    0.1323
#            [H]c1nc2n(n1)C([H])([H])C([H])([H])O2 0.2454            0.3734    0.1280
#           [H]c1nn2c(c1[H])OC([H])([H])C2([H])[H] 0.2331            0.3512    0.1181
#                [H]c1nnn2c1OC([H])([H])C2([H])[H] 0.2228            0.3405    0.1177
#
# Final df_test shape: (100, 4)

# %%
pip install openpyxl
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Defaulting to user installation because normal site-packages is not writeable
# Collecting openpyxl
#   Downloading openpyxl-3.1.5-py2.py3-none-any.whl (250 kB)
#      |████████████████████████████████| 250 kB 7.1 MB/s eta 0:00:01
# Collecting et-xmlfile
#   Downloading et_xmlfile-2.0.0-py3-none-any.whl (18 kB)
# Installing collected packages: et-xmlfile, openpyxl
# Successfully installed et-xmlfile-2.0.0 openpyxl-3.1.5
# WARNING: You are using pip version 21.2.4; however, version 25.3 is available.
# You should consider upgrading via the '/Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
# 1. Compute the MAE (most common way)
mae = df_test["abs_error"].mean()
print(mae)

import openpyxl
df_test.to_excel("~/Desktop/my_results.xlsx", index=False, engine="openpyxl")
# Out:
# 0.1630652495559357

# %%
# quick sanity checks
assert 'df_test' in globals(), "df_test not found in globals() — please ensure df_test exists"
assert model is not None, "model not found"
assert tokenizer is not None, "tokenizer not found"
assert device is not None, "device not defined"

df_test = pd.read_csv(r"/Users/edwardclayson/Desktop/qm8.csv", nrows=150)
df_test = df_test.iloc[101:122].reset_index(drop=True)
df_test = df_test[['smiles', 'E1-CC2']]
print(df_test)
print(df_test.columns)
# Out:
#                                            smiles    E1-CC2
# 0   [H]C1([H])C2([H])C([H])([H])C1([H])C2([H])[H]  0.342918
# 1             [H]C1([H])C2([H])OC1([H])C2([H])[H]  0.265776
# 2                         [H]C#CC([H])([H])C#C[H]  0.269839
# 3                            [H]C#CC([H])([H])C#N  0.271908
# 4                               [H]C([H])(C#N)C#N  0.312861
# 5                       [H]C#CC([H])([H])C([H])=O  0.164412
# 6                          [H]C(=O)C([H])([H])C#N  0.164618
# 7                       [H]N=C([H])N([H])C([H])=O  0.183942
# 8                            [H]N=C([H])OC([H])=O  0.214191
# 9                          [H]C(=O)N([H])C([H])=O  0.172651
# 10                        [H]C#CC#CC([H])([H])[H]  0.204037
# 11                           [H]C([H])([H])C#CC#N  0.221354
# 12                      [H]C(=O)C#CC([H])([H])[H]  0.148978
# 13               [H]OC([H])([H])C#CC([H])([H])[H]  0.248975
# 14     [H]C([H])([H])C#CC([H])([H])C([H])([H])[H]  0.269998
# 15          [H]C(=NC([H])([H])[H])OC([H])([H])[H]  0.225629
# 16     [H]C#CC([H])([H])C([H])([H])C([H])([H])[H]  0.271462
# 17        [H]C([H])([H])C([H])([H])C([H])([H])C#N  0.316588
# 18             [H]N(C([H])([H])[H])C([H])([H])C#N  0.238479
# 19               [H]C#CC([H])([H])OC([H])([H])[H]  0.256150
# 20                  [H]C([H])([H])OC([H])([H])C#N  0.267748
# Index(['smiles', 'E1-CC2'], dtype='object')
